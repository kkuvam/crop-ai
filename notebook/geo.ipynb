# %%
import os
import time
import json
import requests
from typing import Dict, Any, List, Optional

# %%
locationiq_token = "pk.787388e33aac1f0c4ced6650d7a7e89d"

# %%
def load_jsonl(file_path):
    """Load a JSONL file and return a list of locations (strings)."""
    locations = []
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():  # skip empty lines
                obj = json.loads(line)
                locations.append(obj)
    return locations

# %%
def save_jsonl(data, file_path):
    """Save a list of dicts to JSONL."""
    with open(file_path, "w", encoding="utf-8") as f:
        for obj in data:
            f.write(json.dumps(obj, ensure_ascii=False) + "\n")

# %%
def build_name_query(rec: Dict[str, Any]) -> str:
    """
    Build a geocoding query string.
    Adjust keys as needed; we default to 'name' if present.
    """
    
    parts = [
        rec.get("market_name", ""),
        rec.get("district_name", ""),
        rec.get("state_name", "")
    ]
    base = " ".join(p for p in parts if p).strip()

    # Bias to India by adding the country token
    if base and "india" not in base.lower():
        base = f"{base} India"
    return base

# %%
def build_district_query(rec: Dict[str, Any]) -> Optional[str]:
    """
    Fallback query focusing on district + state (admin level).
    """
    dist = (rec.get("district_name") or "").strip()
    state = (rec.get("state_name") or "").strip()
    if not dist and not state:
        return None
    base = " ".join(p for p in [dist, state, "India"] if p)
    return base if base else None

# %%
def fetch_locationiq(q, api_key, retries=3, sleep_s=0.6):
    url = "https://us1.locationiq.com/v1/search"
    params = {
        "key": api_key,
        "q": q,
        "format": "json",
        "normalizecity": 1,
        "addressdetails": 1,
        "limit": 5,
        "countrycodes": "in",
        "accept-language": "en"
    }
    for attempt in range(retries):
        try:
            r = requests.get(url, params=params, timeout=20)
            r.raise_for_status()
            return r.json()
        except requests.RequestException:
            if attempt == retries - 1:
                return []
            time.sleep(sleep_s * (attempt + 1))
    return []

# %%
def select_best(results):
    if not results:
        return None
    # Prefer IN, then highest importance
    ranked = []
    for item in results:
        addr = item.get("address", {}) or {}
        cc = (addr.get("country_code") or "").lower()
        imp = item.get("importance", 0) or 0
        ranked.append((cc == "in", imp, item))
    ranked.sort(key=lambda t: (t[0], t[1]), reverse=True)
    best = ranked[0][2]
    return {
        "resolved_name": best.get("display_name"),
        "latitude": float(best.get("lat")) if best.get("lat") else None,
        "longitude": float(best.get("lon")) if best.get("lon") else None,
        "country_code": (best.get("address", {}).get("country_code") or "").upper(),
        "place_class": best.get("class"),
        "place_type": best.get("type"),
        "importance": best.get("importance"),
        "source": "locationiq"
    }

# %%
def resolve_by_name(rec: Dict[str, Any], api_key: str) -> Optional[Dict[str, Any]]:
    q = build_name_query(rec)
    results = fetch_locationiq(q, api_key=api_key)
    return select_best(results)

# %%
def resolve_by_district(rec: Dict[str, Any], api_key: str, cache: Dict[str, Dict[str, Any]]) -> Optional[Dict[str, Any]]:
    """
    Fallback: resolve using district+state. Uses a small in-memory cache to avoid
    repeating identical district queries.
    """
    q = build_district_query(rec)
    if not q:
        return None
    if q in cache:
        return cache[q]
    results = fetch_locationiq(q, api_key=api_key)
    best = select_best(results)
    cache[q] = best
    return best

# %%
input_file = "mandies.jsonl"
output_file = "mandies_20250907.jsonl"
locations = load_jsonl(input_file)
district_cache: Dict[str, Dict[str, Any]] = {}
api_key = locationiq_token
for loc in locations:
    print(f"Processing {loc['market_name']} {loc['state_name']}")
    best = resolve_by_name(loc, api_key=api_key)
    strategy = "name"
    # print(best)
    if not best or not best.get("latitude") or not best.get("longitude"):
        district_best = resolve_by_district(loc, api_key=api_key, cache=district_cache)
        if district_best:
            best = district_best
            strategy = "district"
            if best:
                loc.update(best)
                loc["resolution_strategy"] = strategy
            else:
                print(f"Unable to resolve >>>>>>>>>> {loc}")
    else:
        loc.update(best)
        loc["resolution_strategy"] = strategy
    
    # input("...")
save_jsonl(locations, output_file)
print(f"Enriched file saved to {output_file}")
# Out:
# Processing Kurnool Andhra Pradesh
# Processing Mandal Gujarat
# Processing Amreli Gujarat
# Processing Jamnagar Gujarat
# Processing Unjha Gujarat
# Processing Patan Gujarat
# Processing Shegaon Maharashtra
# Processing Pratapgarh Rajasthan
# Processing Chitradurga Karnataka
# Processing Davangere Karnataka
# Processing Mumbai Maharashtra
# Processing Binny Mill (F&V), Bangalore Karnataka
# Processing North Paravur Kerala
# Processing Balarampuram Kerala
# Processing Vadodara(Sayajipura) Gujarat
# Processing Kattappana Kerala
# Processing Nedumkandam Kerala
# Processing Kondotty Kerala
# Processing Kottakkal Kerala
# Processing Parappanangadi Kerala
# Processing Perinthalmanna Kerala
# Processing Nasik Maharashtra
# Processing Pune Maharashtra
# Processing Azadpur NCT of Delhi
# Processing Faridkot Punjab
# Processing Bhawanigarh Punjab
# Processing Chomu (F&V) Rajasthan
# Processing Jodhpur(F&V)(Paota) Rajasthan
# Processing Jameenrayapettai(Uzhavar Sandhai ) Tamil Nadu
# Processing Pallavaram(Uzhavar Sandhai ) Tamil Nadu
# Processing Thirukalukundram(Uzhavar Sandhai ) Tamil Nadu
# Processing Mettupalayam(Uzhavar Sandhai ) Tamil Nadu
# Processing Pollachi(Uzhavar Sandhai ) Tamil Nadu
# Processing RSPuram(Uzhavar Sandhai ) Tamil Nadu
# Processing Singanallur(Uzhavar Sandhai ) Tamil Nadu
# Processing Udumalpet Tamil Nadu
# Processing Vadavalli(Uzhavar Sandhai ) Tamil Nadu
# Processing Cuddalore(Uzhavar Sandhai ) Tamil Nadu
# Processing Dharmapuri(Uzhavar Sandhai ) Tamil Nadu
# Processing Palacode(Uzhavar Sandhai ) Tamil Nadu
# Processing Dindigul(Uzhavar Sandhai ) Tamil Nadu
# Processing Palani(Uzhavar Sandhai ) Tamil Nadu
# Processing Periyar Nagar(Uzhavar Sandhai ) Tamil Nadu
# Processing Sampath Nagar(Uzhavar Sandhai ) Tamil Nadu
# Processing Sankarapuram(Uzhavar Sandhai ) Tamil Nadu
# Processing Kulithalai(Uzhavar Sandhai ) Tamil Nadu
# Processing Pallapatti (Uzhavar Sandhai ) Tamil Nadu
# Processing Hosur(Uzhavar Sandhai ) Tamil Nadu
# Processing Krishnagiri(Uzhavar Sandhai ) Tamil Nadu
# Processing Anaiyur(Uzhavar Sandhai ) Tamil Nadu
# Processing Chokkikulam(Uzhavar Sandhai ) Tamil Nadu
# Processing Melur(Uzhavar Sandhai ) Tamil Nadu
# Processing Palanganatham(Uzhavar Sandhai ) Tamil Nadu
# Processing Vadaseri Tamil Nadu
# Processing Kumarapalayam(Uzhavar Sandhai ) Tamil Nadu
# Processing Namakkal(Uzhavar Sandhai ) Tamil Nadu
# Processing Rasipuram(Uzhavar Sandhai ) Tamil Nadu
# Processing Tiruchengode Tamil Nadu
# Processing Arcot(Uzhavar Sandhai ) Tamil Nadu
# Processing Ammapet(Uzhavar Sandhai ) Tamil Nadu
# Processing Athur(Uzhavar Sandhai ) Tamil Nadu
# Processing Edapadi (Uzhavar Sandhai ) Tamil Nadu
# Processing Hasthampatti(Uzhavar Sandhai ) Tamil Nadu
# Processing Jalagandapuram(Uzhavar Sandhai ) Tamil Nadu
# Processing Sooramangalam(Uzhavar Sandhai ) Tamil Nadu
# Processing Thathakapatti(Uzhavar Sandhai ) Tamil Nadu
# Processing Tenkasi(Uzhavar Sandhai ) Tamil Nadu
# Processing Kumbakonam (Uzhavar Sandhai ) Tamil Nadu
# Processing Udhagamandalam(Uzhavar Sandhai ) Tamil Nadu
# Processing Kambam(Uzhavar Sandhai ) Tamil Nadu
# Processing Theni(Uzhavar Sandhai ) Tamil Nadu
# Processing Lalgudi(Uzhavar Sandhai ) Tamil Nadu
# Processing Musiri(Uzhavar Sandhai ) Tamil Nadu
# Processing Melapalayam(Uzhavar Sandhai ) Tamil Nadu
# Processing NGO Colony(Uzhavar Sandhai ) Tamil Nadu
# Processing Palayamkottai(Uzhavar Sandhai ) Tamil Nadu
# Processing Vaniyampadi(Uzhavar Sandhai ) Tamil Nadu
# Processing Tiruppur (South) (Uzhavar Sandhai ) Tamil Nadu
# Processing Chengam(Uzhavar Sandhai ) Tamil Nadu
# Processing Polur(Uzhavar Sandhai ) Tamil Nadu
# Processing Tamarainagar(Uzhavar Sandhai ) Tamil Nadu
# Processing Tiruvannamalai(Uzhavar Sandhai ) Tamil Nadu
# Processing Tiruthuraipoondi(Uzhavar Sandhai ) Tamil Nadu
# Processing Tuticorin(Uzhavar Sandhai ) Tamil Nadu
# Processing Gudiyatham(Uzhavar Sandhai ) Tamil Nadu
# Processing Thirupathur Tamil Nadu
# Processing Vellore Tamil Nadu
# Processing Tindivanam Tamil Nadu
# Processing Ulundurpettai Tamil Nadu
# Processing Bowenpally Telangana
# Processing Alappuzha Kerala
# Processing Chengannur Kerala
# Processing Harippad Kerala
# Processing Kayamkulam Kerala
# Processing Madhavapuram Kerala
# Processing Mannar Kerala
# Processing Ernakulam Kerala
# Processing Piravam Kerala
# Processing Thrippunithura Kerala
# Processing Adimali Kerala
# Processing Neeleswaram Kerala
# Processing Kollam Kerala
# Processing Neduvathoor VFPCK Kerala
# Processing Veliyam VFPCK Kerala
# Processing Avarma VFPCK Kerala
# Processing Kanjirappally Kerala
# Processing Kuruppanthura Kerala
# Processing Kallachi Kerala
# Processing Mukkom Kerala
# Processing Palayam Kerala
# Processing Perambra Kerala
# Processing Quilandy Kerala
# Processing Aralamoodu Kerala
# Processing Attingal Kerala
# Processing Neyyatinkara Kerala
# Processing Pothencode Kerala
# Processing Flower Market,Gazipur NCT of Delhi
# Processing Chandigarh(Grain/Fruit) Chandigarh
# Processing Mapusa Goa
# Processing Porbandar Gujarat
# Processing Gondal(Veg.market Gondal) Gujarat
# Processing Vadhvan Gujarat
# Processing Ambala Cantt. Haryana
# Processing Barara Haryana
# Processing Naraingarh Haryana
# Processing Ch. Dadri Haryana
# Processing Faridabad Haryana
# Processing Ratia Haryana
# Processing Gurgaon Haryana
# Processing Pataudi Haryana
# Processing Barwala(Hisar) Haryana
# Processing Hansi Haryana
# Processing Uklana Haryana
# Processing Bahadurgarh Haryana
# Processing Narwana Haryana
# Processing Safidon Haryana
# Processing Dhand Haryana
# Processing Gharaunda Haryana
# Processing Indri Haryana
# Processing Tarori Haryana
# Processing Iamailabad Haryana
# Processing Ladwa Haryana
# Processing Shahabad Haryana
# Processing Thanesar Haryana
# Processing Narnaul Haryana
# Processing Tauru Haryana
# Processing Palwal Haryana
# Processing New Grain Market , Panchkula Haryana
# Processing Panchkul(Kalka) Haryana
# Processing Panipat Haryana
# Processing Rewari Haryana
# Processing Rohtak Haryana
# Processing Ellanabad Haryana
# Processing Sirsa Haryana
# Processing Ganaur Haryana
# Processing Gohana Haryana
# Processing Sonepat Haryana
# Processing Sonepat(Kharkhoda) Haryana
# Processing Jagadhri Haryana
# Processing Sadhaura Haryana
# Processing Yamuna Nagar Haryana
# Processing Chamba Himachal Pradesh
# Processing Hamirpur Himachal Pradesh
# Processing Hamirpur(Nadaun) Himachal Pradesh
# Processing Dharamshala Himachal Pradesh
# Processing Kangra Himachal Pradesh
# Processing Kangra(Baijnath) Himachal Pradesh
# Processing Kangra(Jaisinghpur) Himachal Pradesh
# Processing Kangra(Jassour) Himachal Pradesh
# Processing Kangra(Nagrota Bagwan) Himachal Pradesh
# Processing Palampur Himachal Pradesh
# Processing Dhanotu (Mandi) Himachal Pradesh
# Processing Mandi(Mandi) Himachal Pradesh
# Processing Solan Himachal Pradesh
# Processing Santoshgarh Himachal Pradesh
# Processing Una Himachal Pradesh
# Processing Batote Jammu and Kashmir
# Processing Udhampur Jammu and Kashmir
# Processing Munnar Kerala
# Processing Thodupuzha Kerala
# Processing Manjeri Kerala
# Processing Nagpur Maharashtra
# Processing Pune(Moshi) Maharashtra
# Processing Sangli(Phale, Bhajipura Market) Maharashtra
# Processing Solapur Maharashtra
# Processing Bathinda Punjab
# Processing Bassi Pathana Punjab
# Processing Sirhind Punjab
# Processing Fazilka Punjab
# Processing Jalalabad Punjab
# Processing Firozepur City Punjab
# Processing Dinanagar Punjab
# Processing Gurdaspur Punjab
# Processing Garh Shankar Punjab
# Processing Garh Shankar(Mahalpur) Punjab
# Processing Mukerian Punjab
# Processing Mukerian(Talwara) Punjab
# Processing Tanda Urmur Punjab
# Processing Jalandhar City(Jalandhar) Punjab
# Processing Phagwara Punjab
# Processing Jagraon Punjab
# Processing Khanna Punjab
# Processing Ludhiana Punjab
# Processing Budalada Punjab
# Processing Mansa Punjab
# Processing Nawan Shahar(Subzi Mandi) Punjab
# Processing Nabha Punjab
# Processing Patiala Punjab
# Processing Patran Punjab
# Processing Rajpura Punjab
# Processing Ropar Punjab
# Processing Lehra Gaga Punjab
# Processing Patti Punjab
# Processing Bikaner (F&V) Rajasthan
# Processing Sriganganagar (F&V) Rajasthan
# Processing Jodhpur (F&V) Rajasthan
# Processing Kota (F&V) Rajasthan
# Processing Guduvancheri(Uzhavar Sandhai ) Tamil Nadu
# Processing Kundrathur(Uzhavar Sandhai ) Tamil Nadu
# Processing Anna nagar(Uzhavar Sandhai ) Tamil Nadu
# Processing Perambalur(Uzhavar Sandhai ) Tamil Nadu
# Processing Mettur(Uzhavar Sandhai ) Tamil Nadu
# Processing Thanjavur(Uzhavar Sandhai ) Tamil Nadu
# Processing Mannargudi I(Uzhavar Sandhai ) Tamil Nadu
# Processing Tiruvarur(Uzhavar Sandhai ) Tamil Nadu
# Processing Kahithapattarai(Uzhavar Sandhai ) Tamil Nadu
# Processing Katpadi (Uzhavar Sandhai ) Tamil Nadu
# Processing Gaddiannaram Telangana
# Processing Warangal Telangana
# Processing Kanchanpur Tripura
# Processing Aligarh Uttar Pradesh
# Processing Akbarpur Uttar Pradesh
# Processing Jafarganj Uttar Pradesh
# Processing Sultanpur Uttar Pradesh
# Processing Amroha Uttar Pradesh
# Processing Dhanaura Uttar Pradesh
# Processing Hasanpur Uttar Pradesh
# Processing Achalda Uttar Pradesh
# Processing Auraiya Uttar Pradesh
# Processing Faizabad Uttar Pradesh
# Processing Azamgarh Uttar Pradesh
# Processing Badayoun Uttar Pradesh
# Processing Ujhani Uttar Pradesh
# Processing Baraut Uttar Pradesh
# Processing Bahraich Uttar Pradesh
# Processing Naanpara Uttar Pradesh
# Processing Ballia Uttar Pradesh
# Processing Rasda Uttar Pradesh
# Processing Balrampur Uttar Pradesh
# Processing Tulsipur Uttar Pradesh
# Processing Banda Uttar Pradesh
# Processing Barabanki Uttar Pradesh
# Processing Safdarganj Uttar Pradesh
# Processing Bareilly Uttar Pradesh
# Processing Richha Uttar Pradesh
# Processing Basti Uttar Pradesh
# Processing Gopiganj Uttar Pradesh
# Processing Nagina Uttar Pradesh
# Processing Buland Shahr Uttar Pradesh
# Processing Khurja Uttar Pradesh
# Processing Siyana Uttar Pradesh
# Processing Chandoli Uttar Pradesh
# Processing Devariya Uttar Pradesh
# Processing Etah Uttar Pradesh
# Processing Etawah Uttar Pradesh
# Processing Jasvantnagar Uttar Pradesh
# Processing Farukhabad Uttar Pradesh
# Processing Kamlaganj Uttar Pradesh
# Processing Kayamganj Uttar Pradesh
# Processing Mohamadabad Uttar Pradesh
# Processing Bindki Uttar Pradesh
# Processing Fatehpur Uttar Pradesh
# Processing Khaga Uttar Pradesh
# Processing Firozabad Uttar Pradesh
# Processing Dadri Uttar Pradesh
# Processing Dankaur Uttar Pradesh
# Processing Ghaziabad Uttar Pradesh
# Processing Hapur Uttar Pradesh
# Processing Noida Uttar Pradesh
# Processing Gonda Uttar Pradesh
# Processing Nawabganj Uttar Pradesh
# Processing Gorakhpur Uttar Pradesh
# Processing Bharuasumerpur Uttar Pradesh
# Processing Hardoi Uttar Pradesh
# Processing Madhoganj Uttar Pradesh
# Processing Sandi Uttar Pradesh
# Processing Sandila Uttar Pradesh
# Processing Shahabad(New Mandi) Uttar Pradesh
# Processing Haathras Uttar Pradesh
# Processing Jalaun Uttar Pradesh
# Processing Orai Uttar Pradesh
# Processing Jaunpur Uttar Pradesh
# Processing Mugrabaadshahpur Uttar Pradesh
# Processing Shahganj Uttar Pradesh
# Processing Jhansi Uttar Pradesh
# Processing Mauranipur Uttar Pradesh
# Processing Chhibramau Uttar Pradesh
# Processing Kannauj Uttar Pradesh
# Processing Choubepur Uttar Pradesh
# Processing Kanpur(Grain) Uttar Pradesh
# Processing Uttaripura Uttar Pradesh
# Processing Varipaal Uttar Pradesh
# Processing Pukharayan Uttar Pradesh
# Processing Kasganj Uttar Pradesh
# Processing Manjhanpur Uttar Pradesh
# Processing Maigalganj Uttar Pradesh
# Processing Mohammdi Uttar Pradesh
# Processing Tamkuhi road Uttar Pradesh
# Processing Golagokarnath Uttar Pradesh
# Processing Lakhimpur Uttar Pradesh
# Processing Lalitpur Uttar Pradesh
# Processing Lucknow Uttar Pradesh
# Processing Anandnagar Uttar Pradesh
# Processing Nautnava Uttar Pradesh
# Processing Partaval Uttar Pradesh
# Processing Mahoba Uttar Pradesh
# Processing Ghiraur Uttar Pradesh
# Processing Mainpuri Uttar Pradesh
# Processing Kosikalan Uttar Pradesh
# Processing Mathura Uttar Pradesh
# Processing Kopaganj Uttar Pradesh
# Processing Meerut Uttar Pradesh
# Processing Mirzapur Uttar Pradesh
# Processing Khatauli Uttar Pradesh
# Processing Muzzafarnagar Uttar Pradesh
# Processing Pilibhit Uttar Pradesh
# Processing Puranpur Uttar Pradesh
# Processing Vishalpur Uttar Pradesh
# Processing Pratapgarh Uttar Pradesh
# Processing Allahabad Uttar Pradesh
# Processing Jayas Uttar Pradesh
# Processing Rampur Uttar Pradesh
# Processing Vilaspur Uttar Pradesh
# Processing Saharanpur Uttar Pradesh
# Processing Chandausi Uttar Pradesh
# Processing Muradabad Uttar Pradesh
# Processing Sambhal Uttar Pradesh
# Processing Khalilabad Uttar Pradesh
# Processing Puwaha Uttar Pradesh
# Processing Shahjahanpur Uttar Pradesh
# Processing Tilhar Uttar Pradesh
# Processing Khandhla Uttar Pradesh
# Processing Shamli Uttar Pradesh
# Processing Thanabhavan Uttar Pradesh
# Processing Bhinga Uttar Pradesh
# Processing Naugarh Uttar Pradesh
# Processing Sitapur Uttar Pradesh
# Processing Viswan Uttar Pradesh
# Processing Robertsganj Uttar Pradesh
# Processing Bangarmau Uttar Pradesh
# Processing Purwa Uttar Pradesh
# Processing Unnao Uttar Pradesh
# Processing Varanasi(F&V) Uttar Pradesh
# Processing Dehradoon Uttrakhand
# Processing Rishikesh Uttrakhand
# Processing Vikasnagar Uttrakhand
# Processing Haridwar Union Uttrakhand
# Processing Haldwani Uttrakhand
# Processing Ramnagar Uttrakhand
# Processing Kashipur Uttrakhand
# Processing Rudrapur Uttrakhand
# Processing Mechua West Bengal
# Processing Sanquelim Goa
# Processing Valpol Goa
# Processing Curchorem Goa
# Processing Ponda Goa
# Processing Koppa Karnataka
# Processing Honnavar Karnataka
# Processing Sirsi Karnataka
# Processing Yellapur Karnataka
# Processing Gonikappal Karnataka
# Processing K.R. Pet Karnataka
# Processing Bantwala Karnataka
# Processing Bhadravathi Karnataka
# Processing Shimoga Karnataka
# Processing Shimogga(Theertahalli) Karnataka
# Processing Sira Karnataka
# Processing Karkala Karnataka
# Processing Perumbavoor Kerala
# Processing Kuthuparambu Kerala
# Processing Payyannur Kerala
# Processing Kanjangadu Kerala
# Processing Kasargod Kerala
# Processing Manjeswaram Kerala
# Processing Shillong Meghalaya
# Processing Nuiland Nagaland
# Processing Adoni Andhra Pradesh
# Processing Yemmiganur Andhra Pradesh
# Processing Rajula Gujarat
# Processing Savarkundla Gujarat
# Processing Amod Gujarat
# Processing Jambusar Gujarat
# Processing Jambusar(Kaavi) Gujarat
# Processing Valia Gujarat
# Processing Valia(Nethrang) Gujarat
# Processing Bhavnagar Gujarat
# Processing Mahuva(Station Road) Gujarat
# Processing Palitana Gujarat
# Processing Taleja Gujarat
# Processing Botad Gujarat
# Processing Bodeliu Gujarat
# Processing Hadad Gujarat
# Processing Dahod Gujarat
# Processing Dhrol Gujarat
# Processing Kalawad Gujarat
# Processing Bhesan Gujarat
# Processing Junagadh Gujarat
# Processing Visavadar Gujarat
# Processing Halvad Gujarat
# Processing Rajpipla Gujarat
# Processing Gogamba Gujarat
# Processing Gogamba(Similiya) Gujarat
# Processing Sami Gujarat
# Processing Dhoraji Gujarat
# Processing Gondal Gujarat
# Processing Jasdan Gujarat
# Processing Jetpur(Dist.Rajkot) Gujarat
# Processing Rajkot Gujarat
# Processing Upleta Gujarat
# Processing Khedbrahma Gujarat
# Processing Vadali Gujarat
# Processing Mandvi Gujarat
# Processing Vyra Gujarat
# Processing Chotila Gujarat
# Processing Dasada Patadi Gujarat
# Processing Dhragradhra Gujarat
# Processing Vagodiya Gujarat
# Processing Chittapur Karnataka
# Processing Raichur Karnataka
# Processing Palakkad Kerala
# Processing Betul Madhya Pradesh
# Processing Burhanpur Madhya Pradesh
# Processing Chaurai Madhya Pradesh
# Processing Chhindwara Madhya Pradesh
# Processing Damoh Madhya Pradesh
# Processing Patharia Madhya Pradesh
# Processing Bagli Madhya Pradesh
# Processing Kannod Madhya Pradesh
# Processing Harda Madhya Pradesh
# Processing Khirakiya Madhya Pradesh
# Processing Itarsi Madhya Pradesh
# Processing Pipariya Madhya Pradesh
# Processing Indore Madhya Pradesh
# Processing Mhow Madhya Pradesh
# Processing Jabalpur Madhya Pradesh
# Processing Paatan Madhya Pradesh
# Processing Katni Madhya Pradesh
# Processing Harsood Madhya Pradesh
# Processing Khandwa Madhya Pradesh
# Processing Badwaha Madhya Pradesh
# Processing Bhikangaon Madhya Pradesh
# Processing Khargone Madhya Pradesh
# Processing Sanawad Madhya Pradesh
# Processing Nainpur Madhya Pradesh
# Processing Kailaras Madhya Pradesh
# Processing Morena Madhya Pradesh
# Processing Gadarwada Madhya Pradesh
# Processing Gotegaon Madhya Pradesh
# Processing Kareli Madhya Pradesh
# Processing Narsinghpur Madhya Pradesh
# Processing Bareli Madhya Pradesh
# Processing Udaipura Madhya Pradesh
# Processing Sagar Madhya Pradesh
# Processing Satna Madhya Pradesh
# Processing Nasrullaganj Madhya Pradesh
# Processing Sehore Madhya Pradesh
# Processing Ghansour Madhya Pradesh
# Processing Ahmednagar Maharashtra
# Processing Jamkhed Maharashtra
# Processing Karjat Maharashtra
# Processing Kopargaon Maharashtra
# Processing Rahuri(Vambori) Maharashtra
# Processing Shevgaon Maharashtra
# Processing Shevgaon(Bodhegaon) Maharashtra
# Processing Akola Maharashtra
# Processing Achalpur Maharashtra
# Processing Amarawati Maharashtra
# Processing Anajngaon Maharashtra
# Processing Chandur Bazar Maharashtra
# Processing Chandur Railway Maharashtra
# Processing Shetkari Khushi Bazar Maharashtra
# Processing Varud(Rajura Bazar) Maharashtra
# Processing Ambejaogai Maharashtra
# Processing Beed Maharashtra
# Processing Gevrai Maharashtra
# Processing Kada Maharashtra
# Processing Majalgaon Maharashtra
# Processing Parali Vaijyanath Maharashtra
# Processing Bhandara Maharashtra
# Processing BSK Krishi Bazar Private Ltd Maharashtra
# Processing Buldhana(Dhad) Maharashtra
# Processing Chikali Maharashtra
# Processing Deoulgaon Raja Maharashtra
# Processing Jaykissan Krushi Uttpan Khajgi Bazar Maharashtra
# Processing Khamgaon Maharashtra
# Processing Lonar Maharashtra
# Processing Malkapur Maharashtra
# Processing Mehekar Maharashtra
# Processing Chandrapur Maharashtra
# Processing Rajura Maharashtra
# Processing Chattrapati Sambhajinagar Maharashtra
# Processing Gangapur Maharashtra
# Processing Kannad Maharashtra
# Processing Murum Maharashtra
# Processing Umarga Maharashtra
# Processing Shirpur Maharashtra
# Processing Sengoan Maharashtra
# Processing Jalana Maharashtra
# Processing Chopada Maharashtra
# Processing Dharangaon Maharashtra
# Processing Jalgaon Maharashtra
# Processing Chakur Maharashtra
# Processing Devani Maharashtra
# Processing Nilanga Maharashtra
# Processing Kalmeshwar Maharashtra
# Processing Katol Maharashtra
# Processing Savner Maharashtra
# Processing Bhokar Maharashtra
# Processing Himalyatnagar Maharashtra
# Processing Kandhar Maharashtra
# Processing Kinwat Maharashtra
# Processing Mukhed Maharashtra
# Processing Nanded Maharashtra
# Processing Nandurbar Maharashtra
# Processing Lasalgaon Maharashtra
# Processing Lasalgaon(Niphad) Maharashtra
# Processing Manmad Maharashtra
# Processing Nandgaon Maharashtra
# Processing Yeola Maharashtra
# Processing Gangakhed Maharashtra
# Processing Jintur Maharashtra
# Processing Manwat Maharashtra
# Processing Barshi Maharashtra
# Processing Barshi(Vairag) Maharashtra
# Processing Dudhani Maharashtra
# Processing Karmala Maharashtra
# Processing Kurdwadi Maharashtra
# Processing Karanja Maharashtra
# Processing Krushna Krishi Bazar Maharashtra
# Processing Mangrulpeer Maharashtra
# Processing Manora Maharashtra
# Processing N N Mundhada Agriculture Market Produce Maharashtra
# Processing Risod Maharashtra
# Processing Arvi Maharashtra
# Processing Hinganghat Maharashtra
# Processing Pulgaon Maharashtra
# Processing Sindi Maharashtra
# Processing Sindi(Selu) Maharashtra
# Processing Wardha Maharashtra
# Processing Bori Arab Maharashtra
# Processing Digras Maharashtra
# Processing Ghatanji Maharashtra
# Processing Kalamb Maharashtra
# Processing Kisan Market Yard Maharashtra
# Processing Mahesh Krushi Utpanna Bazar, Digras Maharashtra
# Processing Ner Parasopant Maharashtra
# Processing Pandhakawada Maharashtra
# Processing Ramdev Krushi Bazaar Maharashtra
# Processing Vani Maharashtra
# Processing Yeotmal Maharashtra
# Processing Sumerganj Rajasthan
# Processing Gangapur City Rajasthan
# Processing Khairthal Rajasthan
# Processing Ranipettai(Uzhavar Sandhai ) Tamil Nadu
# Processing Natrampalli(Uzhavar Sandhai ) Tamil Nadu
# Processing Asifabad Telangana
# Processing Bhainsa Telangana
# Processing Choppadandi Telangana
# Processing Jagtial Telangana
# Processing Karimnagar Telangana
# Processing Badepalli Telangana
# Processing Gadwal Telangana
# Processing Narayanpet Telangana
# Processing Siddipet Telangana
# Processing Zaheerabad Telangana
# Processing Aler Telangana
# Processing Suryapeta Telangana
# Processing Tirumalagiri Telangana
# Processing Pargi Telangana
# Processing Tanduru Telangana
# Processing Jam Jodhpur Gujarat
# Processing Morbi Gujarat
# Processing Bishenpur Manipur
# Processing Lamlong Bazaar Manipur
# Processing Imphal Manipur
# Processing Kakching Market Manipur
# Processing Thoubal Manipur
# Processing Agra Uttar Pradesh
# Processing Chorichora Uttar Pradesh
# Processing Lalganj Uttar Pradesh
# Processing Varanasi Uttar Pradesh
# Processing Sainthia West Bengal
# Processing Siliguri West Bengal
# Processing Ramkrishanpur(Howrah) West Bengal
# Processing Asansol West Bengal
# Processing Agar Madhya Pradesh
# Processing Neemuch Madhya Pradesh
# Processing Vidisha Madhya Pradesh
# Processing Gudimalkapur Telangana
# Processing Borsad Gujarat
# Processing Khambhat(Grain Market) Gujarat
# Processing Umreth Gujarat
# Processing Amirgadh Gujarat
# Processing Diyodar Gujarat
# Processing Palanpur Gujarat
# Processing Panthawada Gujarat
# Processing Thara Gujarat
# Processing Tharad Gujarat
# Processing Vadgam Gujarat
# Processing Dehgam Gujarat
# Processing Dehgam(Rekhiyal) Gujarat
# Processing Mansa Gujarat
# Processing Mehsana(Jornang) Gujarat
# Processing Visnagar Gujarat
# Processing Siddhpur Gujarat
# Processing Talod Gujarat
# Processing Ateli Haryana
# Processing Kalburgi Karnataka
# Processing Bhind Madhya Pradesh
# Processing Kukshi Madhya Pradesh
# Processing Porsa Madhya Pradesh
# Processing Rahuri Maharashtra
# Processing Ambad (Vadigodri) Maharashtra
# Processing Jalgaon(Masawat) Maharashtra
# Processing Pachora Maharashtra
# Processing Devala Maharashtra
# Processing Satana Maharashtra
# Processing Sangli Maharashtra
# Processing Ulhasnagar Maharashtra
# Processing Narela NCT of Delhi
# Processing Alwar Rajasthan
# Processing Beawar Rajasthan
# Processing Bharatpur Rajasthan
# Processing Bhusawar Bair Rajasthan
# Processing Nadwai Rajasthan
# Processing Bandikui Rajasthan
# Processing Bandikui(Geejgarh) Rajasthan
# Processing Lalsot Rajasthan
# Processing Madanganj Mahuwa Rajasthan
# Processing Madanganj Mandawar Rajasthan
# Processing Mandawari Rajasthan
# Processing Deedwana Rajasthan
# Processing Kama Rajasthan
# Processing Dholpur Rajasthan
# Processing Bassi Rajasthan
# Processing Chomu (Grain) Rajasthan
# Processing Ositan Mathania Rajasthan
# Processing Hindoun Rajasthan
# Processing Tijara Rajasthan
# Processing Kota Rajasthan
# Processing Bansoor Rajasthan
# Processing Sri Madhopur Rajasthan
# Processing Raniwara Rajasthan
# Processing Palsana Rajasthan
# Processing Sawai Madhopur Rajasthan
# Processing Deoli Rajasthan
# Processing Dooni Rajasthan
# Processing Malpura Rajasthan
# Processing Udaipur (Grain) Rajasthan
# Processing Coimbatore Tamil Nadu
# Processing Panruti Tamil Nadu
# Processing Gingee Tamil Nadu
# Processing Kallakurichi Tamil Nadu
# Processing Thirukovilur Tamil Nadu
# Processing Villupuram Tamil Nadu
# Processing Achnera Uttar Pradesh
# Processing Fatehabad Uttar Pradesh
# Processing Jagnair Uttar Pradesh
# Processing Khairagarh Uttar Pradesh
# Processing Charra Uttar Pradesh
# Processing Visoli Uttar Pradesh
# Processing Wazirganj Uttar Pradesh
# Processing Sikandraraau Uttar Pradesh
# Processing Bewar Uttar Pradesh
# Processing Bhehjoi Uttar Pradesh
# Processing Tirupati Andhra Pradesh
# Processing Ambajipeta Andhra Pradesh
# Processing Ravulapelem Andhra Pradesh
# Processing Nalbari Assam
# Processing Khambhat(Veg Yard Khambhat) Gujarat
# Processing Mehsana(Mehsana Veg) Gujarat
# Processing Navsari Gujarat
# Processing Hissar Haryana
# Processing Meham Haryana
# Processing Sampla Haryana
# Processing Rania Haryana
# Processing Bilaspur Himachal Pradesh
# Processing Bhuntar Himachal Pradesh
# Processing Solan(Nalagarh) Himachal Pradesh
# Processing Parimpore Jammu and Kashmir
# Processing Venmony VFPCK Kerala
# Processing Aluva Kerala
# Processing Kadungallur VFPCK Kerala
# Processing Kothamangalam Kerala
# Processing Kunnukara VFPCK Kerala
# Processing Malayattoor VFPCK Kerala
# Processing Mazhuvannur VFPCK Kerala
# Processing Mookkannur VFPCK Kerala
# Processing Moovattupuzha Kerala
# Processing Nedungapra VFPCK Kerala
# Processing Thiruvaniyoor VFPCK Kerala
# Processing Alacode VFPCK Kerala
# Processing Kamakshi VFPCK Kerala
# Processing Kodikulam VFPCK Kerala
# Processing Udumbannoor VFPCK Kerala
# Processing Vandiperiyar Kerala
# Processing Irityy Kerala
# Processing Koodali VFPCK Kerala
# Processing Taliparamba Kerala
# Processing Thalasserry Kerala
# Processing Anchal Kerala
# Processing Anchal VFPCK Kerala
# Processing Chathanoor Kerala
# Processing Chengamanad VFPCK Kerala
# Processing Elamad VFPCK Kerala
# Processing Kadakkal VFPCK Kerala
# Processing Kottarakkara Kerala
# Processing Nedumpaikulam VFPCK Kerala
# Processing Nedumpana VFPCK Kerala
# Processing Punalur VFPCK Kerala
# Processing Sasthamkotta VFPCK Kerala
# Processing Athirampuzha Kerala
# Processing Ettumanoor Kerala
# Processing Kattampak VFPCK Kerala
# Processing Kottayam Kerala
# Processing Kuriem VFPCK Kerala
# Processing Mannackanad VFPCK Kerala
# Processing Mutholy VFPCK Kerala
# Processing Pala Kerala
# Processing Pampady Kerala
# Processing Thalayolaparambu Kerala
# Processing Thottuva VFPCK Kerala
# Processing Vayala VFPCK Kerala
# Processing Vempally VFPCK Kerala
# Processing Keezhparamba VFPCK Kerala
# Processing Mukkam VFPCK Kerala
# Processing Vellannur VFPCK Kerala
# Processing Elamkur VFPCK Kerala
# Processing Othayi VFPCK Kerala
# Processing Parappanangadi VFPCK Kerala
# Processing Thalappara VFPCK Kerala
# Processing Thirurrangadi Kerala
# Processing Thiruvali VFPCK Kerala
# Processing Kadambazhi puram VFPCK Kerala
# Processing Koduvayoor Kerala
# Processing Kollengode Kerala
# Processing Pattambi Kerala
# Processing Vadakkenchery Kerala
# Processing Kalanjoor VFPCK Kerala
# Processing Kuttoor Kerala
# Processing Mallappally VFPCK Kerala
# Processing Mezhuveli VFPCK Kerala
# Processing Omalloor Kerala
# Processing Pallikkal VFPCK Kerala
# Processing Pandalam Kerala
# Processing Pandalam Thekkekkara VFPCK Kerala
# Processing Pramadom VFPCK Kerala
# Processing Seethathode VFPCK Kerala
# Processing Alengad VFPCK Kerala
# Processing Amballur VFPCK Kerala
# Processing Annamanada VFPCK Kerala
# Processing Chalakudy Kerala
# Processing Chavakkad Kerala
# Processing Irinjalakkuda Kerala
# Processing Kuzhur VFPCK Kerala
# Processing Marottichal VFPCK Kerala
# Processing Muriyad VFPCK Kerala
# Processing Nooluvally VFPCK Kerala
# Processing Pazhayannur VFPCK Kerala
# Processing Puthur VFPCK Kerala
# Processing Varandarappilly VFPCK Kerala
# Processing Anyara(EEC) Kerala
# Processing Balaramapuram VFPCK Kerala
# Processing Chenkal VFPCK Kerala
# Processing Kallara VFPCK Kerala
# Processing Kollayil VFPCK Kerala
# Processing Kunnathukkal VFPCK Kerala
# Processing Maranelloor VFPCK Kerala
# Processing Nedumangadu Kerala
# Processing Neyyattinkara VFPCK Kerala
# Processing Vamanapuram Kerala
# Processing Vellarada VFPCK Kerala
# Processing Vengannore VFPCK Kerala
# Processing Manathavady Kerala
# Processing Padinjarathara VFPCK Kerala
# Processing Pulpally Kerala
# Processing Sulthanbathery VFPCK Kerala
# Processing Hoshangabad(F&V) Madhya Pradesh
# Processing Sheopurkalan(F&V) Madhya Pradesh
# Processing Yawal Maharashtra
# Processing Williamnagar Meghalaya
# Processing Wahiajer Meghalaya
# Processing Tuli Nagaland
# Processing Tsemenyu Nagaland
# Processing Bhagta Bhai Ka Punjab
# Processing Raman Punjab
# Processing Talwandi Sabo Punjab
# Processing GarhShankar (Kotfatuhi) Punjab
# Processing Hoshiarpur Punjab
# Processing Banur Punjab
# Processing Bariwala Punjab
# Processing Pathankot Punjab
# Processing Dudhansadhan Punjab
# Processing Chamkaur Sahib Punjab
# Processing Dhuri Punjab
# Processing Udaipur (F&V) Rajasthan
# Processing Ariyalur(Uzhavar Sandhai) Tamil Nadu
# Processing Jeyankondam (Uzhavar Sandhai ) Tamil Nadu
# Processing Madhuranthagam(Uzhavar Sandhai ) Tamil Nadu
# Processing Sulur(Uzhavar Sandhai ) Tamil Nadu
# Processing Sundarapuram(Uzhavar Sandhai ) Tamil Nadu
# Processing Chidambaram(Uzhavar Sandhai ) Tamil Nadu
# Processing Panruti(Uzhavar Sandhai ) Tamil Nadu
# Processing Viruthachalam(Uzhavar Sandhai ) Tamil Nadu
# Processing AJattihalli(Uzhavar Sandhai ) Tamil Nadu
# Processing Harur(Uzhavar Sandhai ) Tamil Nadu
# Processing Pennagaram(Uzhavar Sandhai ) Tamil Nadu
# Processing Chinnalapatti(Uzhavar Sandhai ) Tamil Nadu
# Processing Vedasanthur(Uzhavar Sandhai ) Tamil Nadu
# Processing Gobichettipalayam(Uzhavar Sandhai ) Tamil Nadu
# Processing Perundurai(Uzhavar Sandhai ) Tamil Nadu
# Processing Sathiyamagalam(Uzhavar Sandhai ) Tamil Nadu
# Processing Thalavadi(Uzhavar Sandhai ) Tamil Nadu
# Processing Kallakurichi(Uzhavar Sandhai ) Tamil Nadu
# Processing Kancheepuram(Uzhavar Sandhai ) Tamil Nadu
# Processing Padappai(Uzhavar Sandhai ) Tamil Nadu
# Processing Karur(Uzhavar Sandhai ) Tamil Nadu
# Processing Velayuthampalayam(Uzhavar Sandhai ) Tamil Nadu
# Processing Denkanikottai(Uzhavar Sandhai ) Tamil Nadu
# Processing Kaveripattinam(Uzhavar Sandhai ) Tamil Nadu
# Processing Mayiladuthurai(Uzhavar Sandhai ) Tamil Nadu
# Processing Nagapattinam(Uzhavar Sandhai ) Tamil Nadu
# Processing Sirkali(Uzhavar Sandhai ) Tamil Nadu
# Processing Myladi(Uzhavar Sandhai ) Tamil Nadu
# Processing Mohanur(Uzhavar Sandhai ) Tamil Nadu
# Processing Paramathivelur(Uzhavar Sandhai ) Tamil Nadu
# Processing Alangudi(Uzhavar Sandhai ) Tamil Nadu
# Processing Aranthangi(Uzhavar Sandhai ) Tamil Nadu
# Processing Gandarvakottai(Uzhavar Sandhai ) Tamil Nadu
# Processing Karambakkudi(Uzhavar Sandhai ) Tamil Nadu
# Processing Pudukottai(Uzhavar Sandhai ) Tamil Nadu
# Processing Viralimalai(Uzhavar Sandhai ) Tamil Nadu
# Processing Paramakudi(Uzhavar Sandhai ) Tamil Nadu
# Processing Ramanathapuram(Uzhavar Sandhai ) Tamil Nadu
# Processing Attayampatti(Uzhavar Sandhai ) Tamil Nadu
# Processing Elampillai(Uzhavar Sandhai ) Tamil Nadu
# Processing Thammampatti (Uzhavar Sandhai ) Tamil Nadu
# Processing Devakottai (Uzhavar Sandhai ) Tamil Nadu
# Processing Karaikudi(Uzhavar Sandhai ) Tamil Nadu
# Processing Singampunari(Uzhavar Sandhai ) Tamil Nadu
# Processing Sivagangai (Uzhavar Sandhai ) Tamil Nadu
# Processing Tirupatthur(Uzhavar Sandhai ) Tamil Nadu
# Processing Sankarankoil(Uzhavar Sandhai ) Tamil Nadu
# Processing Papanasam(Uzhavar Sandhai ) Tamil Nadu
# Processing Pattukottai(Uzhavar Sandhai ) Tamil Nadu
# Processing Coonoor(Uzhavar Sandhai ) Tamil Nadu
# Processing Andipatti(Uzhavar Sandhai ) Tamil Nadu
# Processing Bodinayakanur(Uzhavar Sandhai ) Tamil Nadu
# Processing Chinnamanur(Uzhavar Sandhai ) Tamil Nadu
# Processing Devaram(Uzhavar Sandhai ) Tamil Nadu
# Processing Periyakulam(Uzhavar Sandhai ) Tamil Nadu
# Processing Manachanallur(Uzhavar Sandhai ) Tamil Nadu
# Processing Manapparai(Uzhavar Sandhai ) Tamil Nadu
# Processing Thuraiyur Tamil Nadu
# Processing Dharapuram(Uzhavar Sandhai ) Tamil Nadu
# Processing Kangayam(Uzhavar Sandhai ) Tamil Nadu
# Processing Palladam(Uzhavar Sandhai ) Tamil Nadu
# Processing Tiruppur (North) (Uzhavar Sandhai ) Tamil Nadu
# Processing Arani(Uzhavar Sandhai ) Tamil Nadu
# Processing Cheyyar(Uzhavar Sandhai ) Tamil Nadu
# Processing Mannargudi II(Uzhavar Sandhai ) Tamil Nadu
# Processing Paruthipattu(Uzhavar Sandhai ) Tamil Nadu
# Processing Tiruvallur(Uzhavar Sandhai ) Tamil Nadu
# Processing Kovilpatti(Uzhavar Sandhai ) Tamil Nadu
# Processing Gingee(Uzhavar Sandhai ) Tamil Nadu
# Processing Aruppukottai(Uzhavar Sandhai ) Tamil Nadu
# Processing Rajapalayam(Uzhavar Sandhai ) Tamil Nadu
# Processing Sivakasi(Uzhavar Sandhai ) Tamil Nadu
# Processing Srivilliputhur(Uzhavar Sandhai ) Tamil Nadu
# Processing Thalavaipuram(Uzhavar Sandhai ) Tamil Nadu
# Processing Virudhunagar(Uzhavar Sandhai ) Tamil Nadu
# Processing Melaghar Tripura
# Processing Khair Uttar Pradesh
# Processing Shahaswan Uttar Pradesh
# Processing Chitwadagaon Uttar Pradesh
# Processing Karvi Uttar Pradesh
# Processing Muskara Uttar Pradesh
# Processing Moth Uttar Pradesh
# Processing Milak Uttar Pradesh
# Processing Hargaon (Laharpur) Uttar Pradesh
# Processing Tanakpur Uttrakhand
# Processing Roorkee Uttrakhand
# Processing Khateema Uttrakhand
# Processing Sitarganj Uttrakhand
# Processing Bharuch Gujarat
# Processing Surat Gujarat
# Processing Cheriyanadu VFPCK Kerala
# Processing Cherthala Kerala
# Processing Pandanadu VFPCK Kerala
# Processing Thazhakkara VFPCK Kerala
# Processing Angamaly Kerala
# Processing Broadway market Kerala
# Processing Keezhampara VFPCK Kerala
# Processing Puthenvelikkara VFPCK Kerala
# Processing Chavassery VFPCK Kerala
# Processing Kannur Kerala
# Processing Maloor VFPCK Kerala
# Processing Pattiyam VFPCK Kerala
# Processing Thamarassery Kerala
# Processing Puthupariyaram VFPCK Kerala
# Processing Wadakkanchery Kerala
# Processing Parassala VFPCK Kerala
# Processing Kalpetta Kerala
# Processing Sultan bathery Kerala
# Processing Bhusaval Maharashtra
# Processing Boudh Odisha
# Processing Hindol Odisha
# Processing Samana Punjab
# Processing Nanganallur(Uzhavar Sandhai ) Tamil Nadu
# Processing Sunguvarchatram(Uzhavar Sandhai ) Tamil Nadu
# Processing Avallapalli(Uzhavar Sandhai ) Tamil Nadu
# Processing Usilampatty Tamil Nadu
# Processing Muthupettai(Uzhavar Sandhai ) Tamil Nadu
# Processing Needamangalam(Uzhavar Sandhai ) Tamil Nadu
# Processing Valangaiman Tamil Nadu
# Processing Naravarikuppam(Uzhavar Sandhai ) Tamil Nadu
# Processing Perambakkam(Uzhavar Sandhai ) Tamil Nadu
# Processing Sathur(Uzhavar Sandhai ) Tamil Nadu
# Processing L B Nagar Telangana
# Processing Kukatpally(Rythu Bazar) Telangana
# Processing Mehndipatnam(Rythu Bazar) Telangana
# Processing Boxonagar Tripura
# Processing Sonamura Tripura
# Processing Rudauli Uttar Pradesh
# Processing Kiratpur Uttar Pradesh
# Processing Gadaura Uttar Pradesh
# Processing Shahpur Uttar Pradesh
# Processing Farukh Nagar Haryana
# Processing Kotma Madhya Pradesh
# Processing Bijawar Madhya Pradesh
# Processing Chhatarpur Madhya Pradesh
# Processing Harpalpur Madhya Pradesh
# Processing Naugaon Madhya Pradesh
# Processing Rajnagar Madhya Pradesh
# Processing Datia Madhya Pradesh
# Processing Lashkar Madhya Pradesh
# Processing Mandsaur Madhya Pradesh
# Processing Manasa Madhya Pradesh
# Processing Nagod Madhya Pradesh
# Processing Soyatkalan Madhya Pradesh
# Processing Sheopurkalan Madhya Pradesh
# Processing Karera Madhya Pradesh
# Processing Khanyadhana Madhya Pradesh
# Processing Kolaras Madhya Pradesh
# Processing Pichhour Madhya Pradesh
# Processing Niwadi Madhya Pradesh
# Processing Tikamgarh Madhya Pradesh
# Processing Tikamgarh(F&V) Madhya Pradesh
# Processing Najafgarh NCT of Delhi
# Processing Jhunjhunu Rajasthan
# Processing Nawalgarh Rajasthan
# Processing Anupgarh Rajasthan
# Processing Gharsana Rajasthan
# Processing Jaitsar Rajasthan
# Processing Rawla Rajasthan
# Processing Sri Vijayanagar Rajasthan
# Processing Baran Rajasthan
# Processing Nahargarh Rajasthan
# Processing Vijaynagar Rajasthan
# Processing Bhilwara Rajasthan
# Processing Bundi Rajasthan
# Processing Dei Rajasthan
# Processing Keshoraipatan Rajasthan
# Processing Nimbahera Rajasthan
# Processing Gajsinghpur Rajasthan
# Processing Ridmalsar Rajasthan
# Processing Sriganganagar (Grain) Rajasthan
# Processing Suratgarh Rajasthan
# Processing Nohar Rajasthan
# Processing Rawatsar Rajasthan
# Processing Kishan Renwal(Fulera) Rajasthan
# Processing Sambhar (Kishangarh renwal) Rajasthan
# Processing Kishangarhbas Rajasthan
# Processing Chhotisadri Rajasthan
# Processing Niwai Rajasthan
# Processing Tonk Rajasthan
# Processing Jhansi (Grain) Uttar Pradesh
# Processing Lakhipur Assam
# Processing Brahmaputra Private Market Assam
# Processing Pamohi(Garchuk) Assam
# Processing Ramanagara Karnataka
# Processing Chamaraj Nagar Karnataka
# Processing Chikkamagalore Karnataka
# Processing Chickkaballapura Karnataka
# Processing Kolar Karnataka
# Processing Malur Karnataka
# Processing Mysore (Bandipalya) Karnataka
# Processing Rahata Maharashtra
# Processing Vadgaonpeth Maharashtra
# Processing Junnar(Otur) Maharashtra
# Processing Manchar Maharashtra
# Processing Pune(Khadiki) Maharashtra
# Processing Pune(Manjri) Maharashtra
# Processing Pune(Pimpri) Maharashtra
# Processing Panvel Maharashtra
# Processing Ratnagiri (Nachane) Maharashtra
# Processing Akluj Maharashtra
# Processing Kalyan Maharashtra
# Processing Dimapur Nagaland
# Processing Kohima Nagaland
# Processing Kesinga Odisha
# Processing Gudalur(Uzhavar Sandhai ) Tamil Nadu
# Processing Keelpennathur(Uzhavar Sandhai ) Tamil Nadu
# Processing Barpeta Road Assam
# Processing Sibsagar Assam
# Processing Nadiyad(Piplag) Gujarat
# Processing Ballabhgarh Haryana
# Processing Punalur Kerala
# Processing vadakarapathy Kerala
# Processing Amrawati(Frui & Veg. Market) Maharashtra
# Processing Rayagada(Muniguda) Odisha
# Processing Mahboob Manison Telangana
# Processing Dibiapur Uttar Pradesh
# Processing Dudhi Uttar Pradesh
# Processing Bhatapara Chattisgarh
# Processing Kunkuri Chattisgarh
# Processing Kheragarh Chattisgarh
# Processing Viramgam Gujarat
# Processing Bagasara Gujarat
# Processing Dhari Gujarat
# Processing Khambha Gujarat
# Processing Zalod(Zalod) Gujarat
# Processing Vankaner Gujarat
# Processing Harij Gujarat
# Processing Radhanpur Gujarat
# Processing Himatnagar Gujarat
# Processing Nizar Gujarat
# Processing Bailahongal Karnataka
# Processing Ramdurga Karnataka
# Processing Alirajpur Madhya Pradesh
# Processing Jobat Madhya Pradesh
# Processing Ashoknagar Madhya Pradesh
# Processing Chanderi Madhya Pradesh
# Processing Isagarh Madhya Pradesh
# Processing Mungawali Madhya Pradesh
# Processing Khetia Madhya Pradesh
# Processing Sendhwa Madhya Pradesh
# Processing Berasia Madhya Pradesh
# Processing Bhopal Madhya Pradesh
# Processing LavKush Nagar(Laundi) Madhya Pradesh
# Processing Hata Madhya Pradesh
# Processing Javera Madhya Pradesh
# Processing Bhander Madhya Pradesh
# Processing Dewas Madhya Pradesh
# Processing Haatpipliya Madhya Pradesh
# Processing Khategaon Madhya Pradesh
# Processing Loharda Madhya Pradesh
# Processing Sonkatch Madhya Pradesh
# Processing Badnawar Madhya Pradesh
# Processing Dhamnod Madhya Pradesh
# Processing Dhar Madhya Pradesh
# Processing Manawar Madhya Pradesh
# Processing Aron Madhya Pradesh
# Processing Binaganj Madhya Pradesh
# Processing Guna Madhya Pradesh
# Processing Kumbhraj Madhya Pradesh
# Processing Maksudangarh Madhya Pradesh
# Processing Dabra Madhya Pradesh
# Processing Sirali Madhya Pradesh
# Processing Timarni Madhya Pradesh
# Processing Banapura Madhya Pradesh
# Processing Semriharchand Madhya Pradesh
# Processing Sehora Madhya Pradesh
# Processing Shahpura Bhitoni (F&V) Madhya Pradesh
# Processing Jhabua Madhya Pradesh
# Processing Mundi Madhya Pradesh
# Processing Pandhana Madhya Pradesh
# Processing Karhi Madhya Pradesh
# Processing Segaon Madhya Pradesh
# Processing Daloda Madhya Pradesh
# Processing Piplya Madhya Pradesh
# Processing Shamgarh Madhya Pradesh
# Processing Sitmau Madhya Pradesh
# Processing Tendukheda Madhya Pradesh
# Processing Panna Madhya Pradesh
# Processing Begamganj Madhya Pradesh
# Processing Gairatganj Madhya Pradesh
# Processing Obedullaganj Madhya Pradesh
# Processing Raisen Madhya Pradesh
# Processing Silvani Madhya Pradesh
# Processing Biaora Madhya Pradesh
# Processing Jeerapur Madhya Pradesh
# Processing Khilchipur Madhya Pradesh
# Processing Kurawar Madhya Pradesh
# Processing Narsinghgarh Madhya Pradesh
# Processing Pachaur Madhya Pradesh
# Processing Sarangpur Madhya Pradesh
# Processing Jaora Madhya Pradesh
# Processing Ratlam Madhya Pradesh
# Processing Sailana Madhya Pradesh
# Processing Sailana(F&V) Madhya Pradesh
# Processing Bamora Madhya Pradesh
# Processing Banda Madhya Pradesh
# Processing Bina Madhya Pradesh
# Processing Deori Madhya Pradesh
# Processing Khurai Madhya Pradesh
# Processing Rahatgarh Madhya Pradesh
# Processing Rehli Madhya Pradesh
# Processing Ashta Madhya Pradesh
# Processing Ichhawar Madhya Pradesh
# Processing Ichhawar(F&V) Madhya Pradesh
# Processing Jawar Madhya Pradesh
# Processing Rehati Madhya Pradesh
# Processing Kalapipal Madhya Pradesh
# Processing Nalkehda Madhya Pradesh
# Processing Shajapur Madhya Pradesh
# Processing Shujalpur Madhya Pradesh
# Processing Susner Madhya Pradesh
# Processing Sheopurbadod Madhya Pradesh
# Processing Badarwas Madhya Pradesh
# Processing Barad Madhya Pradesh
# Processing Khatora Madhya Pradesh
# Processing Pohari Madhya Pradesh
# Processing Rannod Madhya Pradesh
# Processing Shivpuri Madhya Pradesh
# Processing Badnagar Madhya Pradesh
# Processing Mahidpur Madhya Pradesh
# Processing Tarana Madhya Pradesh
# Processing Ujjain Madhya Pradesh
# Processing Ganjbasoda Madhya Pradesh
# Processing Kurwai Madhya Pradesh
# Processing Lateri Madhya Pradesh
# Processing Shamshabad Madhya Pradesh
# Processing Sironj Madhya Pradesh
# Processing Om Chaitanya Multistate Agro Purpose CoOp Society Maharashtra
# Processing Shrirampur Maharashtra
# Processing Nandura Maharashtra
# Processing Bhadrawati Maharashtra
# Processing Varora Maharashtra
# Processing Sillod Maharashtra
# Processing Paranda Maharashtra
# Processing Tuljapur Maharashtra
# Processing Dondaicha Maharashtra
# Processing Hingoli Maharashtra
# Processing Partur Maharashtra
# Processing Aurad Shahajani Maharashtra
# Processing Ausa Maharashtra
# Processing Latur(Murud) Maharashtra
# Processing Shahada Maharashtra
# Processing Pathari Maharashtra
# Processing Tasgaon Maharashtra
# Processing Umarked(Danki) Maharashtra
# Processing Umarkhed Maharashtra
# Processing Anta Rajasthan
# Processing Atru Rajasthan
# Processing Kawai Salpura (Atru) Rajasthan
# Processing Samraniyan Rajasthan
# Processing Pugal Road (Grain) Rajasthan
# Processing Bhawani Mandi Rajasthan
# Processing Iklera Rajasthan
# Processing Khanpur Rajasthan
# Processing Bhagat Ki Kothi Rajasthan
# Processing Itawa Rajasthan
# Processing Ramganjmandi Rajasthan
# Processing Degana Rajasthan
# Processing Merta City Rajasthan
# Processing Rani Rajasthan
# Processing Sumerpur Rajasthan
# Processing Malpura(Todaraisingh) Rajasthan
# Processing Uniyara Rajasthan
# Processing Samalkha Haryana
# Processing Dumal Odisha
# Processing Tamluk (Medinipur E) West Bengal
# Processing Banglagarh Assam
# Processing Balajan Tiniali Assam
# Processing Damnagar Gujarat
# Processing Anand(Veg,Yard,Anand) Gujarat
# Processing Ankleshwar Gujarat
# Processing Dahod(Veg. Market) Gujarat
# Processing Mansa(Manas Veg Yard) Gujarat
# Processing Talalagir Gujarat
# Processing Kapadvanj Gujarat
# Processing Bilimora Gujarat
# Processing Vansda Gujarat
# Processing Rajkot(Veg.Sub Yard) Gujarat
# Processing Bardoli(Katod) Gujarat
# Processing Mahuva(Anaval) Gujarat
# Processing Songadh Gujarat
# Processing Songadh(Badarpada) Gujarat
# Processing Songadh(Umrada) Gujarat
# Processing Vyara(Paati) Gujarat
# Processing Padra Gujarat
# Processing Mohindergarh Haryana
# Processing Nuh Haryana
# Processing Radaur Haryana
# Processing Madikai VFPCK Kerala
# Processing Pullur Periya VFPCK Kerala
# Processing Thrikkodithanam VFPCK Kerala
# Processing Kunnamangalam VFPCK Kerala
# Processing Mavoor VFPCK Kerala
# Processing Vengeri(Kozhikode) Kerala
# Processing Vithinasserri VFPCK Kerala
# Processing Ranniangadi Kerala
# Processing Kattakada Kerala
# Processing Badwani(F&V) Madhya Pradesh
# Processing Sendhwa(F&V) Madhya Pradesh
# Processing Chattarpur(F&V) Madhya Pradesh
# Processing Dhamnod(F&V) Madhya Pradesh
# Processing Itarsi(F&V) Madhya Pradesh
# Processing Pipariya(F&V) Madhya Pradesh
# Processing Mhow(F&V) Madhya Pradesh
# Processing Petlawad(F&V) Madhya Pradesh
# Processing Sarangpur(F&V) Madhya Pradesh
# Processing Jawra(F&V) Madhya Pradesh
# Processing Sehore(F&V) Madhya Pradesh
# Processing Dharashiv Maharashtra
# Processing Kamthi Maharashtra
# Processing Chandvad Maharashtra
# Processing Khed(Chakan) Maharashtra
# Processing Vita Maharashtra
# Processing Patan Maharashtra
# Processing Mangal Wedha Maharashtra
# Processing Shahapur Maharashtra
# Processing Nongstoin Meghalaya
# Processing Shahdara NCT of Delhi
# Processing Bargarh Odisha
# Processing Sohela Odisha
# Processing Khunthabandha Odisha
# Processing Kamakhyanagar Odisha
# Processing Parlakhemundi Odisha
# Processing Gopa Odisha
# Processing Keonjhar Odisha
# Processing Baripada Odisha
# Processing Karanjia Odisha
# Processing Udala Odisha
# Processing Bahadajholla Odisha
# Processing Sarankul Odisha
# Processing Khariar Odisha
# Processing Khariar Road Odisha
# Processing Panposh Odisha
# Processing Rayya Punjab
# Processing F.G.Churian Punjab
# Processing Hoshiarpur(Sham Churasi) Punjab
# Processing Chengalpet(Uzhavar Sandhai ) Tamil Nadu
# Processing Medavakkam(Uzhavar Sandhai ) Tamil Nadu
# Processing Thirumangalam(Uzhavar Sandhai ) Tamil Nadu
# Processing Kandiyaperi(Uzhavar Sandhai ) Tamil Nadu
# Processing Kalwakurthy Telangana
# Processing Vantamamidi Telangana
# Processing Venkateswarnagar Telangana
# Processing Kulai Tripura
# Processing Masli Tripura
# Processing Garjee Tripura
# Processing Nutanbazar Tripura
# Processing Kalyanpur Tripura
# Processing Bishalgarh Tripura
# Processing Bishramganj Tripura
# Processing Barpathari Tripura
# Processing Santir Bazar Tripura
# Processing Pabiacherra Tripura
# Processing Kamalghat Tripura
# Processing Mohanpur Tripura
# Processing Bijnaur Uttar Pradesh
# Processing Ahirora Uttar Pradesh
# Processing Dinhata West Bengal
# Processing Champadanga West Bengal
# Processing Kalipur West Bengal
# Processing Pandua West Bengal
# Processing Sheoraphuly West Bengal
# Processing Sealdah Koley Market West Bengal
# Processing Ghatal West Bengal
# Processing Nadia West Bengal
# Processing Balarampur West Bengal
# Processing Kasipur West Bengal
# Processing Chapar Assam
# Processing Chikli(Khorgam) Gujarat
# Processing Sohna Haryana
# Processing Pazhayarikandam VFPCK Kerala
# Processing Rajakkad VFPCK Kerala
# Processing Elevancheri VFPCK Kerala
# Processing Thondernad VFPCK Kerala
# Processing Manawar(F&V) Madhya Pradesh
# Processing Timarni(F&V) Madhya Pradesh
# Processing Islampur Maharashtra
# Processing Keshopur NCT of Delhi
# Processing Kendrapara Odisha
# Processing Kendrapara(Marshaghai) Odisha
# Processing Pattamundai Odisha
# Processing Balugaon Odisha
# Processing Saraskana Odisha
# Processing Gunpur Odisha
# Processing Muktsar Punjab
# Processing Gandacharra Tripura
# Processing Teliamura Tripura
# Processing Dasda Tripura
# Processing Masmara Tripura
# Processing Champaknagar Tripura
# Processing Manglaur Uttrakhand
# Processing Alipurduar West Bengal
# Processing Falakata West Bengal
# Processing Mekhliganj West Bengal
# Processing Balurghat West Bengal
# Processing Gangarampur(Dakshin Dinajpur) West Bengal
# Processing Egra/contai West Bengal
# Processing Medinipur(West) West Bengal
# Processing Barasat West Bengal
# Processing Habra West Bengal
# Processing Memari West Bengal
# Processing Baruipur(Canning) West Bengal
# Processing Badamalhera Madhya Pradesh
# Processing Kille Dharur Maharashtra
# Processing Kollapur Telangana
# Processing Somvarpet Karnataka
# Processing Jorhat Assam
# Processing Dhekiajuli Assam
# Processing Nadiyad(Chaklasi) Gujarat
# Processing Shahzadpur Haryana
# Processing Siwan Haryana
# Processing FerozpurZirkha(Nagina) Haryana
# Processing Hassanpur Haryana
# Processing Barwala Haryana
# Processing Raipur Rai Haryana
# Processing Chhachrauli Haryana
# Processing Mustafabad Haryana
# Processing Vallikunnam VFPCK Kerala
# Processing Kannamangalam VFPCK Kerala
# Processing Sirali(F&V) Madhya Pradesh
# Processing Khurai(F&V) Madhya Pradesh
# Processing Pen Maharashtra
# Processing Vai Maharashtra
# Processing Mehta Punjab
# Processing Bilga Punjab
# Processing Phillaur(Apra Mandi) Punjab
# Processing Kurali Punjab
# Processing Lalru Punjab
# Processing Sunam Punjab
# Processing Kariyapatti(Uzhavar Sandhai ) Tamil Nadu
# Processing Kadamtala Tripura
# Processing Panisagar Tripura
# Processing Atrauli Uttar Pradesh
# Processing Bilsi Uttar Pradesh
# Processing Anwala Uttar Pradesh
# Processing Najibabad Uttar Pradesh
# Processing Anoop Shahar Uttar Pradesh
# Processing Gulavati Uttar Pradesh
# Processing Sikarpur Uttar Pradesh
# Processing Awagarh Uttar Pradesh
# Processing Ajuha Uttar Pradesh
# Processing Tanda(Rampur) Uttar Pradesh
# Processing Chutmalpur Uttar Pradesh
# Processing Jalalabad Uttar Pradesh
# Processing Kairana Uttar Pradesh
# Processing Jaspur(UC) Uttrakhand
# Processing Bishnupur(Bankura) West Bengal
# Processing Khatra West Bengal
# Processing Palamaner Andhra Pradesh
# Processing Vadakarapathy VFPCK Kerala
# Processing Sabalgarh(F&V) Madhya Pradesh
# Processing Chandrapur(Ganjwad) Maharashtra
# Processing Palus Maharashtra
# Processing Phaltan Maharashtra
# Processing Jaleswar Odisha
# Processing Bargarh(Barapalli) Odisha
# Processing Padampur Odisha
# Processing Kasinagar Odisha
# Processing Digapahandi Odisha
# Processing Rahama Odisha
# Processing Betnoti Odisha
# Processing Nimapara Odisha
# Processing Rayagada Odisha
# Processing Sargipali Odisha
# Processing Khamano Punjab
# Processing Batala Punjab
# Processing Kalanaur Punjab
# Processing Lohian Khas Punjab
# Processing Mehatpur Punjab
# Processing Bhulath Punjab
# Processing Bhulath (Nadala) Punjab
# Processing Doraha Punjab
# Processing Kot ise Khan Punjab
# Processing Malout Punjab
# Processing Tarantaran Punjab
# Processing Mahabubnagar(Rythu Bazar) Telangana
# Processing Chevella Telangana
# Processing Ibrahimputnam Telangana
# Processing Muradnagar Uttar Pradesh
# Processing Kotadwara Uttrakhand
# Processing Bankura Sadar West Bengal
# ...
# Processing Kaij Maharashtra
# Processing Bareta Punjab
# Processing Peddapuram Andhra Pradesh
# Processing Devakottai Tamil Nadu
# Processing Sontoli Assam
# Processing Hansi(Sisai) Haryana
# Processing Bapauli Haryana
# Processing Palladam Tamil Nadu
# Processing Pernamallur Tamil Nadu
# Processing Kalamnuri Maharashtra
# Processing Bavla Gujarat
# Processing Redhills Tamil Nadu
# Processing Rasipuram Tamil Nadu
# Processing Bilha Chattisgarh
# Processing Oddunchairum Tamil Nadu
# Processing Una Gujarat
# Processing Bajju Rajasthan
# Processing Sembanarkoil Tamil Nadu
# Processing Kamuthi Tamil Nadu
# Processing Budalur Tamil Nadu
# Processing Basmat Maharashtra
# Processing Mantha Maharashtra
# Processing Navapur Maharashtra
# Processing Challakere Karnataka
# Processing Anjad(F&V) Madhya Pradesh
# Processing Rona Karnataka
# Processing Santoshgarah Himachal Pradesh
# Processing Sindagi(Indi) Karnataka
# Processing Bidar Karnataka
# Processing Parkal Telangana
# Processing Mudkhed Maharashtra
# Processing Saidpurhat Bihar
# Processing Sattupalli Telangana
# Processing Jangipura Uttar Pradesh
# Processing Siddapur Karnataka
# Processing Hosanagar Karnataka
# Processing Tumkur Karnataka
# Processing Sedam Karnataka
# Processing Jaipur (Grain) Rajasthan
# Processing Annigeri Karnataka
# Processing Sakaleshpura Karnataka
# Processing Kanakapura Karnataka
# Processing Shantilal Jain Agro Maharashtra
# Processing Nippani Karnataka
# Processing Byadagi Karnataka
# Processing Mailaduthurai Tamil Nadu
# Processing Sathur Tamil Nadu
# Processing Bangalore Karnataka
# Processing Bellary Karnataka
# Processing Sindagi Karnataka
# Processing Melur Tamil Nadu
# Processing Idar(Jadar) Gujarat
# Processing Srirangapattana Karnataka
# Processing Kudavasal Tamil Nadu
# Processing Ahmedpur Maharashtra
# Processing Nagarkurnool Telangana
# Processing Pattikonda Andhra Pradesh
# Processing Sanawad(F&V) Madhya Pradesh
# Processing Samrala Punjab
# Processing Lakhtar Gujarat
# Processing Enkoor Telangana
# Processing Belur Karnataka
# Processing Gopalavaram Andhra Pradesh
# Processing H.B. Halli Karnataka
# Processing Bijolia Rajasthan
# Processing Gangapur Rajasthan
# Processing Malavalli Karnataka
# Processing Khanapur Telangana
# Processing Panchpedwa Uttar Pradesh
# Processing Karimnagar(Rythu Bazar) Telangana
# Processing Kalol(Veg,Market,Kalol) Gujarat
# Processing Phillaur Punjab
# Processing Jasdan(Vichhiya) Gujarat
# Processing Boath Telangana
# Processing Kalol Gujarat
# Processing Mhalingapur Karnataka
# Processing Thalaivasal Tamil Nadu
# Processing Jaitipir Mandi, Lalganj block Bihar
# Processing Kodakkad VFPCK Kerala
# Processing Tarikere Karnataka
# Processing Gopalpatti Tamil Nadu
# Processing Arcot Tamil Nadu
# Processing Meghraj Gujarat
# Processing Laxmeshwar Karnataka
# Processing Sirkali Tamil Nadu
# Processing Karamadai Tamil Nadu
# Processing Garobadha Meghalaya
# Processing Patna (Musallahpur) Bihar
# Processing Puttur Karnataka
# Processing Sonkachh(F&V) Madhya Pradesh
# Processing Mandya Karnataka
# Processing Vikarabad Telangana
# Processing Akot Maharashtra
# Processing Junnar(Bhlhe) Maharashtra
# Processing Makthal Telangana
# Processing Bayad(Sadamba) Gujarat
# Processing Meghraj(Radlavada) Gujarat
# Processing Nawanshahar Punjab
# Processing Jalukie Nagaland
# Processing Sambalpur (Bemetra) Chattisgarh
# Processing Kollegal Karnataka
# Processing Vadamadurai Tamil Nadu
# Processing Nargunda Karnataka
# Processing Rongram Meghalaya
# Processing Kovilpatti Tamil Nadu
# Processing Motala Maharashtra
# Processing Andimadom Tamil Nadu
# Processing Chengam Tamil Nadu
# Processing KKNagar(Uzhavar Sandhai ) Tamil Nadu
# Processing Arur Tamil Nadu
# Processing Doddaballa Pur Karnataka
# Processing Kharora Chattisgarh
# Processing Pudukottai Tamil Nadu
# Processing Mawana Uttar Pradesh
# Processing Ranebennur Karnataka
# Processing ETTUMANOOR VFPCK Kerala
# Processing KURICHY VFPCK Kerala
# Processing KOTTAYI VFPCK Kerala
# Processing Kamuthi(Uzhavar Sandhai ) Tamil Nadu
# Processing KULATHOOPUZHA VFPCK Kerala
# Processing KODASSERY VFPCK Kerala
# Processing PAPPANCHANI VFPCK Kerala
# Processing Bandrol Himachal Pradesh
# Processing Kullu(Chauri Bihal) Himachal Pradesh
# Processing Kullu(Patli Kuhal) Himachal Pradesh
# Processing Shimla and Kinnaur(Nerwa) Himachal Pradesh
# Processing Kanispora Baramulla (F&V) Jammu and Kashmir
# Processing Nowpora Jammu and Kashmir
# Processing Shopian Jammu and Kashmir
# Processing Indore(F&V) Madhya Pradesh
# Processing Sagar(F&V) Madhya Pradesh
# Processing Satna(F&V) Madhya Pradesh
# Processing Belthangdi Karnataka
# Processing MS Kalpana Agri Commodities Marketing Maharashtra
# Processing Srinivasapur Karnataka
# Processing PATTAZHY NORTH VFPCK Kerala
# Processing CHELAKKARA VFPCK Kerala
# Processing Lakhani Gujarat
# Processing THAMARAKKULAM VFPCK Kerala
# Processing KARUMALOOR VFPCK Kerala
# Processing KURUMASSERY VFPCK Kerala
# Processing POTHANIKKADU VFPCK Kerala
# Processing THURAVOOR VFPCK Kerala
# Processing ERRATTAYAR VFPCK Kerala
# Processing KANNAKUNNU VFPCK Kerala
# Processing PARATHODE VFPCK Kerala
# Processing KOLAYAD VFPCK Kerala
# Processing MANGATTIDOM VFPCK Kerala
# Processing PAYAM VFPCK Kerala
# Processing SREEKANDAPURAM VFPCK Kerala
# Processing EDAMON VFPCK Kerala
# Processing INCHAKKAD VFPCK Kerala
# Processing PIRAVANTHOOR VFPCK Kerala
# Processing PLAPPALLY VFPCK Kerala
# Processing PUTHUR VFPCK Kerala
# Processing THALAVOOR VFPCK Kerala
# Processing AYMANAM VFPCK Kerala
# Processing BHARANANGANAM Kerala
# Processing KS MANGALAM VFPCK Kerala
# Processing RAMAPURAM VFPCK Kerala
# Processing VAKATHANAM VFPCK Kerala
# Processing KAKKUR VFPCK Kerala
# Processing KODIYATHUR VFPCK Kerala
# Processing THALAKULATHUR VFPCK Kerala
# Processing THIRUVAMBADY VFPCK Kerala
# Processing ANGADIPPURAM VFPCK Kerala
# Processing ATHANIKKAL VFPCK Kerala
# Processing ELAMKULAM VFPCK Kerala
# Processing KALIKAVU VFPCK Kerala
# Processing KOORAD WANDOOR VFPCK Kerala
# Processing MANKADA VFPCK Kerala
# Processing PALLIKKAL VFPCK Kerala
# Processing VAZHAYUR VFPCK Kerala
# Processing AGALI VFPCK Kerala
# Processing KARIMPUZHA VFPCK Kerala
# Processing CHITTAR VFPCK Kerala
# Processing ENADIMANGALAM VFPCK Kerala
# Processing EZHAMKULAM VFPCK Kerala
# Processing KODUMON VFPCK Kerala
# Processing NEDUMBRAM VFPCK Kerala
# Processing PANDALAM VFPCK Kerala
# Processing RANNI VFPCK Kerala
# Processing CHAZHUR VFPCK Kerala
# Processing KADUKUTTY VFPCK Kerala
# Processing KARALAM VFPCK Kerala
# Processing MALA VFPCK Kerala
# Processing MELOCR VFPCK Kerala
# Processing PANANCHERY VFPCK Kerala
# Processing THOTTIPPAL VFPCK Kerala
# Processing ARYANAD VFPCK Kerala
# Processing KILMANNUR VFPCK Kerala
# Processing MUDAKKAL VFPCK Kerala
# Processing VELLANAD VFPCK Kerala
# Processing VEMBAYAM VFPCK Kerala
# Processing CHEERAL VFPCK Kerala
# Processing MUTTIL VFPCK Kerala
# Processing PERIA VFPCK Kerala
# Processing POOTHADI VFPCK Kerala
# Processing THAVINJAL VFPCK Kerala
# Processing Bhopal(F&V) Madhya Pradesh
# Processing Tuensang Nagaland
# Processing EDATHWA VFPCK Kerala
# Processing CHANNAPETTA VFPCK Kerala
# Processing CHATHANNOORE VFPCK Kerala
# Processing KAITHEPALAM VFPCK Kerala
# Processing PARATHODE VFPCK Kerala
# Processing Gulabpura Rajasthan
# Processing KOLLENGODE VFPCK Kerala
# Processing PERUMATTY VFPCK Kerala
# Processing Dewas(F&V) Madhya Pradesh
# Processing Lashkar(F&V) Madhya Pradesh
# Processing Badwah(F&V) Madhya Pradesh
# Processing Khandwa(F&V) Madhya Pradesh
# Processing Banki Odisha
# Processing NEEZHOOR VFPCK Kerala
# Processing Akkalkot Maharashtra
# Processing CHENNITHALA VFPCK Kerala
# Processing Shimla and Kinnaur(Theog) Himachal Pradesh
# Processing Adilabad(Rythu Bazar) Telangana
# Processing Waknaghat Himachal Pradesh
# Processing Kesamudram Telangana
# Processing MOOCHAMKUNDU VFPCK Kerala
# Processing THENGAMAM VFPCK Kerala
# Processing VELOORKKARA VFPCK Kerala
# Processing Jabalpur(F&V) Madhya Pradesh
# Processing Dablirathan Rajasthan
# Processing Jamanian Uttar Pradesh
# Processing Rura Uttar Pradesh
# Processing Nalkheda(F&V) Madhya Pradesh
# Processing Sojat City Rajasthan
# Processing Jalandhar City Punjab
# Processing Jalandhar City(Kartar Pur Dana mandi) Punjab
# Processing Badnawar(F&V) Madhya Pradesh
# Processing Sakri Maharashtra
# Processing Dindori Maharashtra
# Processing Obedullaganj(F&V) Madhya Pradesh
# Processing Kedar Chattisgarh
# Processing Avalpoonthurai Tamil Nadu
# Processing Chinnoar Telangana
# Processing Mancharial Telangana
# Processing Solan(Parwanoo) Himachal Pradesh
# Processing Indapur(Bhigwan) Maharashtra
# Processing THARIYODE VFPCK Kerala
# Processing VENGAPALLY VFPCK Kerala
# Processing Shikohabad Uttar Pradesh
# Processing NOORANAD VFPCK Kerala
# Processing Nakodar(Sarih) Punjab
# Processing Choutuppal Telangana
# Processing Ganderbal Jammu and Kashmir
# Processing KANJOOR VFPCK Kerala
# Processing MELECHINNAR VFPCK Kerala
# Processing KELAKAM VFPCK Kerala
# Processing PERAVOOR VFPCK Kerala
# Processing KODENCHERY VFPCK Kerala
# Processing KOODARANJI VFPCK Kerala
# Processing Jhijhank Uttar Pradesh
# Processing KANTHALOOR VFPCK Kerala
# Processing Dharampur Himachal Pradesh
# Processing Chail Chowk Himachal Pradesh
# Processing Virudhunagar Tamil Nadu
# Processing ATHIRAMPUZHA VFPCK Kerala
# Processing Sikri Rajasthan
# Processing Khatauli Rajasthan
# Processing Natham Tamil Nadu
# Processing Perfect Krishi Market Yard Pvt Ltd Maharashtra
# Processing Yusufpur Uttar Pradesh
# Processing Baberu Uttar Pradesh
# Processing Bolangir Odisha
# Processing Tusura Odisha
# Processing Amloh Punjab
# Processing Madagadipet Pondicherry
# Processing Nongpoh (R-Bhoi) Meghalaya
# Processing Sidhwan Bet Punjab
# Processing Matar(Limbasi) Gujarat
# Processing Dharamkot Punjab
# Processing Ambur Tamil Nadu
# Processing Prantij Gujarat
# Processing Neem Ka Thana Rajasthan
# Processing Kalburgi (Jevargi) Karnataka
# Processing Annur Tamil Nadu
# Processing Pulwama (F&V) Jammu and Kashmir
# Processing Gudiyatham Tamil Nadu
# Processing Botad(Bhabarkot) Gujarat
# Processing Bori Maharashtra
# Processing MYLACHAL VFPCK Kerala
# Processing Aashta(F&V) Madhya Pradesh
# Processing Salihabhata Chattisgarh
# Processing Wanaparthy Road(Prbbair) Telangana
# Processing Chakia Bihar
# Processing Phingeshwer Chattisgarh
# Processing Kianthukadavu Tamil Nadu
# Processing Shahkot Punjab
# Processing Pavagada Karnataka
# Processing Sitamau(F&V) Madhya Pradesh
# Processing Sampara Andhra Pradesh
# Processing Jetpur-Pavi Gujarat
# Processing Nelakondapally Telangana
# Processing Paderu Andhra Pradesh
# Processing Shri Gajanan Maharaj Khajagi Krushi Utpanna Bazar Maharashtra
# Processing Kuber Telangana
# Processing Jaggayyapeta Andhra Pradesh
# Processing Prattipadu Andhra Pradesh
# Processing Koregaon Maharashtra
# Processing Kalsi Tripura
# Processing Tuni Andhra Pradesh
# Processing Achampet(Amrabad) Telangana
# Processing Nagarkurnool(Talkapalli) Telangana
# Processing Karapa Andhra Pradesh
# Processing Uchhal Gujarat
# Processing Cumbum Tamil Nadu
# Processing Premium Krushi Utpanna Bazar Maharashtra
# Processing Miryalaguda Telangana
# Processing Nira(Saswad) Maharashtra
# Processing Bareli(F&V) Madhya Pradesh
# Processing Ghansawangi Maharashtra
# Processing Palari(F&V) Madhya Pradesh
# Processing Chandrapur Chattisgarh
# Processing Kotmi Chattisgarh
# Processing Namhol(Bilaspur) Himachal Pradesh
# Processing Nissing Haryana
# Processing Jaitu Punjab
# Processing Magroni(F&V) Madhya Pradesh
# Processing Janata Agri Market (DLS Agro Infrastructure Pvt Lt Maharashtra
# Processing Kakni Chattisgarh
# Processing Raghunathpur Chattisgarh
# Processing Udaypur Chattisgarh
# Processing Gangapurcity(Old Lal mandi) Rajasthan
# Processing Raver(Sauda) Maharashtra
# Processing Kolaras(F&V) Madhya Pradesh
# Processing Sangrampur(Varvatbakal) Maharashtra
# Processing Tadikonda Andhra Pradesh
# Processing Athani Karnataka
# Processing Nira Maharashtra
# Processing Pulivendala Andhra Pradesh
# Processing Vallam Tamil Nadu
# Processing Gangavathi(Karatagi) Karnataka
# Processing Neora Chattisgarh
# Processing Kolhapur(Malkapur) Maharashtra
# Processing Bhaga Assam
# Processing Ipur Andhra Pradesh
# Processing Ampati Meghalaya
# Processing Tenakallu Andhra Pradesh
# Processing Proddatur Andhra Pradesh
# Processing Rajampet Andhra Pradesh
# Processing Dharmavaram Andhra Pradesh
# Processing Pochampalli Tamil Nadu
# Processing Karaikudi Tamil Nadu
# Processing Piler Andhra Pradesh
# Processing Nigdu Haryana
# Processing Gopalraopet Telangana
# Processing Jalna(Badnapur) Maharashtra
# Processing Parala Himachal Pradesh
# Processing Vitthal Krushi Utpanna Bazar Maharashtra
# Processing Chanarthal Punjab
# Processing Puttur Andhra Pradesh
# Processing Khedbrahma(Lambadia) Gujarat
# Processing Rajdhanai Mandi (KukarKheda) Rajasthan
# Processing Parikshitgarh Uttar Pradesh
# Processing kum Kalan Punjab
# Processing Sidhwan Bet (Lodhiwala) Punjab
# Processing Moodigere Karnataka
# Processing Jalgaon(Jamod) Maharashtra
# Processing Dharwar Karnataka
# Processing KALLUVATHUKKAL VFPCK Kerala
# Processing Bargur Tamil Nadu
# Processing Hosur Tamil Nadu
# Processing Krishnagiri Tamil Nadu
# Processing Bhawanipur Bihar
# Processing KERALAPURAM VFPCK Kerala
# Processing Palakode Tamil Nadu
# Processing Amloh(Gobind Garh Mandi) Punjab
# Processing Attari Punjab
# Processing Rajpipla(Garudeshwal) Gujarat
# Processing Dharampuri Tamil Nadu
# Processing Khedbrahma(Posina) Gujarat
# Processing Eathamozhi Tamil Nadu
# Processing Tiruthuraipoondi Tamil Nadu
# Processing Dhilwan Punjab
# Processing Surjyagarha Bihar
# Processing Thasara Gujarat
# Processing Thasara(Dokar) Gujarat
# Processing Pathriya Chattisgarh
# Processing Ambagarh Chowki Chattisgarh
# Processing Mankamneshwar Farmar Producer CoLtd Sanchalit Mank Maharashtra
# Processing Ibrahimpatnam Telangana
# Processing Dharsul Haryana
# Processing Kunjpura Haryana
# Processing Nilokheri Haryana
# Processing Kalawali(Odhan) Haryana
# Processing Sirsa(Malekan) Haryana
# Processing Bilaspur Haryana
# Processing Bhadaur Punjab
# Processing Bhadaur(Sehna) Punjab
# Processing Dhanaula Punjab
# Processing Dhanula (Kaleke) Punjab
# Processing Mehal Kalan Punjab
# Processing Mehal Kallan (ChananWal) Punjab
# Processing Jaitu(Bajakhana) Punjab
# Processing Sadiq Punjab
# Processing Talwandi Bhai Punjab
# Processing Jalandhar Cantt (Jamshedpur Dana Mandi) Punjab
# Processing Jalandhar City(Faintan Ganj) Punjab
# Processing Ludhiana(Salem Tabri) Punjab
# Processing Bhikhi Punjab
# Processing Malout (Kilianwali) Punjab
# Processing Malout (Panniwala) Punjab
# Processing Nawan Shahar(MandiRaho) Punjab
# Processing Patran(Ghagga Mandi) Punjab
# Processing Amargarh Punjab
# Processing Talwandi Bhai(Mudki) Punjab
# Processing Bilga (Talwan ) Punjab
# Processing Jalandhar Cantt. Punjab
# Processing Ludhiana(Mandi gill Road) Punjab
# Processing Ahemadpur Punjab
# Processing Budhlada (Phaphre Bhaike) Punjab
# Processing Sulargharat Punjab
# Processing Dondaicha(Sindhkheda) Maharashtra
# Processing Monday Market Tamil Nadu
# Processing Kodakandal Telangana
# Processing Dharmapuri Telangana
# Processing Bhikhiwind(Khalra) Punjab
# Processing Nawan Shahar(Mandi Jadla) Punjab
# Processing Kada(Ashti) Maharashtra
# Processing Kosamba Gujarat
# Processing Chhachhrauli(Khizrabad) Haryana
# Processing Rayya(Sathiala) Punjab
# Processing Devri(F&V) Madhya Pradesh
# Processing Kankwal Chahlan Punjab
# Processing Bhikhiwind (Basarke) Punjab
# Processing Shivpuri(F&V) Madhya Pradesh
# Processing Naneola Haryana
# Processing Jundla Haryana
# Processing lakhowal Punjab
# Processing Kuttulam Tamil Nadu
# Processing Pongalur Tamil Nadu
# Processing Maudaha Uttar Pradesh
# Processing Baloda(Janjgir Campus) Chattisgarh
# Processing Panipat(Baharpur) Haryana
# Processing Raikot Punjab
# Processing Bhadson Punjab
# Processing Bhikhiwind (Algo) Punjab
# Processing Bhikhiwind (Marrimegha) Punjab
# Processing Bhikhiwind (Sursingh) Punjab
# Processing Mullanpur Punjab
# Processing Mullanpur Dakha (Sawadi) Punjab
# Processing Nurpurbet Punjab
# Processing Purain Punjab
# Processing Rania(Jiwan nagar) Haryana
# Processing Khem karan Punjab
# Processing Khemkaran (Amarkot) Punjab
# Processing Maloud Punjab
# Processing Bardoli(Madhi) Gujarat
# Processing Malaoud (Siar) Punjab
# Processing Venkateswarnagar(Chintapalli) Telangana
# Processing Akkalkuwa Maharashtra
# Processing Velur Tamil Nadu
# Processing CHUNGATHARA VFPCK Kerala
# Processing K.Mandvi Gujarat
# Processing Bangarupalem Andhra Pradesh
# Processing Bhivandi Maharashtra
# Processing Thellar Tamil Nadu
# Processing Mahavir Agri Market Maharashtra
# Processing Theni Tamil Nadu
# Processing Risgaon Chattisgarh
# Processing Pennagaram Tamil Nadu
# Enriched file saved to mandies_20250907.jsonl

# %%
# !cat mandies.jsonl

# %%
output_file = "mandies.jsonl"
locations = load_locations_from_jsonl(output_file)
for loc in locations:
    try:
        if loc['country_code'] != 'IN':
            print(loc)
    except Exception as e:
        print(loc)
