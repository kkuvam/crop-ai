# %%
import os
from glob import glob
import pandas as pd
import gzip
import zipfile
from IPython.display import display, HTML

# %%
def show_scrollable_df(df: pd.DataFrame, height: int = 400, width: int = 1000):
    display(HTML(
        df.to_html(notebook=True)
        .replace('<table border="1" class="dataframe">', 
                 f'<div style="height:{height}px; width:{width}px; overflow:auto; border:1px solid lightgray;"><table border="1" class="dataframe">')
        .replace('</table>', '</table></div>')
    ))

# %%
def list_zip_files(root_folder: str) -> list[str]:
    """
    Recursively list all .zip/.ZIP files under root_folder (year/month subfolders supported).
    """
    zips = []
    for dirpath, _, filenames in os.walk(os.path.expanduser(root_folder)):
        for fn in filenames:
            if fn.lower().endswith(".zip"):
                zips.append(os.path.join(dirpath, fn))
    zips.sort()
    return zips

# %%
def load_jsonl_gz(file_path: str) -> pd.DataFrame:
    try:
        with gzip.open(file_path, "rt", encoding="utf-8") as f:
            df = pd.read_json(f, lines=True)
        return df
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return pd.DataFrame()

# %%
def load_excel_zip(zip_path: str) -> pd.DataFrame:
    try:
        with zipfile.ZipFile(zip_path, "r") as z:
            # Find the BhavCopy file inside
            bhavcopy_file = [f for f in z.namelist() if f.startswith("BhavCopy_NCD_CO") and f.endswith(".xls")]
            if not bhavcopy_file:
                raise FileNotFoundError("No BhavCopy_NCD_CO...xls file found in the zip.")
            
            # Take the first match
            bhavcopy_file = bhavcopy_file[0]
            # print(bhavcopy_file)
            # Open and read directly with pandas
            with z.open(bhavcopy_file) as f:
                df = pd.read_excel(f)
        
        return df
    except Exception as e:
        print(f"Error reading from {zip_path}: {e}")
        return pd.DataFrame()

# %%
STATE_FIXES = {
    "orissa": "odisha",
    "pondicherry": "puducherry",
    "uttrakhand": "uttarakhand",
    "uttaranchal": "uttarakhand",
    "chattisgarh": "chhattisgarh",
    "jammu & kashmir": "jammu and kashmir",
    "delhi nct": "delhi",
    "nct of delhi": "delhi",
    "telengana": "telangana",
    "himanchal pradesh": "himachal pradesh",
    "andaman & nicobar islands": "andaman and nicobar islands",
    "dadra & nagar haveli": "dadra and nagar haveli and daman and diu",
    "daman & diu": "dadra and nagar haveli and daman and diu",
}

# %%
def collect_unique_symbols_from_zips(
    dir_path: str,
    column: str = "TckrSymb",
    normalize=True,
) -> list[str]:
    """
    Scan all .zip files in dir_path, read BhavCopy_NCD_CO... .xls/.xlsx inside,
    and return a sorted list of unique symbols from the given column.
    """
    uniq = set()
    zip_paths = list_zip_files(dir_path)
    for zip_path in zip_paths:
        # print(f"Processing {zip_path} ...")
        df = load_excel_zip(zip_path)
        if column not in df.columns:
            continue
        s = df[column].dropna().astype(str)
        if normalize:
            s = s.str.strip().str.upper()
        uniq.update(s.tolist())

    return sorted(uniq)

# %%
def normalize_state_column(df: pd.DataFrame, col: str, fixes: dict = None) -> None:
    """Normalize a state column in-place: strip, lowercase, unify spaces/& and apply fixes."""
    s = (
        df[col]
        .astype(str)
        .str.strip()
        .str.lower()                              # <- lowercase (the piece you wanted)
        .str.replace("&", " and ", regex=False)   # unify "&" -> "and"
        .str.replace(r"\s+", " ", regex=True)     # collapse multiple spaces
    )
    if fixes:
        s = s.replace(fixes)
    df[col] = s

# %%
enam_file = "../data/enam/2025/Aug/2025-08-01.jsonl.gz"
agmarknet_file = "../data/agmarknet/2025/Aug/2025-08-01.jsonl.gz"
ncdex_file = "../data/ncdex/2025/Aug/2025-08-01.zip"

# %%
df1 = load_jsonl_gz(enam_file)
df2 = load_jsonl_gz(agmarknet_file)
df3 = load_excel_zip(ncdex_file)
col1 = "state"
col2 = "state_name"
normalize_state_column(df1, col1, STATE_FIXES)
normalize_state_column(df2, col2, STATE_FIXES)

# %%
counts1 = df1['state'].value_counts().rename("count_df1")
counts2 = df2['state_name'].value_counts().rename("count_df2")

# Outer join so all states from both appear
result = pd.concat([counts1, counts2], axis=1).fillna(0).astype(int)

# Optional: add difference column
result["diff"] = result["count_df1"] - result["count_df2"]

# %%
result
# Out:
#                    count_df1  count_df2  diff
# haryana                  544        648  -104
# rajasthan                342        556  -214
# uttar pradesh            237       2828 -2591
# odisha                   156        314  -158
# uttarakhand              116        180   -64
# gujarat                  108        944  -836
# maharashtra               87       1258 -1171
# madhya pradesh            85       1502 -1417
# tamil nadu                81       6162 -6081
# himachal pradesh          81        519  -438
# west bengal               64        554  -490
# andhra pradesh            60         66    -6
# chhattisgarh              57         85   -28
# telangana                 34        250  -216
# jammu and kashmir         26        180  -154
# punjab                    14        878  -864
# puducherry                 3          2     1
# karnataka                  1        289  -288
# kerala                     0       1963 -1963
# tripura                    0        232  -232
# assam                      0        116  -116
# delhi                      0        112  -112
# manipur                    0         70   -70
# goa                        0         26   -26
# nagaland                   0         25   -25
# meghalaya                  0         19   -19
# chandigarh                 0         11   -11
# bihar                      0         10   -10

# %%
print(df3.shape)
show_scrollable_df(df3, height=500, width=1200)
# Out:
# (1177, 34)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <div style="height:500px; width:1200px; overflow:auto; border:1px solid lightgray;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>TradDt</th>
#       <th>BizDt</th>
#       <th>Sgmt</th>
#       <th>Src</th>
#       <th>FinInstrmTp</th>
#       <th>FinInstrmId</th>
#       <th>ISIN</th>
#       <th>TckrSymb</th>
#       <th>SctySrs</th>
#       <th>XpryDt</th>
#       <th>FininstrmActlXpryDt</th>
#       <th>StrkPric</th>
#       <th>OptnTp</th>
#       <th>FinInstrmNm</th>
#       <th>OpnPric</th>
#       <th>HghPric</th>
#       <th>LwPric</th>
#       <th>ClsPric</th>
#       <th>LastPric</th>
#       <th>PrvsClsgPric</th>
#       <th>UndrlygPric</th>
#       <th>SttlmPric</th>
#       <th>OpnIntrst</th>
#       <th>ChngInOpnIntrst</th>
#       <th>TtlTradgVol</th>
#       <th>TtlTrfVal</th>
#       <th>TtlNbOfTxsExctd</th>
#       <th>SsnId</th>
#       <th>NewBrdLotQty</th>
#       <th>Rmks</th>
#       <th>Rsvd1</th>
#       <th>Rsvd2</th>
#       <th>Rsvd3</th>
#       <th>Rsvd4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2025-08-01</td>
#       <td>2025-08-01</td>
#       <td>CO</td>
#       <td>NCD</td>
#       <td>COF</td>
#       <td>75678</td>
#       <td>NaN</td>
#       <td>BAJRA</td>
#       <td>NaN</td>
#       <td>2025-08-20</td>
#       <td>2025-08-20</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>BAJRA20AUG2025</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2388.0</td>
#       <td>0.0</td>
#       <td>2398.0</td>
#       <td>2380.00</td>
#       <td>2388.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>F1</td>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2025-08-01</td>
#       <td>2025-08-01</td>
#       <td>CO</td>
#       <td>NCD</td>
#       <td>COF</td>
#       <td>76176</td>
#       <td>NaN</td>
#       <td>BAJRA</td>
#       <td>NaN</td>
#       <td>2025-09-19</td>
#       <td>2025-09-19</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>BAJRA19SEP2025</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2400.0</td>
#       <td>0.0</td>
#       <td>2410.0</td>
#       <td>2380.00</td>
#       <td>2400.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>F1</td>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2025-08-01</td>
#       <td>2025-08-01</td>
#       <td>CO</td>
#       <td>NCD</td>
#       <td>COF</td>
#       <td>76592</td>
#       <td>NaN</td>
#       <td>BAJRA</td>
#       <td>NaN</td>
#       <td>2025-10-20</td>
#       <td>2025-10-20</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>BAJRA20OCT2025</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2412.0</td>
#       <td>0.0</td>
#       <td>2423.0</td>
#       <td>2380.00</td>
#       <td>2412.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>F1</td>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2025-08-01</td>
#       <td>2025-08-01</td>
#       <td>CO</td>
#       <td>NCD</td>
#       <td>COF</td>
#       <td>77041</td>
#       <td>NaN</td>
#       <td>BAJRA</td>
#       <td>NaN</td>
#       <td>2025-11-20</td>
#       <td>2025-11-20</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>BAJRA20NOV2025</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2424.0</td>
#       <td>0.0</td>
#       <td>2435.0</td>
#       <td>2380.00</td>
#       <td>2424.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>F1</td>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2025-08-01</td>
#       <td>2025-08-01</td>
#       <td>CO</td>
#       <td>NCD</td>
#       <td>COF</td>
#       <td>77429</td>
#       <td>NaN</td>
#       <td>BAJRA</td>
#       <td>NaN</td>
#       <td>2025-12-19</td>
#       <td>2025-12-19</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>BAJRA19DEC2025</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2436.0</td>
#       <td>0.0</td>
#       <td>2435.0</td>
#       <td>2380.00</td>
#       <td>2436.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>F1</td>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2025-08-01</td>
#       <td>2025-08-01</td>
#       <td>CO</td>
#       <td>NCD</td>
#       <td>COF</td>
#       <td>75679</td>
#       <td>NaN</td>
#       <td>BARLEYJPR</td>
#       <td>NaN</td>
#       <td>2025-08-20</td>
#       <td>2025-08-20</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>BARLEYJPR20AUG2025</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2337.5</td>
#       <td>0.0</td>
#       <td>2345.5</td>
#       <td>2330.20</td>
#       <td>2337.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>F1</td>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2025-08-01</td>
#       <td>2025-08-01</td>
#       <td>CO</td>
#       <td>NCD</td>
#       <td>COF</td>
#       <td>76177</td>
#       <td>NaN</td>
#       <td>BARLEYJPR</td>
#       <td>NaN</td>
#       <td>2025-09-19</td>
#       <td>2025-09-19</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>BARLEYJPR19SEP2025</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2349.5</td>
#       <td>0.0</td>
#       <td>2357.0</td>
#       <td>2330.20</td>
#       <td>2349.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>F1</td>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2025-08-01</td>
#       <td>2025-08-01</td>
#       <td>CO</td>
#       <td>NCD</td>
#       <td>COF</td>
#       <td>76593</td>
#       <td>NaN</td>
#       <td>BARLEYJPR</td>
#       <td>NaN</td>
#       <td>2025-10-20</td>
#       <td>2025-10-20</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>BARLEYJPR20OCT2025</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2361.0</td>
#       <td>0.0</td>
#       <td>2369.0</td>
#       <td>2330.20</td>
#       <td>2361.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>F1</td>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2025-08-01</td>
#       <td>2025-08-01</td>
#       <td>CO</td>
#       <td>NCD</td>
#       <td>COF</td>
#       <td>77042</td>
#       <td>NaN</td>
#       <td>BARLEYJPR</td>
#       <td>NaN</td>
#       <td>2025-11-20</td>
#       <td>2025-11-20</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>BARLEYJPR20NOV2025</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>2373.5</td>
#       <td>0.0</td>
#       <td>2381.0</td>
#       <td>2330.20</td>
#       <td>2373.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>F1</td>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2025-08-01</td>
#       <td>2025-08-01</td>
#       <td>CO</td>
#       <td>NCD</td>
#       <td>COF</td>
#       <td>77430</td>
#       <td>NaN</td>

# %%
unique_symbols = collect_unique_symbols_from_zips("../data/ncdex")
unique_symbols
# Out:
# Error reading from ../data/ncdex/2025/Apr/2025-04-05.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Apr/2025-04-06.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Apr/2025-04-10.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Apr/2025-04-12.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Apr/2025-04-13.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Apr/2025-04-14.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Apr/2025-04-18.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Apr/2025-04-19.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Apr/2025-04-20.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Apr/2025-04-26.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Apr/2025-04-27.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Aug/2025-08-02.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Aug/2025-08-03.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Aug/2025-08-09.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Aug/2025-08-10.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Aug/2025-08-15.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Aug/2025-08-16.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Aug/2025-08-17.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Feb/2025-02-02.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Feb/2025-02-08.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Feb/2025-02-09.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Feb/2025-02-15.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Feb/2025-02-16.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Feb/2025-02-22.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Feb/2025-02-23.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Feb/2025-02-26.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jan/2025-01-04.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jan/2025-01-05.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jan/2025-01-11.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jan/2025-01-12.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jan/2025-01-18.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jan/2025-01-19.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jan/2025-01-25.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jan/2025-01-26.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jul/2025-07-05.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jul/2025-07-06.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jul/2025-07-12.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jul/2025-07-13.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jul/2025-07-19.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jul/2025-07-20.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jul/2025-07-26.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jul/2025-07-27.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jun/2025-06-01.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jun/2025-06-07.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jun/2025-06-08.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jun/2025-06-14.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jun/2025-06-15.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jun/2025-06-21.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jun/2025-06-22.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jun/2025-06-28.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Jun/2025-06-29.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Mar/2025-03-01.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Mar/2025-03-02.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Mar/2025-03-08.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Mar/2025-03-09.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Mar/2025-03-14.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Mar/2025-03-15.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Mar/2025-03-16.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Mar/2025-03-22.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Mar/2025-03-23.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Mar/2025-03-29.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Mar/2025-03-30.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/Mar/2025-03-31.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/May/2025-05-01.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/May/2025-05-03.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/May/2025-05-04.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/May/2025-05-10.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/May/2025-05-11.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/May/2025-05-17.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/May/2025-05-18.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/May/2025-05-24.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/May/2025-05-25.zip: File is not a zip file
# Error reading from ../data/ncdex/2025/May/2025-05-31.zip: File is not a zip file
# ['BAJRA',
#  'BARLEYJPR',
#  'CASTOR',
#  'CASTOROIL',
#  'COCUDAKL',
#  'COTTON',
#  'COTWASOIL',
#  'DHANIYA',
#  'GROUNDNUT',
#  'GUARGUM5',
#  'GUARSEED10',
#  'ISABGOL',
#  'JEERAMINI',
#  'JEERAUNJHA',
#  'KAPAS',
#  'MAIZE',
#  'SESAMESEED',
#  'STEEL',
#  'SUNOIL',
#  'TMCFGRNZM',
#  'YELLOWP']

# %%
glob(os.path.join("../data/ncdex", "*.zip"),recursive=True)
# Out:
# []
