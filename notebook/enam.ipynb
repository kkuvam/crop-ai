# %%
import os
import json
import time
import requests
from pathlib import Path
import gzip, json
from datetime import datetime, timedelta
from typing import Dict, Any, Optional, Iterable

# %%
def get_states():
    url = "https://enam.gov.in/web/ajax_ctrl/states_name"
    response = requests.get(url)
    return response.json()

# %%
get_states()
# Out:
# {'data': [{'state_name': 'ANDAMAN AND NICOBAR ISLANDS', 'state_id': '37'},
#   {'state_name': 'ANDHRA PRADESH', 'state_id': '276'},
#   {'state_name': 'ASSAM', 'state_id': '38'},
#   {'state_name': 'BIHAR', 'state_id': '33'},
#   {'state_name': 'CHANDIGARH', 'state_id': '526'},
#   {'state_name': 'CHHATTISGARH', 'state_id': '100'},
#   {'state_name': 'GOA', 'state_id': '34'},
#   {'state_name': 'GUJARAT', 'state_id': '22'},
#   {'state_name': 'HARYANA', 'state_id': '32'},
#   {'state_name': 'HIMACHAL PRADESH', 'state_id': '43'},
#   {'state_name': 'JAMMU AND KASHMIR', 'state_id': '696'},
#   {'state_name': 'JHARKHAND', 'state_id': '47'},
#   {'state_name': 'KARNATAKA', 'state_id': '695'},
#   {'state_name': 'KERALA', 'state_id': '694'},
#   {'state_name': 'MADHYA PRADESH', 'state_id': '20'},
#   {'state_name': 'MAHARASHTRA', 'state_id': '296'},
#   {'state_name': 'NAGALAND', 'state_id': '35'},
#   {'state_name': 'ODISHA', 'state_id': '384'},
#   {'state_name': 'PUDUCHERRY', 'state_id': '599'},
#   {'state_name': 'PUNJAB', 'state_id': '602'},
#   {'state_name': 'RAJASTHAN', 'state_id': '26'},
#   {'state_name': 'TAMIL NADU', 'state_id': '509'},
#   {'state_name': 'TELANGANA', 'state_id': '28'},
#   {'state_name': 'TRIPURA', 'state_id': '36'},
#   {'state_name': 'UTTAR PRADESH', 'state_id': '46'},
#   {'state_name': 'UTTARAKHAND', 'state_id': '385'},
#   {'state_name': 'WEST BENGAL', 'state_id': '569'}],
#  'status': 200}

# %%
headers = {
    "User-Agent": "Mozilla/5.0",
    "Content-Type": "application/x-www-form-urlencoded"
}

# %%
def get_apmcs():
    apmcs = []
    url = "https://enam.gov.in/web/Ajax_ctrl/apmc_list"
    states = get_states()['data']
    # Extract all state_ids
    state_ids = [item['state_id'] for item in states]
    for state_id in state_ids:
        payload = { 'state_id': state_id}
        response = requests.post(url, data=payload, headers=headers)
        apmcs.extend(response.json()['data'])
    return apmcs

# %%
get_apmcs()
# Out:
# [{'apmc_id': '5038', 'apmc_name': 'ANDAMAN HI TECH KISAN MANDI'},
#  {'apmc_id': '316', 'apmc_name': 'ADONI'},
#  {'apmc_id': '314', 'apmc_name': 'ANAKAPALLI'},
#  {'apmc_id': '289', 'apmc_name': 'ANANTHAPURAMU'},
#  {'apmc_id': '792', 'apmc_name': 'BOBBILI APMC'},
#  {'apmc_id': '793', 'apmc_name': 'CHILAKALURIPET APMC'},
#  {'apmc_id': '291', 'apmc_name': 'DENDULURU'},
#  {'apmc_id': '312', 'apmc_name': 'DUGGIRALA'},
#  {'apmc_id': '311', 'apmc_name': 'ELURU'},
#  {'apmc_id': '282', 'apmc_name': 'GOPALAPURAM'},
#  {'apmc_id': '313', 'apmc_name': 'GUNTUR'},
#  {'apmc_id': '293', 'apmc_name': 'GURRAMKONDA'},
#  {'apmc_id': '318', 'apmc_name': 'HINDUPUR'},
#  {'apmc_id': '794', 'apmc_name': 'ICHAPURAM APMC'},
#  {'apmc_id': '795', 'apmc_name': 'JAGGAYYAPET APMC'},
#  {'apmc_id': '320', 'apmc_name': 'KADAPA'},
#  {'apmc_id': '292', 'apmc_name': 'KALIKIRI'},
#  {'apmc_id': '319', 'apmc_name': 'Kalyandurg'},
#  {'apmc_id': '315', 'apmc_name': 'KURNOOL'},
#  {'apmc_id': '288', 'apmc_name': 'MADANAPALLE'},
#  {'apmc_id': '290', 'apmc_name': 'PALAMANER'},
#  {'apmc_id': '796', 'apmc_name': 'PARCHUR APMC'},
#  {'apmc_id': '287', 'apmc_name': 'PATTIKONDA'},
#  {'apmc_id': '284', 'apmc_name': 'PIDUGURALLA'},
#  {'apmc_id': '286', 'apmc_name': 'PUNGANUR'},
#  {'apmc_id': '285', 'apmc_name': 'RAPUR'},
#  {'apmc_id': '1200', 'apmc_name': 'RAVULAPALEM APMC'},
#  {'apmc_id': '798', 'apmc_name': 'RAYADURG APMC'},
#  {'apmc_id': '799', 'apmc_name': 'SATTENAPALLE APMC'},
#  {'apmc_id': '800', 'apmc_name': 'TADIKONDA APMC'},
#  {'apmc_id': '283', 'apmc_name': 'TENALI'},
#  {'apmc_id': '784', 'apmc_name': 'VEMURU BHATTIPROLU'},
#  {'apmc_id': '801', 'apmc_name': 'VIZIANAGARAM APMC'},
#  {'apmc_id': '317', 'apmc_name': 'YEMMIGANUR'},
#  {'apmc_id': '5039', 'apmc_name': 'DHING'},
#  {'apmc_id': '5040', 'apmc_name': 'GAURIPUR'},
#  {'apmc_id': '5041', 'apmc_name': 'KHARUPETIA'},
#  {'apmc_id': '4036', 'apmc_name': 'ARA'},
#  {'apmc_id': '4037', 'apmc_name': 'BEGUSARAI'},
#  {'apmc_id': '4038', 'apmc_name': 'BIHARSHARIF'},
#  {'apmc_id': '4039', 'apmc_name': 'BUXAR'},
#  {'apmc_id': '4052', 'apmc_name': 'CHHAPRA'},
#  {'apmc_id': '4040', 'apmc_name': 'DARBHANGA'},
#  {'apmc_id': '4041', 'apmc_name': 'DAUDNAGAR'},
#  {'apmc_id': '4042', 'apmc_name': 'FORBESGANJ'},
#  {'apmc_id': '4043', 'apmc_name': 'GAYA'},
#  {'apmc_id': '4044', 'apmc_name': 'GULABBAGH'},
#  {'apmc_id': '4045', 'apmc_name': 'HAJIPUR'},
#  {'apmc_id': '4046', 'apmc_name': 'KATIHAR'},
#  {'apmc_id': '4047', 'apmc_name': 'MOHANIYA'},
#  {'apmc_id': '4048', 'apmc_name': 'MOTIHARI'},
#  {'apmc_id': '4049', 'apmc_name': 'MUSALLAHPUR'},
#  {'apmc_id': '4050', 'apmc_name': 'MUZAFFARPUR'},
#  {'apmc_id': '4051', 'apmc_name': 'SAMASTIPUR'},
#  {'apmc_id': '4053', 'apmc_name': 'SASARAM'},
#  {'apmc_id': '4054', 'apmc_name': 'SINGHESWAR'},
#  {'apmc_id': '4055', 'apmc_name': 'SITAMARHI'},
#  {'apmc_id': '525', 'apmc_name': 'CHANDIGARH SECTOR-26'},
#  {'apmc_id': '341', 'apmc_name': 'BALOD'},
#  {'apmc_id': '105', 'apmc_name': 'BHATAPARA'},
#  {'apmc_id': '339', 'apmc_name': 'BILASPUR'},
#  {'apmc_id': '338', 'apmc_name': 'DHAMTARI'},
#  {'apmc_id': '336', 'apmc_name': 'DURG'},
#  {'apmc_id': '340', 'apmc_name': 'JAGDALPUR'},
#  {'apmc_id': '103', 'apmc_name': 'KAWARADHA'},
#  {'apmc_id': '104', 'apmc_name': 'KURUD'},
#  {'apmc_id': '343', 'apmc_name': 'MUNGELI'},
#  {'apmc_id': '101', 'apmc_name': 'NAVAPARA'},
#  {'apmc_id': '344', 'apmc_name': 'PATELPALI RAIGARH'},
#  {'apmc_id': '337', 'apmc_name': 'RAIPUR'},
#  {'apmc_id': '342', 'apmc_name': 'RAJIM'},
#  {'apmc_id': '102', 'apmc_name': 'RAJNANDGAON'},
#  {'apmc_id': '4978', 'apmc_name': 'KANKER'},
#  {'apmc_id': '4979', 'apmc_name': 'SARAIPALI'},
#  {'apmc_id': '4980', 'apmc_name': 'BEMETARA'},
#  {'apmc_id': '4981', 'apmc_name': 'KATGHORA'},
#  {'apmc_id': '4982', 'apmc_name': 'AMBIKAPUR'},
#  {'apmc_id': '4983', 'apmc_name': 'JASHPUR'},
#  {'apmc_id': '3907', 'apmc_name': 'CANACONA MARKET YARD'},
#  {'apmc_id': '3906', 'apmc_name': 'CURCHOREM MARKET YARD'},
#  {'apmc_id': '3904', 'apmc_name': 'MAPUSA MARKET YARD'},
#  {'apmc_id': '3903', 'apmc_name': 'MARGAO MAIN MARKET YARD'},
#  {'apmc_id': '3908', 'apmc_name': 'PONDA MARKET YARD'},
#  {'apmc_id': '3902', 'apmc_name': 'SANQUELIM MARKET YARD'},
#  {'apmc_id': '3901', 'apmc_name': 'VALPOI MARKET YARD'},
#  {'apmc_id': '232', 'apmc_name': 'AHMEDABAD'},
#  {'apmc_id': '553', 'apmc_name': 'AMRELI'},
#  {'apmc_id': '541', 'apmc_name': 'ANAND'},
#  {'apmc_id': '665', 'apmc_name': 'ANJAR'},
#  {'apmc_id': '542', 'apmc_name': 'BABRA'},
#  {'apmc_id': '650', 'apmc_name': 'BAGASARA'},
#  {'apmc_id': '812', 'apmc_name': 'BARDOLI APMC'},
#  {'apmc_id': '803', 'apmc_name': 'BAVLA APMC'},
#  {'apmc_id': '834', 'apmc_name': 'BAYAD APMC'},
#  {'apmc_id': '233', 'apmc_name': 'BHABHAR'},
#  {'apmc_id': '656', 'apmc_name': 'BHARUCH'},
#  {'apmc_id': '543', 'apmc_name': 'BHAVNAGAR'},
#  {'apmc_id': '234', 'apmc_name': 'BHESAN'},
#  {'apmc_id': '235', 'apmc_name': 'BHILODA'},
#  {'apmc_id': '554', 'apmc_name': 'BHUJ'},
#  {'apmc_id': '236', 'apmc_name': 'BILIMORA'},
#  {'apmc_id': '555', 'apmc_name': 'BODELI'},
#  {'apmc_id': '652', 'apmc_name': 'BORSAD'},
#  {'apmc_id': '40', 'apmc_name': 'BOTAD'},
#  {'apmc_id': '835', 'apmc_name': 'CHIKHLI APMC'},
#  {'apmc_id': '825', 'apmc_name': 'CHOTILA APMC'},
#  {'apmc_id': '815', 'apmc_name': 'DABHOI APMC'},
#  {'apmc_id': '237', 'apmc_name': 'DAHOD'},
#  {'apmc_id': '828', 'apmc_name': 'DEDIYAPADA APMC'},
#  {'apmc_id': '238', 'apmc_name': 'DEESA'},
#  {'apmc_id': '556', 'apmc_name': 'DEHGAM'},
#  {'apmc_id': '830', 'apmc_name': 'DEVGADHBARIA APMC'},
#  {'apmc_id': '802', 'apmc_name': 'DHANDHUKA APMC'},
#  {'apmc_id': '239', 'apmc_name': 'DHANERA'},
#  {'apmc_id': '651', 'apmc_name': 'DHARI'},
#  {'apmc_id': '240', 'apmc_name': 'DHOALKA'},
#  {'apmc_id': '544', 'apmc_name': 'DHORAJI'},
#  {'apmc_id': '241', 'apmc_name': 'DHROL'},
#  {'apmc_id': '831', 'apmc_name': 'FATEHPURA APMC'},
#  {'apmc_id': '658', 'apmc_name': 'GADHADA'},
#  {'apmc_id': '808', 'apmc_name': 'GANDHINAGAR APMC'},
#  {'apmc_id': '806', 'apmc_name': 'GARIYADHAR APMC'},
#  {'apmc_id': '242', 'apmc_name': 'GODHRA'},
#  {'apmc_id': '669', 'apmc_name': 'GONDAL'},
#  {'apmc_id': '243', 'apmc_name': 'HALVAD'},
#  {'apmc_id': '24', 'apmc_name': 'HIMMATNAGAR'},
#  {'apmc_id': '836', 'apmc_name': 'IDAR APMC'},
#  {'apmc_id': '244', 'apmc_name': 'JAM JODHPUR'},
#  {'apmc_id': '557', 'apmc_name': 'JAMKANDORNA'},
#  {'apmc_id': '245', 'apmc_name': 'JAMKHAMBHALIYA'},
#  {'apmc_id': '246', 'apmc_name': 'JAMNAGAR'},
#  {'apmc_id': '247', 'apmc_name': 'JASDAN'},
#  {'apmc_id': '545', 'apmc_name': 'JETPUR'},
#  {'apmc_id': '804', 'apmc_name': 'JHAGADIYA APMC'},
#  {'apmc_id': '268', 'apmc_name': 'JHALOD'},
#  {'apmc_id': '248', 'apmc_name': 'JUNAGADH'},
#  {'apmc_id': '811', 'apmc_name': 'KADI APMC'},
#  {'apmc_id': '661', 'apmc_name': 'KALAVAD'},
#  {'apmc_id': '558', 'apmc_name': 'KALOL'},
#  {'apmc_id': '546', 'apmc_name': 'KAPADWANJ'},
#  {'apmc_id': '547', 'apmc_name': 'KARJAN'},
#  {'apmc_id': '821', 'apmc_name': 'KATHLAL APMC'},
#  {'apmc_id': '663', 'apmc_name': 'KESHOD'},
#  {'apmc_id': '653', 'apmc_name': 'KHAMBHAT'},
#  {'apmc_id': '249', 'apmc_name': 'KODINAR'},
#  {'apmc_id': '820', 'apmc_name': 'KOSAMBA APMC'},
#  {'apmc_id': '559', 'apmc_name': 'LALPUR'},
#  {'apmc_id': '833', 'apmc_name': 'LIMKHEDA APMC'},
#  {'apmc_id': '837', 'apmc_name': 'LUNAWADA APMC'},
#  {'apmc_id': '664', 'apmc_name': 'MAHEMDAVAD'},
#  {'apmc_id': '162', 'apmc_name': 'MAHUVA'},
#  {'apmc_id': '813', 'apmc_name': 'MAHUVA APMC GJ'},
#  {'apmc_id': '819', 'apmc_name': 'MANADAL APMC'},
#  {'apmc_id': '809', 'apmc_name': 'MANDVI APMC'},
#  {'apmc_id': '816', 'apmc_name': 'MATAR APMC'},
#  {'apmc_id': '548', 'apmc_name': 'MEHSANA'},
#  {'apmc_id': '565', 'apmc_name': 'MODASA'},
#  {'apmc_id': '560', 'apmc_name': 'MORBI'},
#  {'apmc_id': '549', 'apmc_name': 'NADIAD'},
#  {'apmc_id': '838', 'apmc_name': 'NAVSARI APMC'},
#  {'apmc_id': '251', 'apmc_name': 'NIZAR'},
#  {'apmc_id': '673', 'apmc_name': 'PADARA'},
#  {'apmc_id': '561', 'apmc_name': 'PALANPUR'},
#  {'apmc_id': '805', 'apmc_name': 'PALITANA APMC'},
#  {'apmc_id': '655', 'apmc_name': 'PANTHAWADA'},
#  {'apmc_id': '45', 'apmc_name': 'PATAN'},
#  {'apmc_id': '822', 'apmc_name': 'PATDI APMC'},
#  {'apmc_id': '252', 'apmc_name': 'PAVI-JETPUR'},
#  {'apmc_id': '253', 'apmc_name': 'PETALAD'},
#  {'apmc_id': '254', 'apmc_name': 'PORBANDAR'},
#  {'apmc_id': '824', 'apmc_name': 'PRANTIJ APMC'},
#  {'apmc_id': '839', 'apmc_name': 'RADHANPUR APMC'},
#  {'apmc_id': '255', 'apmc_name': 'RAJKOT'},
#  {'apmc_id': '827', 'apmc_name': 'RAJPIPLA APMC'},
#  {'apmc_id': '550', 'apmc_name': 'RAJULA'},
#  {'apmc_id': '666', 'apmc_name': 'RAPAR'},
#  {'apmc_id': '256', 'apmc_name': 'SANAND'},
#  {'apmc_id': '832', 'apmc_name': 'SANJELI APMC'},
#  {'apmc_id': '257', 'apmc_name': 'SAVARKUNDLA'},
#  {'apmc_id': '258', 'apmc_name': 'SAVLI'},
#  {'apmc_id': '826', 'apmc_name': 'SELAMBA APMC'},
#  {'apmc_id': '551', 'apmc_name': 'SIDDHPUR'},
#  {'apmc_id': '818', 'apmc_name': 'SIHOR APMC'},
#  {'apmc_id': '814', 'apmc_name': 'SONGADH APMC'},
#  {'apmc_id': '840', 'apmc_name': 'TALAJA APMC'},
#  {'apmc_id': '259', 'apmc_name': 'TALOD'},
#  {'apmc_id': '552', 'apmc_name': 'TARAPUR'},
#  {'apmc_id': '260', 'apmc_name': 'THARA'},
#  {'apmc_id': '261', 'apmc_name': 'THARAD'},
#  {'apmc_id': '823', 'apmc_name': 'THASRA APMC'},
#  {'apmc_id': '829', 'apmc_name': 'TILAKWADA APMC'},
#  {'apmc_id': '807', 'apmc_name': 'UMRALA APMC'},
#  {'apmc_id': '841', 'apmc_name': 'UNA APMC'},
#  {'apmc_id': '810', 'apmc_name': 'UNAVA APMC'},
#  {'apmc_id': '562', 'apmc_name': 'UPLETA'},
#  {'apmc_id': '842', 'apmc_name': 'VADALI APMC'},
#  {'apmc_id': '262', 'apmc_name': 'VADHVAN'},
#  {'apmc_id': '263', 'apmc_name': 'VADODARA'},
#  {'apmc_id': '817', 'apmc_name': 'VALABHIPUR APMC'},
#  {'apmc_id': '843', 'apmc_name': 'VALIA APMC'},
#  {'apmc_id': '264', 'apmc_name': 'VALSAD'},
#  {'apmc_id': '265', 'apmc_name': 'VIJAPUR'},
#  {'apmc_id': '563', 'apmc_name': 'VINCHHIYA'},
#  {'apmc_id': '266', 'apmc_name': 'VISAVADAR'},
#  {'apmc_id': '267', 'apmc_name': 'VISNAGAR'},
#  {'apmc_id': '564', 'apmc_name': 'VYARA'},
#  {'apmc_id': '844', 'apmc_name': 'WANKANER APMC'},
#  {'apmc_id': '5053', 'apmc_name': 'AHWA'},
#  {'apmc_id': '5054', 'apmc_name': 'DESAR'},
#  {'apmc_id': '5055', 'apmc_name': 'DHANGADRA'},
#  {'apmc_id': '5056', 'apmc_name': 'KAPRADA'},
#  {'apmc_id': '5057', 'apmc_name': 'KUKARMUDA'},
#  {'apmc_id': '5058', 'apmc_name': 'MANDVI'},
#  {'apmc_id': '5059', 'apmc_name': 'PARDI'},
#  {'apmc_id': '5060', 'apmc_name': 'UNCHAL'},
#  {'apmc_id': '5061', 'apmc_name': 'VASDA'},
#  {'apmc_id': '5064', 'apmc_name': 'VERAVAL'},
#  {'apmc_id': '5093', 'apmc_name': 'TALALAGIR'},
#  {'apmc_id': '5094', 'apmc_name': 'BHANVAD'},
#  {'apmc_id': '5095', 'apmc_name': 'LAKHANI'},
#  {'apmc_id': '5096', 'apmc_name': 'MAANSA'},
#  {'apmc_id': '5097', 'apmc_name': 'MALPUR'},
#  {'apmc_id': '5098', 'apmc_name': 'VIRAMGAM'},
#  {'apmc_id': '5128', 'apmc_name': 'CHANASMA '},
#  {'apmc_id': '5129', 'apmc_name': 'DEODAR'},
#  {'apmc_id': '5130', 'apmc_name': 'SURAT'},
#  {'apmc_id': '5131', 'apmc_name': 'UNJHA'},
#  {'apmc_id': '5132', 'apmc_name': 'VALOD'},
#  {'apmc_id': '5133', 'apmc_name': 'VIRPUR'},
#  {'apmc_id': '132', 'apmc_name': 'ADAMPUR'},
#  {'apmc_id': '3931', 'apmc_name': 'ALEWA'},
#  {'apmc_id': '59', 'apmc_name': 'AMBALA'},
#  {'apmc_id': '995', 'apmc_name': 'AMBALA CANTT. APMC'},
#  {'apmc_id': '277', 'apmc_name': 'ASANDH'},
#  {'apmc_id': '996', 'apmc_name': 'ATELI APMC'},
#  {'apmc_id': '3932', 'apmc_name': 'BABAIN'},
#  {'apmc_id': '3933', 'apmc_name': 'BAHADURGARH'},
#  {'apmc_id': '3935', 'apmc_name': 'BALLABGARH'},
#  {'apmc_id': '3936', 'apmc_name': 'BAPOLI'},
#  {'apmc_id': '3937', 'apmc_name': 'BARARA'},
#  {'apmc_id': '364', 'apmc_name': 'BARWALA HISAR'},
#  {'apmc_id': '997', 'apmc_name': 'BARWALA PANCHKULA APMC'},
#  {'apmc_id': '3938', 'apmc_name': 'BASS'},
#  {'apmc_id': '3939', 'apmc_name': 'BEHAL'},
#  {'apmc_id': '3940', 'apmc_name': 'BERI'},
#  {'apmc_id': '998', 'apmc_name': 'BHATTU KALAN APMC'},
#  {'apmc_id': '368', 'apmc_name': 'BHIWANI'},
#  {'apmc_id': '3941', 'apmc_name': 'BHUNA'},
#  {'apmc_id': '112', 'apmc_name': 'CH DADRI'},
#  {'apmc_id': '356', 'apmc_name': 'CHEEKA'},
#  {'apmc_id': '369', 'apmc_name': 'CHHACHHRAULI'},
#  {'apmc_id': '125', 'apmc_name': 'DABWALI'},
#  {'apmc_id': '367', 'apmc_name': 'DHAND'},
#  {'apmc_id': '3942', 'apmc_name': 'DING'},
#  {'apmc_id': '54', 'apmc_name': 'ELLANABAD'},
#  {'apmc_id': '359', 'apmc_name': 'FARIDABAD'},
#  {'apmc_id': '3944', 'apmc_name': 'FARRUKHNAGAR'},
#  {'apmc_id': '357', 'apmc_name': 'FATEHABAD'},
#  {'apmc_id': '999', 'apmc_name': 'FEROZPUR JHIRKA APMC'},
#  {'apmc_id': '129', 'apmc_name': 'GANAUR'},
#  {'apmc_id': '110', 'apmc_name': 'GHARAUNDA'},
#  {'apmc_id': '128', 'apmc_name': 'GOHANA'},
#  {'apmc_id': '360', 'apmc_name': 'GURGAON'},
#  {'apmc_id': '131', 'apmc_name': 'HANSI'},
#  {'apmc_id': '3945', 'apmc_name': 'HASSANPUR'},
#  {'apmc_id': '3946', 'apmc_name': 'HATHIN'},
#  {'apmc_id': '1000', 'apmc_name': 'HISAR APMC'},
#  {'apmc_id': '363', 'apmc_name': 'HODAL'},
#  {'apmc_id': '295', 'apmc_name': 'INDRI'},
#  {'apmc_id': '124', 'apmc_name': 'ISMAILABAD'},
#  {'apmc_id': '1001', 'apmc_name': 'ISRANA APMC'},
#  {'apmc_id': '1002', 'apmc_name': 'JAGADHRI APMC'},
#  {'apmc_id': '433', 'apmc_name': 'JAKHAL'},
#  {'apmc_id': '361', 'apmc_name': 'JHAJJAR'},
#  {'apmc_id': '120', 'apmc_name': 'JIND'},
#  {'apmc_id': '3947', 'apmc_name': 'JUI'},
#  {'apmc_id': '114', 'apmc_name': 'JULANA'},
#  {'apmc_id': '3948', 'apmc_name': 'JUNDLA'},
#  {'apmc_id': '108', 'apmc_name': 'KAITHAL'},
#  {'apmc_id': '123', 'apmc_name': 'KALANWALI'},
#  {'apmc_id': '365', 'apmc_name': 'KALAYAT'},
#  {'apmc_id': '1003', 'apmc_name': 'KANINA APMC'},
#  {'apmc_id': '53', 'apmc_name': 'KARNAL'},
#  {'apmc_id': '3951', 'apmc_name': 'KHARKHODA'},
#  {'apmc_id': '1004', 'apmc_name': 'KOSLI APMC'},
#  {'apmc_id': '122', 'apmc_name': 'LADWA'},
#  {'apmc_id': '3952', 'apmc_name': 'LOHARU'},
#  {'apmc_id': '117', 'apmc_name': 'MADLAUDA'},
#  {'apmc_id': '1005', 'apmc_name': 'MEHAM APMC'},
#  {'apmc_id': '1006', 'apmc_name': 'MOHINDERGARH APMC'},
#  {'apmc_id': '3953', 'apmc_name': 'MOHNA'},
#  {'apmc_id': '106', 'apmc_name': 'MULLANA'},
#  {'apmc_id': '3954', 'apmc_name': 'MUSTAFABAD'},
#  {'apmc_id': '1007', 'apmc_name': 'NARAINGARH APMC'},
#  {'apmc_id': '1008', 'apmc_name': 'NARNAUL APMC'},
#  {'apmc_id': '370', 'apmc_name': 'NARNAUND'},
#  {'apmc_id': '118', 'apmc_name': 'NARWANA'},
#  {'apmc_id': '1009', 'apmc_name': 'NIGDHU APMC'},
#  {'apmc_id': '1010', 'apmc_name': 'NILOKHERI APMC'},
#  {'apmc_id': '111', 'apmc_name': 'NISSING'},
#  {'apmc_id': '1011', 'apmc_name': 'NUH APMC'},
#  {'apmc_id': '1012', 'apmc_name': 'PAI APMC'},
#  {'apmc_id': '366', 'apmc_name': 'PALWAL'},
#  {'apmc_id': '1013', 'apmc_name': 'PANCHKULA APMC'},
#  {'apmc_id': '113', 'apmc_name': 'PANIPAT'},
#  {'apmc_id': '3955', 'apmc_name': 'PATAUDI'},
#  {'apmc_id': '121', 'apmc_name': 'PEHOWA'},
#  {'apmc_id': '362', 'apmc_name': 'PILLUKHERA'},
#  {'apmc_id': '1014', 'apmc_name': 'PIPLI APMC'},
#  {'apmc_id': '278', 'apmc_name': 'PUNDRI'},
#  {'apmc_id': '1015', 'apmc_name': 'PUNHANA APMC'},
#  {'apmc_id': '3956', 'apmc_name': 'RADAUR'},
#  {'apmc_id': '1016', 'apmc_name': 'RAIPUR RANI APMC'},
#  {'apmc_id': '279', 'apmc_name': 'RANIA'},
#  {'apmc_id': '130', 'apmc_name': 'RATIA'},
#  {'apmc_id': '109', 'apmc_name': 'REWARI'},
#  {'apmc_id': '107', 'apmc_name': 'ROHTAK'},
#  {'apmc_id': '1017', 'apmc_name': 'SADHAURA APMC'},
#  {'apmc_id': '116', 'apmc_name': 'SAFIDON'},
#  {'apmc_id': '115', 'apmc_name': 'SAMALKHA'},
#  {'apmc_id': '3957', 'apmc_name': 'SAMPLA'},
#  {'apmc_id': '60', 'apmc_name': 'SHAHBAD'},
#  {'apmc_id': '1018', 'apmc_name': 'SHAHZADPUR APMC'},
#  {'apmc_id': '280', 'apmc_name': 'SIRSA'},
#  {'apmc_id': '3958', 'apmc_name': 'SIWAN'},
#  {'apmc_id': '371', 'apmc_name': 'SIWANI'},
#  {'apmc_id': '3959', 'apmc_name': 'SOHNA'},
#  {'apmc_id': '126', 'apmc_name': 'SONEPAT'},
#  {'apmc_id': '127', 'apmc_name': 'TARAORI'},
#  {'apmc_id': '1019', 'apmc_name': 'TAURU APMC'},
#  {'apmc_id': '119', 'apmc_name': 'THANESAR'},
#  {'apmc_id': '3960', 'apmc_name': 'TIGAON'},
#  {'apmc_id': '281', 'apmc_name': 'TOHANA'},
#  {'apmc_id': '3961', 'apmc_name': 'TOSHAM'},
#  {'apmc_id': '358', 'apmc_name': 'UCHANA'},
#  {'apmc_id': '1020', 'apmc_name': 'UKLANA APMC'},
#  {'apmc_id': '1021', 'apmc_name': 'YAMUNA NAGAR APMC'},
#  {'apmc_id': '3896', 'apmc_name': 'BAIJNATH'},
#  {'apmc_id': '375', 'apmc_name': 'BANDROL'},
#  {'apmc_id': '273', 'apmc_name': 'BHATTAKUFAR DHALLI'},
#  {'apmc_id': '269', 'apmc_name': 'BHUNTAR'},
#  {'apmc_id': '3892', 'apmc_name': 'CHAILCHOWK'},
#  {'apmc_id': '383', 'apmc_name': 'CHAMBA'},
#  {'apmc_id': '44', 'apmc_name': 'DHALLI SHIMLA'},
#  {'apmc_id': '3894', 'apmc_name': 'DHANOTU'},
#  {'apmc_id': '3895', 'apmc_name': 'DHARAMSHALA'},
#  {'apmc_id': '42', 'apmc_name': 'FRUIT MANDI SOLAN'},
#  {'apmc_id': '380', 'apmc_name': 'HAMIRPUR'},
#  {'apmc_id': '377', 'apmc_name': 'KANGRA'},
#  {'apmc_id': '272', 'apmc_name': 'KANGRA JASSOUR'},
#  {'apmc_id': '3893', 'apmc_name': 'KHARAPATHAR'},
#  {'apmc_id': '379', 'apmc_name': 'MANDI'},
#  {'apmc_id': '3889', 'apmc_name': 'MEHANDLI'},
#  {'apmc_id': '378', 'apmc_name': 'PALAMPUR'},
#  {'apmc_id': '374', 'apmc_name': 'PAONTA SAHIB'},
#  {'apmc_id': '373', 'apmc_name': 'PARALA'},
#  {'apmc_id': '376', 'apmc_name': 'PATIKUHAL'},
#  {'apmc_id': '372', 'apmc_name': 'ROHRU'},
#  {'apmc_id': '382', 'apmc_name': 'SANTOSHGARH'},
#  {'apmc_id': '270', 'apmc_name': 'SOLAN PARWANOO'},
#  {'apmc_id': '271', 'apmc_name': 'TAKOLI'},
#  {'apmc_id': '3891', 'apmc_name': 'TAPRI'},
#  {'apmc_id': '381', 'apmc_name': 'UNA'},
#  {'apmc_id': '5017', 'apmc_name': 'SMY NERWA '},
#  {'apmc_id': '5018', 'apmc_name': 'SMY NADAUN '},
#  {'apmc_id': '5019', 'apmc_name': 'SMY KULLU'},
#  {'apmc_id': '5020', 'apmc_name': 'SMY SHAAT'},
#  {'apmc_id': '5021', 'apmc_name': 'SMY CHOURIBIHAL'},
#  {'apmc_id': '5026', 'apmc_name': 'SMY WAKHNAGHAT'},
#  {'apmc_id': '5031', 'apmc_name': 'SMY DHARAMPUR'},
#  {'apmc_id': '5032', 'apmc_name': 'SMY NAGROTA BAGWAN'},
#  {'apmc_id': '5033', 'apmc_name': 'SMY TAKARLA'},
#  {'apmc_id': '5034', 'apmc_name': 'PMY NAHAN'},
#  {'apmc_id': '5035', 'apmc_name': 'SMY RAJGARH'},
#  {'apmc_id': '5037', 'apmc_name': 'PMY BILASPUR'},
#  {'apmc_id': '3875', 'apmc_name': 'ANANTNAG'},
#  {'apmc_id': '3876', 'apmc_name': 'CHARARISHARIEF'},
#  {'apmc_id': '3877', 'apmc_name': 'HANDWARA'},
#  {'apmc_id': '3878', 'apmc_name': 'KATHUA'},
#  {'apmc_id': '3879', 'apmc_name': 'KULGAM'},
#  {'apmc_id': '1371', 'apmc_name': 'NARWAL'},
#  {'apmc_id': '1372', 'apmc_name': 'PARIMPORA SGR'},
#  {'apmc_id': '3880', 'apmc_name': 'PULWAMA'},
#  {'apmc_id': '3881', 'apmc_name': 'SHOPIAN'},
#  {'apmc_id': '3882', 'apmc_name': 'SOPORE'},
#  {'apmc_id': '3883', 'apmc_name': 'UDHAMPUR'},
#  {'apmc_id': '348', 'apmc_name': 'BOKARO'},
#  {'apmc_id': '152', 'apmc_name': 'CHAIBASA'},
#  {'apmc_id': '350', 'apmc_name': 'CHAKULIA'},
#  {'apmc_id': '153', 'apmc_name': 'DALTENGANJ'},
#  {'apmc_id': '354', 'apmc_name': 'DEOGHAR'},
#  {'apmc_id': '154', 'apmc_name': 'DHANBAD'},
#  {'apmc_id': '355', 'apmc_name': 'DUMKA'},
#  {'apmc_id': '349', 'apmc_name': 'GARHWA'},
#  {'apmc_id': '351', 'apmc_name': 'GRIDIH'},
#  {'apmc_id': '155', 'apmc_name': 'GUMLA'},
#  {'apmc_id': '346', 'apmc_name': 'HAZARIBAGH'},
#  {'apmc_id': '156', 'apmc_name': 'JAMSHEDPUR'},
#  {'apmc_id': '353', 'apmc_name': 'KODERMA'},
#  {'apmc_id': '157', 'apmc_name': 'LOHARDAGA'},
#  {'apmc_id': '352', 'apmc_name': 'PAKUR'},
#  {'apmc_id': '52', 'apmc_name': 'PANDRA RANCHI'},
#  {'apmc_id': '345', 'apmc_name': 'Ramgarh'},
#  {'apmc_id': '347', 'apmc_name': 'SAHEBGANJ'},
#  {'apmc_id': '159', 'apmc_name': 'SIMDEGA'},
#  {'apmc_id': '1368', 'apmc_name': 'APMC CHINCHOLI'},
#  {'apmc_id': '1366', 'apmc_name': 'APMC KALBURGI'},
#  {'apmc_id': '5012', 'apmc_name': 'CHANNAGIRI '},
#  {'apmc_id': '5014', 'apmc_name': 'APMC YARD SAUNDATTI'},
#  {'apmc_id': '5015', 'apmc_name': 'APMC TIPTUR'},
#  {'apmc_id': '1357', 'apmc_name': 'ARWM MUVATTUPUZHA'},
#  {'apmc_id': '1362', 'apmc_name': 'ARWM NEDUMANGAD'},
#  {'apmc_id': '1361', 'apmc_name': 'ARWM SULTAN BARTHERY'},
#  {'apmc_id': '1359', 'apmc_name': 'AUWM ANAYARA'},
#  {'apmc_id': '1358', 'apmc_name': 'AUWM MARADU'},
#  {'apmc_id': '1360', 'apmc_name': 'AUWM VENGERI'},
#  {'apmc_id': '406', 'apmc_name': 'AGAR'},
#  {'apmc_id': '4063', 'apmc_name': 'ALIRAJPUR'},
#  {'apmc_id': '3912', 'apmc_name': 'AMARPATAN'},
#  {'apmc_id': '4165', 'apmc_name': 'ANUPPUR'},
#  {'apmc_id': '4057', 'apmc_name': 'ARON'},
#  {'apmc_id': '133', 'apmc_name': 'ASHOKNAGAR'},
#  {'apmc_id': '334', 'apmc_name': 'ASHTA'},
#  {'apmc_id': '3928', 'apmc_name': 'BADA MALHERA'},
#  {'apmc_id': '4058', 'apmc_name': 'BADARWAS'},
#  {'apmc_id': '400', 'apmc_name': 'BADNAGAR'},
#  {'apmc_id': '396', 'apmc_name': 'BADNAWAR'},
#  {'apmc_id': '3914', 'apmc_name': 'BAIKUNTHPUR'},
#  {'apmc_id': '466', 'apmc_name': 'BALAGHAT'},
#  {'apmc_id': '4085', 'apmc_name': 'BANKHEDI'},
#  {'apmc_id': '387', 'apmc_name': 'BARELI'},
#  {'apmc_id': '3915', 'apmc_name': 'BARWANI'},
#  {'apmc_id': '4064', 'apmc_name': 'BEOHARI'},
#  {'apmc_id': '386', 'apmc_name': 'BERASIA'},
#  {'apmc_id': '134', 'apmc_name': 'BETUL'},
#  {'apmc_id': '4065', 'apmc_name': 'BHIND'},
#  {'apmc_id': '390', 'apmc_name': 'BIAORA'},
#  {'apmc_id': '411', 'apmc_name': 'BINA'},
#  {'apmc_id': '399', 'apmc_name': 'BURHANPUR'},
#  {'apmc_id': '4164', 'apmc_name': 'CHAKGHAT'},
#  {'apmc_id': '4091', 'apmc_name': 'CHAURAI'},
#  {'apmc_id': '3916', 'apmc_name': 'CHHAPARA'},
#  {'apmc_id': '465', 'apmc_name': 'CHHATARPUR'},
#  {'apmc_id': '135', 'apmc_name': 'CHHINDWARA'},
#  {'apmc_id': '407', 'apmc_name': 'DABRA'},
#  {'apmc_id': '4079', 'apmc_name': 'DALAUDA'},
#  {'apmc_id': '136', 'apmc_name': 'DAMOH'},
#  {'apmc_id': '418', 'apmc_name': 'DATIA'},
#  {'apmc_id': '4086', 'apmc_name': 'DEORI'},
#  {'apmc_id': '137', 'apmc_name': 'DEWAS'},
#  {'apmc_id': '395', 'apmc_name': 'DHAR'},
#  {'apmc_id': '468', 'apmc_name': 'GADARWARA'},
#  {'apmc_id': '389', 'apmc_name': 'GANJ BASODA'},
#  {'apmc_id': '4087', 'apmc_name': 'GARHAKOTA'},
#  {'apmc_id': '3929', 'apmc_name': 'GAUTAMPURA'},
#  {'apmc_id': '4166', 'apmc_name': 'GOTEGAON'},
#  {'apmc_id': '409', 'apmc_name': 'GUNA'},
#  {'apmc_id': '4096', 'apmc_name': 'HANUMANA'},
#  {'apmc_id': '138', 'apmc_name': 'HARDA'},
#  {'apmc_id': '3930', 'apmc_name': 'HARPALPUR'},
#  {'apmc_id': '3917', 'apmc_name': 'HARSUD'},
#  {'apmc_id': '139', 'apmc_name': 'INDORE'},
#  {'apmc_id': '393', 'apmc_name': 'ITARSI'},
#  {'apmc_id': '140', 'apmc_name': 'JABALPUR'},
#  {'apmc_id': '4075', 'apmc_name': 'JABERA'},
#  {'apmc_id': '141', 'apmc_name': 'JAORA'},
#  {'apmc_id': '4059', 'apmc_name': 'JHABUA'},
#  {'apmc_id': '3920', 'apmc_name': 'JOBAT'},
#  {'apmc_id': '3921', 'apmc_name': 'KARERA'},
#  {'apmc_id': '21', 'apmc_name': 'KAROND'},
#  {'apmc_id': '3922', 'apmc_name': 'KASRAWAD'},
#  {'apmc_id': '3923', 'apmc_name': 'KATANGI'},
#  {'apmc_id': '415', 'apmc_name': 'KATNI'},
#  {'apmc_id': '398', 'apmc_name': 'KHANDWA'},
#  {'apmc_id': '397', 'apmc_name': 'KHARGONE'},
#  {'apmc_id': '403', 'apmc_name': 'KHATEGAON'},
#  {'apmc_id': '4060', 'apmc_name': 'KHETIYA'},
#  {'apmc_id': '392', 'apmc_name': 'KHIRKIYA'},
#  {'apmc_id': '4097', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI PATAN'},
#  {'apmc_id': '854', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-ANJAD'},
#  {'apmc_id': '849', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-BADWAHA'},
#  {'apmc_id': '848', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-BANAPURA'},
#  {'apmc_id': '852', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-BHIKANGAON'},
#  {'apmc_id': '869', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-DHAMNOD'},
#  {'apmc_id': '856', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-GANDHWANI'},
#  {'apmc_id': '860', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-KARELI'},
#  {'apmc_id': '853', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-KARHI'},
#  {'apmc_id': '863', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-KHURAI'},
#  {'apmc_id': '866', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-KOLARAS'},
#  {'apmc_id': '857', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-KUKSHI'},
#  {'apmc_id': '864', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-KUMBHRAJ'},
#  {'apmc_id': '865', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-LASHKAR'},
#  {'apmc_id': '867', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-NAGOD'},
#  {'apmc_id': '845', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-NASRULLAGANJ'},
#  {'apmc_id': '862', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-PANDHURNA'},
#  {'apmc_id': '847', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-RAISEN'},
#  {'apmc_id': '851', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-SANAWAD'},
#  {'apmc_id': '861', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-SAUNSAR'},
#  {'apmc_id': '855', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-SHIVPURI'},
#  {'apmc_id': '868', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-SINGRAULI'},
#  {'apmc_id': '846', 'apmc_name': 'KRISHI UPAJ MANDI SAMITI-UDAIPURA'},
#  {'apmc_id': '3924', 'apmc_name': 'KURAWAR'},
#  {'apmc_id': '4078', 'apmc_name': 'LAVKUSHNAGAR'},
#  {'apmc_id': '402', 'apmc_name': 'MAHIDPUR'},
#  {'apmc_id': '4088', 'apmc_name': 'MAIHAR'},
#  {'apmc_id': '469', 'apmc_name': 'MANDLA'},
#  {'apmc_id': '142', 'apmc_name': 'MANDSAUR'},
#  {'apmc_id': '417', 'apmc_name': 'MHOW'},
#  {'apmc_id': '463', 'apmc_name': 'MORENA'},
#  {'apmc_id': '4098', 'apmc_name': 'MUNGAOLI'},
#  {'apmc_id': '3925', 'apmc_name': 'NARSINGHGARH'},
#  {'apmc_id': '143', 'apmc_name': 'NEEMUCH'},
#  {'apmc_id': '4066', 'apmc_name': 'NIWARI'},
#  {'apmc_id': '388', 'apmc_name': 'OBAIDULLAGANJ'},
#  {'apmc_id': '4061', 'apmc_name': 'PACHORE'},
#  {'apmc_id': '4156', 'apmc_name': 'PALARI'},
#  {'apmc_id': '4083', 'apmc_name': 'PANNA'},
#  {'apmc_id': '4074', 'apmc_name': 'PATHARIA'},
#  {'apmc_id': '4067', 'apmc_name': 'PETLAWAD'},
#  {'apmc_id': '4068', 'apmc_name': 'PIPALIYA'},
#  {'apmc_id': '144', 'apmc_name': 'PIPARIYA'},
#  {'apmc_id': '4072', 'apmc_name': 'RAHATGARH'},
#  {'apmc_id': '3927', 'apmc_name': 'RAJGARH'},
#  {'apmc_id': '4062', 'apmc_name': 'RAJNAGAR'},
#  {'apmc_id': '145', 'apmc_name': 'RATLAM'},
#  {'apmc_id': '4092', 'apmc_name': 'REHLI'},
#  {'apmc_id': '146', 'apmc_name': 'REWA'},
#  {'apmc_id': '147', 'apmc_name': 'SAGAR'},
#  {'apmc_id': '394', 'apmc_name': 'SANWER'},
#  {'apmc_id': '148', 'apmc_name': 'SATNA'},
#  {'apmc_id': '4069', 'apmc_name': 'SEGAON'},
#  {'apmc_id': '412', 'apmc_name': 'SEHORA'},
#  {'apmc_id': '149', 'apmc_name': 'SEHORE'},
#  {'apmc_id': '3911', 'apmc_name': 'SEMRI HARCHAND'},
#  {'apmc_id': '462', 'apmc_name': 'SENDHWA'},
#  {'apmc_id': '467', 'apmc_name': 'SEONI'},
#  {'apmc_id': '4093', 'apmc_name': 'SHAHDOL'},
#  {'apmc_id': '413', 'apmc_name': 'SHAHPURA BHITONI'},
#  {'apmc_id': '420', 'apmc_name': 'SHAJAPUR'},
#  {'apmc_id': '464', 'apmc_name': 'SHEOPURKALAN'},
#  {'apmc_id': '404', 'apmc_name': 'SHUJALPUR'},
#  {'apmc_id': '4094', 'apmc_name': 'SIDHI'},
#  {'apmc_id': '4082', 'apmc_name': 'SILWANI'},
#  {'apmc_id': '3910', 'apmc_name': 'SIRALI'},
#  {'apmc_id': '4071', 'apmc_name': 'SIRONJ'},
#  {'apmc_id': '4070', 'apmc_name': 'SONKATCH'},
#  {'apmc_id': '4155', 'apmc_name': 'THANDLA'},
#  {'apmc_id': '335', 'apmc_name': 'TIKAMGARH'},
#  {'apmc_id': '391', 'apmc_name': 'TIMARNI'},
#  {'apmc_id': '150', 'apmc_name': 'UJJAIN'},
#  {'apmc_id': '4095', 'apmc_name': 'UMARIA'},
#  {'apmc_id': '151', 'apmc_name': 'VIDISHA'},
#  {'apmc_id': '1022', 'apmc_name': 'AAMGAON'},
#  {'apmc_id': '308', 'apmc_name': 'AATPADI'},
#  {'apmc_id': '471', 'apmc_name': 'ACHALPUR'},
#  {'apmc_id': '459', 'apmc_name': 'AHERI'},
#  {'apmc_id': '401', 'apmc_name': 'AHMEDNAGAR'},
#  {'apmc_id': '299', 'apmc_name': 'AKOLA'},
#  {'apmc_id': '1023', 'apmc_name': 'AKOT'},
#  {'apmc_id': '566', 'apmc_name': 'AMALNER'},
#  {'apmc_id': '405', 'apmc_name': 'AMARAVATHI'},
#  {'apmc_id': '1024', 'apmc_name': 'AMBEJOGAI'},
#  {'apmc_id': '567', 'apmc_name': 'ANJANGAON SURJI'},
#  {'apmc_id': '460', 'apmc_name': 'ARJUNI MORGOAN'},
#  {'apmc_id': '1025', 'apmc_name': 'ARVI'},
#  {'apmc_id': '303', 'apmc_name': 'AURANGABAD'},
#  {'apmc_id': '1026', 'apmc_name': 'AUSA'},
#  {'apmc_id': '1027', 'apmc_name': 'BARAMATI'},
#  {'apmc_id': '461', 'apmc_name': 'BARSHI'},
#  {'apmc_id': '470', 'apmc_name': 'Basmat'},
#  {'apmc_id': '408', 'apmc_name': 'BEED'},
#  {'apmc_id': '1028', 'apmc_name': 'BHIWAPUR'},
#  {'apmc_id': '456', 'apmc_name': 'BHOKAR'},
#  {'apmc_id': '1029', 'apmc_name': 'CHALISGAON'},
#  {'apmc_id': '1030', 'apmc_name': 'CHAMORSHI'},
#  {'apmc_id': '568', 'apmc_name': 'CHANDRAPUR'},
#  {'apmc_id': '1031', 'apmc_name': 'CHANDUR BAZAR'},
#  {'apmc_id': '1032', 'apmc_name': 'CHANDVAD'},
#  {'apmc_id': '1033', 'apmc_name': 'CHIKHALI'},
#  {'apmc_id': '587', 'apmc_name': 'CHOPADA'},
#  {'apmc_id': '588', 'apmc_name': 'DARYAPUR'},
#  {'apmc_id': '1034', 'apmc_name': 'DEVALA'},
#  {'apmc_id': '1035', 'apmc_name': 'DHAMANGAON RAILWAY'},
#  {'apmc_id': '457', 'apmc_name': 'DHULE'},
#  {'apmc_id': '1036', 'apmc_name': 'DIGRAS'},
#  {'apmc_id': '1037', 'apmc_name': 'DINDORI'},
#  {'apmc_id': '410', 'apmc_name': 'DONDAICHA'},
#  {'apmc_id': '451', 'apmc_name': 'DOUND'},
#  {'apmc_id': '1038', 'apmc_name': 'GANGAPUR-MH'},
#  {'apmc_id': '455', 'apmc_name': 'GEVRAI'},
#  {'apmc_id': '589', 'apmc_name': 'GONDIYA'},
#  {'apmc_id': '1039', 'apmc_name': 'HINGANGHAT'},
#  {'apmc_id': '414', 'apmc_name': 'HINGOLI'},
#  {'apmc_id': '1040', 'apmc_name': 'INDAPUR'},
#  {'apmc_id': '1041', 'apmc_name': 'JALGAON'},
#  {'apmc_id': '1042', 'apmc_name': 'JALNA'},
#  {'apmc_id': '1043', 'apmc_name': 'JINTUR'},
#  {'apmc_id': '416', 'apmc_name': 'JUNNAR'},
#  {'apmc_id': '1044', 'apmc_name': 'KALAMB'},
#  {'apmc_id': '1045', 'apmc_name': 'KANNAD'},
#  {'apmc_id': '421', 'apmc_name': 'KARAD'},
#  {'apmc_id': '1046', 'apmc_name': 'KARANJA'},
#  {'apmc_id': '1047', 'apmc_name': 'KARMALA'},
#  {'apmc_id': '590', 'apmc_name': 'KATOL'},
#  {'apmc_id': '419', 'apmc_name': 'KHAMGAON'},
#  {'apmc_id': '591', 'apmc_name': 'KHED'},
#  {'apmc_id': '297', 'apmc_name': 'KOLHAPUR'},
#  {'apmc_id': '1048', 'apmc_name': 'LASALGAON'},
#  {'apmc_id': '1049', 'apmc_name': 'LASUR STATION'},
#  {'apmc_id': '300', 'apmc_name': 'LATUR'},
#  {'apmc_id': '473', 'apmc_name': 'LONAND'},
#  {'apmc_id': '592', 'apmc_name': 'LONAR'},
#  {'apmc_id': '1050', 'apmc_name': 'MAJALGAON'},
#  {'apmc_id': '474', 'apmc_name': 'MALEGOAN'},
#  {'apmc_id': '472', 'apmc_name': 'Malkapur'},
#  {'apmc_id': '1051', 'apmc_name': 'MANGALWEDHA'},
#  {'apmc_id': '422', 'apmc_name': 'MANGRULPEER'},
#  {'apmc_id': '1052', 'apmc_name': 'MANORA'},
#  {'apmc_id': '1053', 'apmc_name': 'MORSHI'},
#  {'apmc_id': '1054', 'apmc_name': 'MUL'},
#  {'apmc_id': '424', 'apmc_name': 'MUMBAI'},
#  {'apmc_id': '593', 'apmc_name': 'MURTIZAPUR'},
#  {'apmc_id': '1055', 'apmc_name': 'MURUM'},
#  {'apmc_id': '1056', 'apmc_name': 'NAGBHID'},
#  {'apmc_id': '305', 'apmc_name': 'NAGPUR'},
#  {'apmc_id': '1057', 'apmc_name': 'NAMPUR'},
#  {'apmc_id': '1058', 'apmc_name': 'NANDED'},
#  {'apmc_id': '1059', 'apmc_name': 'NANDGAON'},
#  {'apmc_id': '458', 'apmc_name': 'NANDURBAR'},
#  {'apmc_id': '425', 'apmc_name': 'NASIK'},
#  {'apmc_id': '1060', 'apmc_name': 'NER PARASOPANT'},
#  {'apmc_id': '307', 'apmc_name': 'NEWASA'},
#  {'apmc_id': '1061', 'apmc_name': 'PANDHARPUR'},
#  {'apmc_id': '304', 'apmc_name': 'PARBHANI'},
#  {'apmc_id': '1062', 'apmc_name': 'Parli Vaijyanath'},
#  {'apmc_id': '1063', 'apmc_name': 'PARTUR'},
#  {'apmc_id': '1064', 'apmc_name': 'PHALTAN'},
#  {'apmc_id': '426', 'apmc_name': 'PIMPALGAON BASWANT'},
#  {'apmc_id': '427', 'apmc_name': 'PUNE'},
#  {'apmc_id': '1065', 'apmc_name': 'RAHATA'},
#  {'apmc_id': '428', 'apmc_name': 'RAHURI'},
#  {'apmc_id': '1066', 'apmc_name': 'RISOD'},
#  {'apmc_id': '1067', 'apmc_name': 'SANGAMNER'},
#  {'apmc_id': '298', 'apmc_name': 'SANGLI'},
#  {'apmc_id': '1068', 'apmc_name': 'SANGOLA'},
#  {'apmc_id': '1069', 'apmc_name': 'SATANA'},
#  {'apmc_id': '1070', 'apmc_name': 'SAVNER'},
#  {'apmc_id': '453', 'apmc_name': 'SELU'},
#  {'apmc_id': '594', 'apmc_name': 'SENGOAN'},
#  {'apmc_id': '595', 'apmc_name': 'SHAHADA'},
#  {'apmc_id': '596', 'apmc_name': 'SHEGAON'},
#  {'apmc_id': '597', 'apmc_name': 'SHIRPUR'},
#  {'apmc_id': '306', 'apmc_name': 'SHIRUR'},
#  {'apmc_id': '1071', 'apmc_name': 'SHRIRAMPUR'},
#  {'apmc_id': '1072', 'apmc_name': 'Sindevahi'},
#  {'apmc_id': '1073', 'apmc_name': 'SINDI'},
#  {'apmc_id': '1074', 'apmc_name': 'SINNER'},
#  {'apmc_id': '429', 'apmc_name': 'SOLAPUR'},
#  {'apmc_id': '1075', 'apmc_name': 'TIRODA'},
#  {'apmc_id': '301', 'apmc_name': 'TUMSAR'},
#  {'apmc_id': '598', 'apmc_name': 'UDGIR'},
#  {'apmc_id': '1076', 'apmc_name': 'UMRANE'},
#  {'apmc_id': '1077', 'apmc_name': 'VAI'},
#  {'apmc_id': '430', 'apmc_name': 'VAIJAPUR'},
#  {'apmc_id': '452', 'apmc_name': 'VANI'},
#  {'apmc_id': '431', 'apmc_name': 'VARORA'},
#  {'apmc_id': '432', 'apmc_name': 'WARDHA'},
#  {'apmc_id': '1078', 'apmc_name': 'WASHIM'},
#  {'apmc_id': '1079', 'apmc_name': 'YAVATMAL'},
#  {'apmc_id': '302', 'apmc_name': 'YEOLA'},
#  {'apmc_id': '3849', 'apmc_name': 'DIMAPUR APMC'},
#  {'apmc_id': '3848', 'apmc_name': 'KOHIMA APMC'},
#  {'apmc_id': '3847', 'apmc_name': 'MOKOKCHUNG APMC'},
#  {'apmc_id': '3846', 'apmc_name': 'MON APMC'},
#  {'apmc_id': '3845', 'apmc_name': 'PFUTSERO APMC'},
#  {'apmc_id': '3844', 'apmc_name': 'WOKHA APMC'},
#  {'apmc_id': '3843', 'apmc_name': 'ZUNHEBOTO APMC'},
#  {'apmc_id': '4926', 'apmc_name': 'BAGHTY APMC'},
#  {'apmc_id': '4927', 'apmc_name': 'GHATASHI'},
#  {'apmc_id': '4928', 'apmc_name': 'JALUKIE'},
#  {'apmc_id': '4929', 'apmc_name': 'TULI'},
#  {'apmc_id': '4930', 'apmc_name': 'KIPHIRE'},
#  {'apmc_id': '4931', 'apmc_name': 'LONGLENG'},
#  {'apmc_id': '4932', 'apmc_name': 'NIULAND'},
#  {'apmc_id': '4933', 'apmc_name': 'PHEK'},
#  {'apmc_id': '4934', 'apmc_name': 'TENNING'},
#  {'apmc_id': '4936', 'apmc_name': 'TSEMENYU'},
#  {'apmc_id': '4937', 'apmc_name': 'TUENSANG'},
#  {'apmc_id': '4938', 'apmc_name': 'MANGKOLEMBA'},
#  {'apmc_id': '888', 'apmc_name': 'ANANDAPUR'},
#  {'apmc_id': '870', 'apmc_name': 'ANGUL'},
#  {'apmc_id': '3867', 'apmc_name': 'ATHMALLIK'},
#  {'apmc_id': '873', 'apmc_name': 'ATTABIRA'},
#  {'apmc_id': '445', 'apmc_name': 'BAHADAJHOLA'},
#  {'apmc_id': '871', 'apmc_name': 'BALASORE'},
#  {'apmc_id': '889', 'apmc_name': 'BALUGAON'},
#  {'apmc_id': '3871', 'apmc_name': 'BANKI'},
#  {'apmc_id': '874', 'apmc_name': 'BARGARH'},
#  {'apmc_id': '893', 'apmc_name': 'BARIPADA'},
#  {'apmc_id': '894', 'apmc_name': 'BETNOTI'},
#  {'apmc_id': '876', 'apmc_name': 'BHADRAK'},
#  {'apmc_id': '3850', 'apmc_name': 'BHANJANAGAR'},
#  {'apmc_id': '884', 'apmc_name': 'BHAWANIPATNA'},
#  {'apmc_id': '899', 'apmc_name': 'BONAI'},
#  {'apmc_id': '3853', 'apmc_name': 'BOUDH'},
#  {'apmc_id': '877', 'apmc_name': 'CHANDBALI'},
#  {'apmc_id': '878', 'apmc_name': 'DEOGARH'},
#  {'apmc_id': '3870', 'apmc_name': 'DHENKANAL'},
#  {'apmc_id': '880', 'apmc_name': 'DIGAPAHANDI'},
#  {'apmc_id': '898', 'apmc_name': 'DUNGURIPALI'},
#  {'apmc_id': '897', 'apmc_name': 'GUNUPUR'},
#  {'apmc_id': '879', 'apmc_name': 'HINDOL'},
#  {'apmc_id': '3856', 'apmc_name': 'HINJILICUT'},
#  {'apmc_id': '881', 'apmc_name': 'JAGATSINGHPUR'},
#  {'apmc_id': '883', 'apmc_name': 'JAJPUR'},
#  {'apmc_id': '872', 'apmc_name': 'JALESWAR'},
#  {'apmc_id': '890', 'apmc_name': 'JATNI'},
#  {'apmc_id': '891', 'apmc_name': 'JEYPORE'},
#  {'apmc_id': '3857', 'apmc_name': 'JHARSUGUDA'},
#  {'apmc_id': '3861', 'apmc_name': 'KAMAKHYANAGAR'},
#  {'apmc_id': '886', 'apmc_name': 'KANDHAMAL'},
#  {'apmc_id': '440', 'apmc_name': 'KANTABANJI'},
#  {'apmc_id': '3862', 'apmc_name': 'KARANJIA'},
#  {'apmc_id': '887', 'apmc_name': 'KENDRAPARA'},
#  {'apmc_id': '446', 'apmc_name': 'KENDUPATNA'},
#  {'apmc_id': '885', 'apmc_name': 'KESINGA'},
#  {'apmc_id': '439', 'apmc_name': 'KORAPUT'},
#  {'apmc_id': '443', 'apmc_name': 'KUCHINDA'},
#  {'apmc_id': '892', 'apmc_name': 'MALKANGIRI'},
#  {'apmc_id': '442', 'apmc_name': 'NABARANGPUR'},
#  {'apmc_id': '3863', 'apmc_name': 'NARSINGHPUR'},
#  {'apmc_id': '896', 'apmc_name': 'NIMAPARA'},
#  {'apmc_id': '875', 'apmc_name': 'PADAMPUR OD'},
#  {'apmc_id': '3897', 'apmc_name': 'PALLAHARA'},
#  {'apmc_id': '900', 'apmc_name': 'PANPOSH'},
#  {'apmc_id': '441', 'apmc_name': 'PARALAKHEMUNDI'},
#  {'apmc_id': '882', 'apmc_name': 'RAHAMA'},
#  {'apmc_id': '447', 'apmc_name': 'RAYAGADA'},
#  {'apmc_id': '448', 'apmc_name': 'SAKHIGOPAL'},
#  {'apmc_id': '3864', 'apmc_name': 'SAMBALPUR'},
#  {'apmc_id': '3865', 'apmc_name': 'TALCHER'},
#  {'apmc_id': '444', 'apmc_name': 'TIKABALI'},
#  {'apmc_id': '895', 'apmc_name': 'UDALA'},
#  {'apmc_id': '4940', 'apmc_name': 'BIRAMAHARAJPUR'},
#  {'apmc_id': '4941', 'apmc_name': 'BALANGIR'},
#  {'apmc_id': '4942', 'apmc_name': 'CHAMPUA'},
#  {'apmc_id': '4943', 'apmc_name': 'JUNAGARH'},
#  {'apmc_id': '4944', 'apmc_name': 'KEONJHAR'},
#  {'apmc_id': '4945', 'apmc_name': 'KHARIAR ROAD'},
#  {'apmc_id': '4946', 'apmc_name': 'MUKHIGUDA'},
#  {'apmc_id': '4947', 'apmc_name': 'NILGIRI'},
#  {'apmc_id': '4948', 'apmc_name': 'PATNAGARH'},
#  {'apmc_id': '4949', 'apmc_name': 'RAIRAKHOL'},
#  {'apmc_id': '4950', 'apmc_name': 'RAIRANGPUR'},
#  {'apmc_id': '4951', 'apmc_name': 'SARGIPALI'},
#  {'apmc_id': '601', 'apmc_name': 'KARAIKAL'},
#  {'apmc_id': '600', 'apmc_name': 'THATTANCHAVADY'},
#  {'apmc_id': '603', 'apmc_name': 'ABOHAR'},
#  {'apmc_id': '4100', 'apmc_name': 'AJNALA'},
#  {'apmc_id': '917', 'apmc_name': 'AMLOH APMC'},
#  {'apmc_id': '604', 'apmc_name': 'AMRITSAR'},
#  {'apmc_id': '4101', 'apmc_name': 'ATTARI'},
#  {'apmc_id': '4102', 'apmc_name': 'BALACHAUR'},
#  {'apmc_id': '4105', 'apmc_name': 'BANGA'},
#  {'apmc_id': '4103', 'apmc_name': 'BARETA'},
#  {'apmc_id': '605', 'apmc_name': 'BARNALA'},
#  {'apmc_id': '4106', 'apmc_name': 'BATALA'},
#  {'apmc_id': '606', 'apmc_name': 'BHATINDA'},
#  {'apmc_id': '915', 'apmc_name': 'BHIKHI APMC'},
#  {'apmc_id': '4109', 'apmc_name': 'BHIKHIWIND'},
#  {'apmc_id': '4110', 'apmc_name': 'BHOGPUR'},
#  {'apmc_id': '901', 'apmc_name': 'BHUCHO MANDI APMC'},
#  {'apmc_id': '902', 'apmc_name': 'BUDHLADA APMC'},
#  {'apmc_id': '4111', 'apmc_name': 'DERA BABA NANAK'},
#  {'apmc_id': '4112', 'apmc_name': 'DHURI'},
#  {'apmc_id': '4159', 'apmc_name': 'DINANAGAR'},
#  {'apmc_id': '4113', 'apmc_name': 'DUDAN SADHAN'},
#  {'apmc_id': '903', 'apmc_name': 'FARIDKOT APMC'},
#  {'apmc_id': '4114', 'apmc_name': 'FATEHGARH CHURIAN'},
#  {'apmc_id': '609', 'apmc_name': 'FATHEGARH SAHIB'},
#  {'apmc_id': '611', 'apmc_name': 'FAZILKA'},
#  {'apmc_id': '4115', 'apmc_name': 'FEROZEPUR CANTT'},
#  {'apmc_id': '904', 'apmc_name': 'FEROZEPUR CITY APMC'},
#  {'apmc_id': '613', 'apmc_name': 'GIDDERBAHA'},
#  {'apmc_id': '614', 'apmc_name': 'GONIANA'},
#  {'apmc_id': '905', 'apmc_name': 'GURDASPUR APMC'},
#  {'apmc_id': '4116', 'apmc_name': 'GURUHARSAHAI'},
#  {'apmc_id': '616', 'apmc_name': 'HOSHIYARPUR'},
#  {'apmc_id': '4157', 'apmc_name': 'JAGRAON'},
#  {'apmc_id': '4117', 'apmc_name': 'JAITO'},
#  {'apmc_id': '4118', 'apmc_name': 'JALALBAD'},
#  {'apmc_id': '617', 'apmc_name': 'JALANDHAR'},
#  {'apmc_id': '4120', 'apmc_name': 'JANDIALA GURU GEHRI'},
#  {'apmc_id': '4121', 'apmc_name': 'KALANAUR'},
#  {'apmc_id': '906', 'apmc_name': 'KAPURTHALA APMC'},
#  {'apmc_id': '4122', 'apmc_name': 'KHANAURI'},
#  {'apmc_id': '918', 'apmc_name': 'KHANNA APMC'},
#  {'apmc_id': '907', 'apmc_name': 'KHARAR APMC'},
#  {'apmc_id': '4123', 'apmc_name': 'KHEMKARAN'},
#  {'apmc_id': '908', 'apmc_name': 'KOTKAPURA APMC'},
#  {'apmc_id': '4124', 'apmc_name': 'LEHRAGAGA'},
#  {'apmc_id': '909', 'apmc_name': 'LUDHIANA APMC'},
#  {'apmc_id': '4160', 'apmc_name': 'MACHHIWARA SAHIB'},
#  {'apmc_id': '4158', 'apmc_name': 'MAKHU'},
#  {'apmc_id': '4162', 'apmc_name': 'MALERKOTLA'},
#  {'apmc_id': '910', 'apmc_name': 'MALOUT APMC'},
#  {'apmc_id': '621', 'apmc_name': 'MANSA'},
#  {'apmc_id': '620', 'apmc_name': 'MAUR'},
#  {'apmc_id': '4163', 'apmc_name': 'MEHTA'},
#  {'apmc_id': '911', 'apmc_name': 'MOGA APMC'},
#  {'apmc_id': '4126', 'apmc_name': 'MOONAK'},
#  {'apmc_id': '622', 'apmc_name': 'MUKTSAR'},
#  {'apmc_id': '4141', 'apmc_name': 'NABHA'},
#  {'apmc_id': '4161', 'apmc_name': 'NAKODAR'},
#  {'apmc_id': '4127', 'apmc_name': 'NAUSHEHARA PANNUAN'},
#  {'apmc_id': '912', 'apmc_name': 'NAWANSHAHR MARKET'},
#  {'apmc_id': '624', 'apmc_name': 'PATHANKOT'},
#  {'apmc_id': '625', 'apmc_name': 'PATIALA'},
#  {'apmc_id': '4128', 'apmc_name': 'PATRAN'},
#  {'apmc_id': '4129', 'apmc_name': 'PATTI'},
#  {'apmc_id': '4130', 'apmc_name': 'PHAGWARA'},
#  {'apmc_id': '4131', 'apmc_name': 'RAJPURA'},
#  {'apmc_id': '913', 'apmc_name': 'RAMAN APMC'},
#  {'apmc_id': '626', 'apmc_name': 'RAMPURA PHUL'},
#  {'apmc_id': '4132', 'apmc_name': 'RAYYA'},
#  {'apmc_id': '627', 'apmc_name': 'ROPAR'},
#  {'apmc_id': '4133', 'apmc_name': 'SADIQ'},
#  {'apmc_id': '4134', 'apmc_name': 'SAMANA'},
#  {'apmc_id': '631', 'apmc_name': 'SANGRUR'},
#  {'apmc_id': '914', 'apmc_name': 'SARDULGARH APMC'},
#  {'apmc_id': '4135', 'apmc_name': 'SHAHKOT'},
#  {'apmc_id': '4137', 'apmc_name': 'SULTANPUR LODHI'},
#  {'apmc_id': '4138', 'apmc_name': 'SUNAM'},
#  {'apmc_id': '4139', 'apmc_name': 'TALWANDI BHAI'},
#  {'apmc_id': '632', 'apmc_name': 'TAPPA'},
#  {'apmc_id': '916', 'apmc_name': 'TARN TARAN APMC'},
#  {'apmc_id': '1080', 'apmc_name': 'AABU ROAD'},
#  {'apmc_id': '1082', 'apmc_name': 'AJMER F AND V'},
#  {'apmc_id': '1081', 'apmc_name': 'AJMER GRAIN'},
#  {'apmc_id': '1083', 'apmc_name': 'ALWAR'},
#  {'apmc_id': '1084', 'apmc_name': 'ANOOPGARH'},
#  {'apmc_id': '1085', 'apmc_name': 'ANTA'},
#  {'apmc_id': '163', 'apmc_name': 'ATRU'},
#  {'apmc_id': '1086', 'apmc_name': 'BAJJU'},
#  {'apmc_id': '1087', 'apmc_name': 'BALOTRA'},
#  {'apmc_id': '323', 'apmc_name': 'BANDIKUI'},
#  {'apmc_id': '1088', 'apmc_name': 'BANSWARA'},
#  {'apmc_id': '164', 'apmc_name': 'BARAN'},
#  {'apmc_id': '1090', 'apmc_name': 'BARISADRI'},
#  {'apmc_id': '1091', 'apmc_name': 'BARMER'},
#  {'apmc_id': '1092', 'apmc_name': 'BARODAMEV'},
#  {'apmc_id': '1093', 'apmc_name': 'BASSI'},
#  {'apmc_id': '1094', 'apmc_name': 'BAYANA'},
#  {'apmc_id': '1095', 'apmc_name': 'BEAWAR'},
#  {'apmc_id': '1096', 'apmc_name': 'BEGU'},
#  {'apmc_id': '1097', 'apmc_name': 'BHADRA'},
#  {'apmc_id': '1098', 'apmc_name': 'BHAGAT KI KOTHI'},
#  {'apmc_id': '1099', 'apmc_name': 'BHARATPUR'},
#  {'apmc_id': '1100', 'apmc_name': 'BHAWANI MANDI'},
#  {'apmc_id': '1101', 'apmc_name': 'BHILWARA'},
#  {'apmc_id': '1102', 'apmc_name': 'BHINMAL'},
#  {'apmc_id': '1103', 'apmc_name': 'BIJAY NAGAR'},
#  {'apmc_id': '1104', 'apmc_name': 'BIJOLIYA'},
#  {'apmc_id': '1105', 'apmc_name': 'BIKANER F AND V'},
#  {'apmc_id': '333', 'apmc_name': 'BIKANER GRAIN'},
#  {'apmc_id': '1106', 'apmc_name': 'BILARA'},
#  {'apmc_id': '165', 'apmc_name': 'BUNDI'},
#  {'apmc_id': '1107', 'apmc_name': 'CHABRA'},
#  {'apmc_id': '1108', 'apmc_name': 'CHAKSU'},
#  {'apmc_id': '1109', 'apmc_name': 'CHIRAWA'},
#  {'apmc_id': '1110', 'apmc_name': 'CHITTORGARH'},
#  {'apmc_id': '1111', 'apmc_name': 'CHOMEHLA'},
#  {'apmc_id': '1113', 'apmc_name': 'CHOMU F AND V'},
#  {'apmc_id': '1112', 'apmc_name': 'CHOMU GRAIN'},
#  {'apmc_id': '1114', 'apmc_name': 'CHOTTISADRI'},
#  {'apmc_id': '1115', 'apmc_name': 'CHURU'},
#  {'apmc_id': '1116', 'apmc_name': 'DAUSA'},
#  {'apmc_id': '1117', 'apmc_name': 'DEEDWANA'},
#  {'apmc_id': '1118', 'apmc_name': 'DEEG'},
#  {'apmc_id': '1119', 'apmc_name': 'DEGANA'},
#  {'apmc_id': '1120', 'apmc_name': 'DEI'},
#  {'apmc_id': '324', 'apmc_name': 'DEOLI'},
#  {'apmc_id': '1121', 'apmc_name': 'DHOLPUR'},
#  {'apmc_id': '1122', 'apmc_name': 'DOONI'},
#  {'apmc_id': '1123', 'apmc_name': 'DUNGARPUR'},
#  {'apmc_id': '169', 'apmc_name': 'FATEHNAGAR'},
#  {'apmc_id': '1124', 'apmc_name': 'FATEHPUR'},
#  {'apmc_id': '1125', 'apmc_name': 'GAJSINGHPUR'},
#  {'apmc_id': '166', 'apmc_name': 'GANGAPUR CITY'},
#  {'apmc_id': '1126', 'apmc_name': 'GANGAPUR-RJ'},
#  {'apmc_id': '1127', 'apmc_name': 'GHARSANA'},
#  {'apmc_id': '1128', 'apmc_name': 'GOLUWALA'},
#  {'apmc_id': '1129', 'apmc_name': 'GUDA GODJI'},
#  {'apmc_id': '1130', 'apmc_name': 'HANUMANGARH'},
#  {'apmc_id': '3842', 'apmc_name': 'HANUMANGARH TOWN'},
#  {'apmc_id': '167', 'apmc_name': 'HINDOUN'},
#  {'apmc_id': '1131', 'apmc_name': 'IKLERA'},
#  {'apmc_id': '1132', 'apmc_name': 'ITAWA'},
#  {'apmc_id': '1133', 'apmc_name': 'JAIPUR F AND V MUHANA'},
#  {'apmc_id': '1134', 'apmc_name': 'JAIPUR GRAIN'},
#  {'apmc_id': '1135', 'apmc_name': 'JAISALMER'},
#  {'apmc_id': '1136', 'apmc_name': 'JAITARAN'},
#  {'apmc_id': '1137', 'apmc_name': 'JAITSAR'},
#  {'apmc_id': '1138', 'apmc_name': 'JALORE'},
#  {'apmc_id': '1139', 'apmc_name': 'JHALRAPATAN'},
#  {'apmc_id': '1140', 'apmc_name': 'JHUNJHUNU'},
#  {'apmc_id': '1141', 'apmc_name': 'JODHPUR F AND V'},
#  {'apmc_id': '322', 'apmc_name': 'JODHPUR GRAIN'},
#  {'apmc_id': '326', 'apmc_name': 'KAMAN'},
#  {'apmc_id': '1142', 'apmc_name': 'KAPASAN'},
#  {'apmc_id': '1143', 'apmc_name': 'KEKRI'},
#  {'apmc_id': '332', 'apmc_name': 'KESHORAIPATAN'},
#  {'apmc_id': '1144', 'apmc_name': 'KESRISINGHPUR'},
#  {'apmc_id': '1145', 'apmc_name': 'KHAIRTHAL'},
#  {'apmc_id': '1146', 'apmc_name': 'KHAJUWALA'},
#  {'apmc_id': '1147', 'apmc_name': 'KHANPUR'},
#  {'apmc_id': '1148', 'apmc_name': 'KHERLI'},
#  {'apmc_id': '1149', 'apmc_name': 'KISHANGARH RENWAL'},
#  {'apmc_id': '168', 'apmc_name': 'KOTA'},
#  {'apmc_id': '1150', 'apmc_name': 'KOTA F AND V'},
#  {'apmc_id': '1151', 'apmc_name': 'KOTPUTLI'},
#  {'apmc_id': '1152', 'apmc_name': 'KUCHAMANCITY'},
#  {'apmc_id': '1154', 'apmc_name': 'LALSOT'},
#  {'apmc_id': '1155', 'apmc_name': 'LOONKARANSAR'},
#  {'apmc_id': '1156', 'apmc_name': 'M. KISHANGARH'},
#  {'apmc_id': '1159', 'apmc_name': 'MAHUWA MANDAWAR'},
#  {'apmc_id': '1157', 'apmc_name': 'MAHUWA RJ'},
#  {'apmc_id': '1089', 'apmc_name': 'MALPURA'},
#  {'apmc_id': '1158', 'apmc_name': 'MANDALGARH'},
#  {'apmc_id': '327', 'apmc_name': 'MANDAWARI'},
#  {'apmc_id': '170', 'apmc_name': 'MERTA CITY'},
#  {'apmc_id': '328', 'apmc_name': 'NADBAI'},
#  {'apmc_id': '423', 'apmc_name': 'NAGAR'},
#  {'apmc_id': '230', 'apmc_name': 'NAGOUR'},
#  {'apmc_id': '1160', 'apmc_name': 'NAWALGARH'},
#  {'apmc_id': '1161', 'apmc_name': 'NEEM KA THANA'},
#  {'apmc_id': '1162', 'apmc_name': 'NIMBAHERA'},
#  {'apmc_id': '321', 'apmc_name': 'NIWAI'},
#  {'apmc_id': '1163', 'apmc_name': 'NOHAR'},
#  {'apmc_id': '329', 'apmc_name': 'NOKHA'},
#  {'apmc_id': '171', 'apmc_name': 'PADAMPUR'},
#  {'apmc_id': '1164', 'apmc_name': 'PALI'},
#  {'apmc_id': '1165', 'apmc_name': 'PALSANA'},
#  {'apmc_id': '1166', 'apmc_name': 'PHALODI'},
#  {'apmc_id': '1167', 'apmc_name': 'PILIBANGA'},
#  {'apmc_id': '1168', 'apmc_name': 'PIPARCITY'},
#  {'apmc_id': '1169', 'apmc_name': 'PRATAPGARH RJ'},
#  {'apmc_id': '1170', 'apmc_name': 'RAISINGHNAGAR'},
#  {'apmc_id': '1153', 'apmc_name': 'RAJDHANI MANDI KUKARKHERA'},
#  {'apmc_id': '1171', 'apmc_name': 'RAJSAMAND'},
#  {'apmc_id': '27', 'apmc_name': 'RAMGANJ MANDI'},
#  {'apmc_id': '1172', 'apmc_name': 'RANI'},
#  {'apmc_id': '1173', 'apmc_name': 'RANIWARA'},
#  {'apmc_id': '1174', 'apmc_name': 'RATANGARH'},
#  {'apmc_id': '1175', 'apmc_name': 'RAWATSAR'},
#  {'apmc_id': '1176', 'apmc_name': 'RAWLA'},
#  {'apmc_id': '1177', 'apmc_name': 'RIDMALSAR'},
#  {'apmc_id': '1178', 'apmc_name': 'SADULPUR'},
#  {'apmc_id': '1179', 'apmc_name': 'SADULSHAHAR'},
#  {'apmc_id': '1180', 'apmc_name': 'SANCHORE'},
#  {'apmc_id': '1181', 'apmc_name': 'SANGARIYA'},
#  {'apmc_id': '1182', 'apmc_name': 'SARDAR SHAHAR'},
#  {'apmc_id': '1183', 'apmc_name': 'SAWAI MADHOPUR'},
#  {'apmc_id': '1184', 'apmc_name': 'SHAHPURA'},
#  {'apmc_id': '1185', 'apmc_name': 'SIKAR'},
#  {'apmc_id': '1186', 'apmc_name': 'SOJAT ROAD'},
#  {'apmc_id': '1187', 'apmc_name': 'SRI DUNGARGARH'},
#  {'apmc_id': '325', 'apmc_name': 'SRI GANGANAGAR GRAIN'},
#  {'apmc_id': '330', 'apmc_name': 'SRI MADHOPUR'},
#  {'apmc_id': '1190', 'apmc_name': 'SRI VIJAYNAGAR'},
#  {'apmc_id': '1188', 'apmc_name': 'SRIGANGANAGAR F AND V'},
#  {'apmc_id': '1189', 'apmc_name': 'SRIKARANPUR'},
#  {'apmc_id': '1191', 'apmc_name': 'SUJANGARH'},
#  {'apmc_id': '1192', 'apmc_name': 'SUMERGANJ'},
#  {'apmc_id': '331', 'apmc_name': 'SUMERPUR'},
#  {'apmc_id': '1193', 'apmc_name': 'SURAJGARH'},
#  {'apmc_id': '1194', 'apmc_name': 'SURATGARH'},
#  {'apmc_id': '1195', 'apmc_name': 'TONK'},
#  {'apmc_id': '1196', 'apmc_name': 'UDAIPUR F AND V'},
#  {'apmc_id': '1197', 'apmc_name': 'UDAIPUR GRAIN'},
#  {'apmc_id': '1198', 'apmc_name': 'UNIYARA'},
#  {'apmc_id': '3962', 'apmc_name': 'ALANGUDI'},
#  {'apmc_id': '3964', 'apmc_name': 'AMBASAMUTHIRAM'},
#  {'apmc_id': '520', 'apmc_name': 'AMMOOR'},
#  {'apmc_id': '682', 'apmc_name': 'ANAIMALAI'},
#  {'apmc_id': '510', 'apmc_name': 'ANNUR'},
#  {'apmc_id': '514', 'apmc_name': 'ANTHIYUR'},
#  {'apmc_id': '920', 'apmc_name': 'ARANI'},
#  {'apmc_id': '3965', 'apmc_name': 'ARANTHANGI'},
#  {'apmc_id': '3966', 'apmc_name': 'ARCOT'},
#  {'apmc_id': '3967', 'apmc_name': 'ATTHUR'},
#  {'apmc_id': '3968', 'apmc_name': 'AVALPOONDURAI'},
#  {'apmc_id': '952', 'apmc_name': 'AVALURPET'},
#  {'apmc_id': '3969', 'apmc_name': 'BATLAGUNDU'},
#  {'apmc_id': '3970', 'apmc_name': 'BODINAYAKANUR'},
#  {'apmc_id': '3971', 'apmc_name': 'BOOTHAPADI'},
#  {'apmc_id': '3972', 'apmc_name': 'BUDALUR'},
#  {'apmc_id': '924', 'apmc_name': 'CHETPET'},
#  {'apmc_id': '919', 'apmc_name': 'CHEYYAR'},
#  {'apmc_id': '3973', 'apmc_name': 'CHINNAMANUR'},
#  ...]

# %%
def date_range(start_date: str, end_date: str):
    """
    Yields date strings (YYYY-MM-DD) from start_date to end_date inclusive.
    """
    start = datetime.strptime(start_date, "%Y-%m-%d").date()
    end = datetime.strptime(end_date, "%Y-%m-%d").date()

    current = start
    while current <= end:
        yield current.strftime("%Y-%m-%d")
        current += timedelta(days=1)

# %%
date_range("2025-08-01", "2025-08-12")
# Out:
# <generator object date_range at 0x111635e70>

# %%
def save_jsonl_gz(data: list, jsonl_path: str) -> None:
    """
    Append DataFrame rows to a JSONL file (one JSON object per line).
    """
    if not data:
        return
    with gzip.open(jsonl_path, "wt", encoding="utf-8") as f:
        for row in data:
            f.write(json.dumps(row, ensure_ascii=False) + "\n")

# %%
def to_date(s: str) -> datetime:
    """
    Parse a date string into a datetime object.
    Supports common formats like:
    - YYYY-MM-DD
    - DD-MM-YYYY
    - DD/MM/YYYY
    - YYYY/MM/DD
    - MM/DD/YYYY
    """
    try:
        return datetime.fromisoformat(s)  # handles YYYY-MM-DD
    except ValueError:
        for fmt in ("%d-%m-%Y", "%d/%m/%Y", "%Y/%m/%d", "%m/%d/%Y"):
            try:
                return datetime.strptime(s, fmt)
            except ValueError:
                continue
    raise ValueError(f"Unrecognized date format: {s}")

# %%
def get_trade_data(date_str: str) -> list:
    url = "https://enam.gov.in/web/Ajax_ctrl/trade_data_list"
    payload = {
        "language": "en",
        "stateName": "-- All --",
        "apmcName": "-- Select APMCs --",
        "commodityName": "-- Select Commodity --"    
    }
    payload["fromDate"] = date_str
    payload["toDate"] = date_str
    response = requests.post(url, data=payload, headers=headers)
    return response.json()['data']

# %%
get_trade_data("2025-08-12")
# Out:
# [{'id': '32145869',
#   'state': 'ODISHA',
#   'apmc': 'SAKHIGOPAL',
#   'commodity': 'COCONUT',
#   'min_price': '7',
#   'modal_price': '7',
#   'max_price': '30',
#   'commodity_arrivals': '183352',
#   'commodity_traded': '183332',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Nos'},
#  {'id': '32147785',
#   'state': 'RAJASTHAN',
#   'apmc': 'MANDAWARI',
#   'commodity': 'MUSTARD',
#   'min_price': '6249',
#   'modal_price': '6934',
#   'max_price': '7000',
#   'commodity_arrivals': '3192',
#   'commodity_traded': '16524',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148596',
#   'state': 'RAJASTHAN',
#   'apmc': 'UDAIPUR F AND V',
#   'commodity': 'COCONUT',
#   'min_price': '15',
#   'modal_price': '15',
#   'max_price': '30',
#   'commodity_arrivals': '16200',
#   'commodity_traded': '16200',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Nos'},
#  {'id': '32147782',
#   'state': 'RAJASTHAN',
#   'apmc': 'MANDAWARI',
#   'commodity': 'WHEAT',
#   'min_price': '2100',
#   'modal_price': '2467',
#   'max_price': '2564',
#   'commodity_arrivals': '2578',
#   'commodity_traded': '15748',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32145973',
#   'state': 'PUNJAB',
#   'apmc': 'KHANNA APMC',
#   'commodity': 'MAIZE',
#   'min_price': '1900',
#   'modal_price': '2010',
#   'max_price': '2100',
#   'commodity_arrivals': '13321',
#   'commodity_traded': '13321',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149377',
#   'state': 'TAMIL NADU',
#   'apmc': 'VADAMADURAI',
#   'commodity': 'COCONUT',
#   'min_price': '10',
#   'modal_price': '10',
#   'max_price': '10',
#   'commodity_arrivals': '10000',
#   'commodity_traded': '10000',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Nos'},
#  {'id': '32144392',
#   'state': 'MAHARASHTRA',
#   'apmc': 'VAIJAPUR',
#   'commodity': 'ONION',
#   'min_price': '325',
#   'modal_price': '500',
#   'max_price': '1450',
#   'commodity_arrivals': '2191',
#   'commodity_traded': '6852',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144020',
#   'state': 'MAHARASHTRA',
#   'apmc': 'ATPADI',
#   'commodity': 'POMEGRANATE - BHAGAWA',
#   'min_price': '13',
#   'modal_price': '28',
#   'max_price': '60',
#   'commodity_arrivals': '206840',
#   'commodity_traded': '6460',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Kg'},
#  {'id': '32143015',
#   'state': 'HARYANA',
#   'apmc': 'TARAORI',
#   'commodity': 'PADDY-BASMATI1509',
#   'min_price': '1750',
#   'modal_price': '2850',
#   'max_price': '2950',
#   'commodity_arrivals': '455',
#   'commodity_traded': '5390',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32139856',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'ANANTHAPURAMU',
#   'commodity': 'MOUSAMBI',
#   'min_price': '650',
#   'modal_price': '1000',
#   'max_price': '1750',
#   'commodity_arrivals': '3565',
#   'commodity_traded': '5109',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143904',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'TIKAMGARH',
#   'commodity': 'WHEAT',
#   'min_price': '2565',
#   'modal_price': '2585',
#   'max_price': '2615',
#   'commodity_arrivals': '3258',
#   'commodity_traded': '4512',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144351',
#   'state': 'MAHARASHTRA',
#   'apmc': 'SANGAMNER',
#   'commodity': 'ONION',
#   'min_price': '75',
#   'modal_price': '511',
#   'max_price': '888',
#   'commodity_arrivals': '5136',
#   'commodity_traded': '4321',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143626',
#   'state': 'KARNATAKA',
#   'apmc': 'APMC KALBURGI',
#   'commodity': 'TUR/ARHAR',
#   'min_price': '5400',
#   'modal_price': '6400',
#   'max_price': '6629',
#   'commodity_arrivals': '3705',
#   'commodity_traded': '4292',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147688',
#   'state': 'RAJASTHAN',
#   'apmc': 'KOTA',
#   'commodity': 'GARLIC',
#   'min_price': '4500',
#   'modal_price': '6925',
#   'max_price': '7625',
#   'commodity_arrivals': '6668',
#   'commodity_traded': '4000',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32141768',
#   'state': 'HARYANA',
#   'apmc': 'INDRI',
#   'commodity': 'PADDY-BASMATI1509',
#   'min_price': '1800',
#   'modal_price': '2925',
#   'max_price': '2980',
#   'commodity_arrivals': '140',
#   'commodity_traded': '3867',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147267',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'COCONUT DEHUSKED IN QUINTAL',
#   'min_price': '3000',
#   'modal_price': '3000',
#   'max_price': '5500',
#   'commodity_arrivals': '978',
#   'commodity_traded': '3784',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147702',
#   'state': 'RAJASTHAN',
#   'apmc': 'KOTA F AND V',
#   'commodity': 'ONION RED',
#   'min_price': '275',
#   'modal_price': '325',
#   'max_price': '1000',
#   'commodity_arrivals': '3705',
#   'commodity_traded': '3670',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148870',
#   'state': 'TAMIL NADU',
#   'apmc': 'GINGEE',
#   'commodity': 'PADDY(75 KG)',
#   'min_price': '1386',
#   'modal_price': '1870',
#   'max_price': '4134',
#   'commodity_arrivals': '3497',
#   'commodity_traded': '3425',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32139966',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'GUNTUR',
#   'commodity': 'CHILLI-TEJA',
#   'min_price': '4500',
#   'modal_price': '11000',
#   'max_price': '15200',
#   'commodity_arrivals': '6038',
#   'commodity_traded': '3295',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147327',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'GREEN CHILLI',
#   'min_price': '3000',
#   'modal_price': '3000',
#   'max_price': '3500',
#   'commodity_arrivals': '2018',
#   'commodity_traded': '3124',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149106',
#   'state': 'TAMIL NADU',
#   'apmc': 'POLLACHI',
#   'commodity': 'TENDER COCONUT (IN NO)',
#   'min_price': '4',
#   'modal_price': '4',
#   'max_price': '4',
#   'commodity_arrivals': '3000',
#   'commodity_traded': '3000',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Nos'},
#  {'id': '32148781',
#   'state': 'TAMIL NADU',
#   'apmc': 'CHETPET',
#   'commodity': 'PADDY(75 KG)',
#   'min_price': '1422',
#   'modal_price': '2346',
#   'max_price': '2492',
#   'commodity_arrivals': '2901',
#   'commodity_traded': '2947',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140133',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'YEMMIGANUR',
#   'commodity': 'GROUND NUT',
#   'min_price': '3690',
#   'modal_price': '6900',
#   'max_price': '7100',
#   'commodity_arrivals': '1740',
#   'commodity_traded': '2915',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140172',
#   'state': 'CHHATTISGARH',
#   'apmc': 'BHATAPARA',
#   'commodity': 'PADDY COMMON',
#   'min_price': '1870',
#   'modal_price': '2011',
#   'max_price': '2309',
#   'commodity_arrivals': '2563',
#   'commodity_traded': '2796',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147294',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'GARLIC',
#   'min_price': '2000',
#   'modal_price': '2000',
#   'max_price': '7000',
#   'commodity_arrivals': '1613',
#   'commodity_traded': '2728',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143735',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'JABALPUR',
#   'commodity': 'MOONG WHOLE (GREEN GRAM)',
#   'min_price': '3000',
#   'modal_price': '6700',
#   'max_price': '7650',
#   'commodity_arrivals': '589',
#   'commodity_traded': '2593',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140687',
#   'state': 'HARYANA',
#   'apmc': 'ADAMPUR',
#   'commodity': 'GUAR SEEDS',
#   'min_price': '2700',
#   'modal_price': '4811',
#   'max_price': '5018',
#   'commodity_arrivals': '1212',
#   'commodity_traded': '2590',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148287',
#   'state': 'RAJASTHAN',
#   'apmc': 'SIKAR',
#   'commodity': 'ONION',
#   'min_price': '400',
#   'modal_price': '700',
#   'max_price': '1300',
#   'commodity_arrivals': '389',
#   'commodity_traded': '2557',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147349',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'TOMATO',
#   'min_price': '4500',
#   'modal_price': '4500',
#   'max_price': '4500',
#   'commodity_arrivals': '4404',
#   'commodity_traded': '2519',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149396',
#   'state': 'TAMIL NADU',
#   'apmc': 'VANDAVASI',
#   'commodity': 'PADDY(75 KG)',
#   'min_price': '1454',
#   'modal_price': '2183',
#   'max_price': '2226',
#   'commodity_arrivals': '2562',
#   'commodity_traded': '2502',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147340',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'POTATO',
#   'min_price': '1400',
#   'modal_price': '1400',
#   'max_price': '1400',
#   'commodity_arrivals': '3803',
#   'commodity_traded': '2446',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143780',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'KRISHI UPAJ MANDI SAMITI-DHAMNOD',
#   'commodity': 'MAIZE',
#   'min_price': '1900',
#   'modal_price': '2000',
#   'max_price': '2273',
#   'commodity_arrivals': '0',
#   'commodity_traded': '2433',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144110',
#   'state': 'MAHARASHTRA',
#   'apmc': 'KARANJA',
#   'commodity': 'SOYABEANS',
#   'min_price': '3910',
#   'modal_price': '4740',
#   'max_price': '4875',
#   'commodity_arrivals': '5160',
#   'commodity_traded': '2395',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144008',
#   'state': 'MAHARASHTRA',
#   'apmc': 'AMRAVATI',
#   'commodity': 'TUR/ARHAR',
#   'min_price': '6150',
#   'modal_price': '6387',
#   'max_price': '6414',
#   'commodity_arrivals': '3657',
#   'commodity_traded': '2218',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149118',
#   'state': 'TAMIL NADU',
#   'apmc': 'POLUR',
#   'commodity': 'PADDY RNR (TN)',
#   'min_price': '1408',
#   'modal_price': '2334',
#   'max_price': '2375',
#   'commodity_arrivals': '2250',
#   'commodity_traded': '2153',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149864',
#   'state': 'UTTAR PRADESH',
#   'apmc': 'BAHRAICH',
#   'commodity': 'WHEAT',
#   'min_price': '2500',
#   'modal_price': '2500',
#   'max_price': '2500',
#   'commodity_arrivals': '2125',
#   'commodity_traded': '2125',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148699',
#   'state': 'TAMIL NADU',
#   'apmc': 'AMMOOR',
#   'commodity': 'PADDY(75 KG)',
#   'min_price': '1479',
#   'modal_price': '1999',
#   'max_price': '2307',
#   'commodity_arrivals': '2100',
#   'commodity_traded': '2112',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147667',
#   'state': 'RAJASTHAN',
#   'apmc': 'KOTA',
#   'commodity': 'SOYABEANS',
#   'min_price': '3201',
#   'modal_price': '4701',
#   'max_price': '4801',
#   'commodity_arrivals': '2660',
#   'commodity_traded': '2103',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147804',
#   'state': 'RAJASTHAN',
#   'apmc': 'MERTA CITY',
#   'commodity': 'CUMMIN',
#   'min_price': '12500',
#   'modal_price': '18500',
#   'max_price': '20000',
#   'commodity_arrivals': '742',
#   'commodity_traded': '2101',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143928',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'VIDISHA',
#   'commodity': 'WHEAT',
#   'min_price': '2510',
#   'modal_price': '2700',
#   'max_price': '3555',
#   'commodity_arrivals': '2084',
#   'commodity_traded': '2084',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147296',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'GINGER',
#   'min_price': '3500',
#   'modal_price': '6500',
#   'max_price': '6500',
#   'commodity_arrivals': '1138',
#   'commodity_traded': '2082',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147274',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'BANANA',
#   'min_price': '2000',
#   'modal_price': '3400',
#   'max_price': '3400',
#   'commodity_arrivals': '1839',
#   'commodity_traded': '2008',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140196',
#   'state': 'CHHATTISGARH',
#   'apmc': 'DHAMTARI',
#   'commodity': 'PADDY IR64 NEW',
#   'min_price': '1750',
#   'modal_price': '1947',
#   'max_price': '1955',
#   'commodity_arrivals': '1923',
#   'commodity_traded': '1905',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147597',
#   'state': 'RAJASTHAN',
#   'apmc': 'KHAIRTHAL',
#   'commodity': 'MUSTARD',
#   'min_price': '5260',
#   'modal_price': '6895',
#   'max_price': '7588',
#   'commodity_arrivals': '1211',
#   'commodity_traded': '1831',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148729',
#   'state': 'TAMIL NADU',
#   'apmc': 'ARANI',
#   'commodity': 'PADDY(75 KG)',
#   'min_price': '1626',
#   'modal_price': '2039',
#   'max_price': '2160',
#   'commodity_arrivals': '1841',
#   'commodity_traded': '1830',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147291',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'CORIANDAR',
#   'min_price': '1500',
#   'modal_price': '3000',
#   'max_price': '4000',
#   'commodity_arrivals': '741',
#   'commodity_traded': '1825',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147299',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'MOUSAMBI',
#   'min_price': '2250',
#   'modal_price': '2250',
#   'max_price': '2250',
#   'commodity_arrivals': '927',
#   'commodity_traded': '1824',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147997',
#   'state': 'RAJASTHAN',
#   'apmc': 'PILIBANGA',
#   'commodity': 'WHEAT',
#   'min_price': '2275',
#   'modal_price': '2340',
#   'max_price': '2654',
#   'commodity_arrivals': '1816',
#   'commodity_traded': '1816',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32151018',
#   'state': 'UTTARAKHAND',
#   'apmc': 'HALDWANI',
#   'commodity': 'WHEAT',
#   'min_price': '2500',
#   'modal_price': '2500',
#   'max_price': '2500',
#   'commodity_arrivals': '1778',
#   'commodity_traded': '1778',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147662',
#   'state': 'RAJASTHAN',
#   'apmc': 'KOTA',
#   'commodity': 'MUSTARD',
#   'min_price': '5960',
#   'modal_price': '6240',
#   'max_price': '7050',
#   'commodity_arrivals': '306',
#   'commodity_traded': '1745',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32139906',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'GUNTUR',
#   'commodity': 'CHILLI-334',
#   'min_price': '4000',
#   'modal_price': '12000',
#   'max_price': '13800',
#   'commodity_arrivals': '3944',
#   'commodity_traded': '1718',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148797',
#   'state': 'TAMIL NADU',
#   'apmc': 'CHEYYAR',
#   'commodity': 'PADDY(75 KG)',
#   'min_price': '1547',
#   'modal_price': '1876',
#   'max_price': '2142',
#   'commodity_arrivals': '1672',
#   'commodity_traded': '1706',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143650',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'BIAORA',
#   'commodity': 'WHEAT',
#   'min_price': '2550',
#   'modal_price': '2650',
#   'max_price': '2690',
#   'commodity_arrivals': '1677',
#   'commodity_traded': '1677',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147336',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'ONION',
#   'min_price': '1800',
#   'modal_price': '1800',
#   'max_price': '1800',
#   'commodity_arrivals': '4073',
#   'commodity_traded': '1653',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140088',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'PALAMANER',
#   'commodity': 'TOMATO',
#   'min_price': '3400',
#   'modal_price': '4000',
#   'max_price': '4000',
#   'commodity_arrivals': '1620',
#   'commodity_traded': '1620',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32145965',
#   'state': 'PUNJAB',
#   'apmc': 'JAGRAON',
#   'commodity': 'MOONG WHOLE (GREEN GRAM)',
#   'min_price': '2200',
#   'modal_price': '6100',
#   'max_price': '6940',
#   'commodity_arrivals': '1584',
#   'commodity_traded': '1584',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149959',
#   'state': 'UTTAR PRADESH',
#   'apmc': 'BILSI',
#   'commodity': 'MAIZE',
#   'min_price': '1950',
#   'modal_price': '1950',
#   'max_price': '1950',
#   'commodity_arrivals': '1560',
#   'commodity_traded': '1560',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147788',
#   'state': 'RAJASTHAN',
#   'apmc': 'MANDAWARI',
#   'commodity': 'CHANA (BENGAL GRAM)',
#   'min_price': '5700',
#   'modal_price': '5712',
#   'max_price': '5900',
#   'commodity_arrivals': '979',
#   'commodity_traded': '1541',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143873',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'SAGAR',
#   'commodity': 'WHEAT',
#   'min_price': '2575',
#   'modal_price': '2635',
#   'max_price': '2655',
#   'commodity_arrivals': '1538',
#   'commodity_traded': '1532',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143759',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'KHANDWA',
#   'commodity': 'WHEAT',
#   'min_price': '2500',
#   'modal_price': '2767',
#   'max_price': '3739',
#   'commodity_arrivals': '1289',
#   'commodity_traded': '1531',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143252',
#   'state': 'HIMACHAL PRADESH',
#   'apmc': 'BHATTAKUFAR DHALLI',
#   'commodity': 'APPLE',
#   'min_price': '5000',
#   'modal_price': '5000',
#   'max_price': '5000',
#   'commodity_arrivals': '1532',
#   'commodity_traded': '1525',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140239',
#   'state': 'CHHATTISGARH',
#   'apmc': 'KURUD',
#   'commodity': 'PADDY-MTU 1010',
#   'min_price': '1650',
#   'modal_price': '1927',
#   'max_price': '1930',
#   'commodity_arrivals': '1830',
#   'commodity_traded': '1492',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32141506',
#   'state': 'HARYANA',
#   'apmc': 'GURGAON',
#   'commodity': 'POTATO',
#   'min_price': '1255',
#   'modal_price': '1455',
#   'max_price': '1955',
#   'commodity_arrivals': '1483',
#   'commodity_traded': '1483',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32145985',
#   'state': 'PUNJAB',
#   'apmc': 'PHAGWARA',
#   'commodity': 'MAIZE',
#   'min_price': '2100',
#   'modal_price': '2122',
#   'max_price': '2122',
#   'commodity_arrivals': '4882',
#   'commodity_traded': '1468',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32139973',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'GUNTUR',
#   'commodity': 'CHILLI-THAALU',
#   'min_price': '3000',
#   'modal_price': '5000',
#   'max_price': '11700',
#   'commodity_arrivals': '4028',
#   'commodity_traded': '1456',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140039',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'MADANAPALLE',
#   'commodity': 'TOMATO',
#   'min_price': '2700',
#   'modal_price': '3200',
#   'max_price': '5200',
#   'commodity_arrivals': '1415',
#   'commodity_traded': '1430',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147901',
#   'state': 'RAJASTHAN',
#   'apmc': 'NIWAI',
#   'commodity': 'MUSTARD',
#   'min_price': '4500',
#   'modal_price': '7111',
#   'max_price': '8000',
#   'commodity_arrivals': '1502',
#   'commodity_traded': '1428',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147312',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'CABBAGE',
#   'min_price': '1600',
#   'modal_price': '1600',
#   'max_price': '1800',
#   'commodity_arrivals': '512',
#   'commodity_traded': '1401',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32139882',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'GUNTUR',
#   'commodity': 'CHILLI BADIGA',
#   'min_price': '5300',
#   'modal_price': '11000',
#   'max_price': '14500',
#   'commodity_arrivals': '1293',
#   'commodity_traded': '1359',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144105',
#   'state': 'MAHARASHTRA',
#   'apmc': 'JALNA',
#   'commodity': 'TUR/ARHAR',
#   'min_price': '6010',
#   'modal_price': '6250',
#   'max_price': '6500',
#   'commodity_arrivals': '611',
#   'commodity_traded': '1352',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149279',
#   'state': 'TAMIL NADU',
#   'apmc': 'THIRUPPUR',
#   'commodity': 'COCONUT WITH HUSK',
#   'min_price': '13',
#   'modal_price': '13',
#   'max_price': '15',
#   'commodity_arrivals': '1350',
#   'commodity_traded': '1350',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Nos'},
#  {'id': '32148127',
#   'state': 'RAJASTHAN',
#   'apmc': 'RAWATSAR',
#   'commodity': 'MUSTARD',
#   'min_price': '6471',
#   'modal_price': '6820',
#   'max_price': '6899',
#   'commodity_arrivals': '1293',
#   'commodity_traded': '1298',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147315',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'CAPSICUM',
#   'min_price': '4000',
#   'modal_price': '5500',
#   'max_price': '5500',
#   'commodity_arrivals': '627',
#   'commodity_traded': '1233',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147318',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'CAULIFLOWER',
#   'min_price': '2200',
#   'modal_price': '2800',
#   'max_price': '3800',
#   'commodity_arrivals': '1467',
#   'commodity_traded': '1199',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147800',
#   'state': 'RAJASTHAN',
#   'apmc': 'MERTA CITY',
#   'commodity': 'GUAR SEEDS',
#   'min_price': '4401',
#   'modal_price': '4970',
#   'max_price': '5021',
#   'commodity_arrivals': '228',
#   'commodity_traded': '1193',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147329',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'LADY FINGER',
#   'min_price': '1000',
#   'modal_price': '1000',
#   'max_price': '1800',
#   'commodity_arrivals': '1258',
#   'commodity_traded': '1167',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32146324',
#   'state': 'RAJASTHAN',
#   'apmc': 'BARAN',
#   'commodity': 'GARLIC',
#   'min_price': '3000',
#   'modal_price': '4652',
#   'max_price': '10590',
#   'commodity_arrivals': '1175',
#   'commodity_traded': '1155',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140111',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'PUNGANUR',
#   'commodity': 'TOMATO',
#   'min_price': '3000',
#   'modal_price': '3340',
#   'max_price': '3670',
#   'commodity_arrivals': '1145',
#   'commodity_traded': '1145',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148755',
#   'state': 'TAMIL NADU',
#   'apmc': 'AVALURPET',
#   'commodity': 'PADDY(75 KG)',
#   'min_price': '1200',
#   'modal_price': '2294',
#   'max_price': '2294',
#   'commodity_arrivals': '1167',
#   'commodity_traded': '1133',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32146298',
#   'state': 'RAJASTHAN',
#   'apmc': 'BARAN',
#   'commodity': 'WHEAT',
#   'min_price': '2440',
#   'modal_price': '2615',
#   'max_price': '2699',
#   'commodity_arrivals': '1115',
#   'commodity_traded': '1114',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143633',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'ASHOKNAGAR',
#   'commodity': 'WHEAT',
#   'min_price': '2300',
#   'modal_price': '2780',
#   'max_price': '4100',
#   'commodity_arrivals': '1100',
#   'commodity_traded': '1100',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32139852',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'ADONI',
#   'commodity': 'GROUND NUT',
#   'min_price': '3159',
#   'modal_price': '5492',
#   'max_price': '7033',
#   'commodity_arrivals': '664',
#   'commodity_traded': '1088',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32150351',
#   'state': 'UTTAR PRADESH',
#   'apmc': 'KHAIR',
#   'commodity': 'BAJRA',
#   'min_price': '1800',
#   'modal_price': '1824',
#   'max_price': '1826',
#   'commodity_arrivals': '1062',
#   'commodity_traded': '1062',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143921',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'UJJAIN',
#   'commodity': 'SOYA-YELLOW',
#   'min_price': '4526',
#   'modal_price': '4875',
#   'max_price': '4879',
#   'commodity_arrivals': '1855',
#   'commodity_traded': '1055',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147656',
#   'state': 'RAJASTHAN',
#   'apmc': 'KOTA',
#   'commodity': 'WHEAT',
#   'min_price': '2466',
#   'modal_price': '2630',
#   'max_price': '2651',
#   'commodity_arrivals': '3586',
#   'commodity_traded': '1048',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140300',
#   'state': 'CHHATTISGARH',
#   'apmc': 'RAJIM',
#   'commodity': 'PADDY-MTU 1010',
#   'min_price': '1000',
#   'modal_price': '1870',
#   'max_price': '1901',
#   'commodity_arrivals': '1108',
#   'commodity_traded': '1045',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32146210',
#   'state': 'RAJASTHAN',
#   'apmc': 'AJMER F AND V',
#   'commodity': 'POTATO',
#   'min_price': '1200',
#   'modal_price': '1204',
#   'max_price': '1220',
#   'commodity_arrivals': '1037',
#   'commodity_traded': '1037',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32146302',
#   'state': 'RAJASTHAN',
#   'apmc': 'BARAN',
#   'commodity': 'MUSTARD',
#   'min_price': '5528',
#   'modal_price': '6714',
#   'max_price': '7176',
#   'commodity_arrivals': '1036',
#   'commodity_traded': '1036',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144245',
#   'state': 'MAHARASHTRA',
#   'apmc': 'MANGRULPEER',
#   'commodity': 'SOYABEANS',
#   'min_price': '4495',
#   'modal_price': '4710',
#   'max_price': '4815',
#   'commodity_arrivals': '1029',
#   'commodity_traded': '1029',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148122',
#   'state': 'RAJASTHAN',
#   'apmc': 'RAWATSAR',
#   'commodity': 'WHEAT',
#   'min_price': '2620',
#   'modal_price': '2660',
#   'max_price': '2666',
#   'commodity_arrivals': '968',
#   'commodity_traded': '1026',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32150910',
#   'state': 'UTTAR PRADESH',
#   'apmc': 'SITAPUR',
#   'commodity': 'WHEAT',
#   'min_price': '2490',
#   'modal_price': '2490',
#   'max_price': '2490',
#   'commodity_arrivals': '1014',
#   'commodity_traded': '1014',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148547',
#   'state': 'RAJASTHAN',
#   'apmc': 'SUMERPUR',
#   'commodity': 'WHEAT',
#   'min_price': '2566',
#   'modal_price': '2602',
#   'max_price': '2995',
#   'commodity_arrivals': '1193',
#   'commodity_traded': '1003',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148965',
#   'state': 'TAMIL NADU',
#   'apmc': 'KINATHUKADAVU',
#   'commodity': 'COCONUT COIR_DECORTICATED FIBR',
#   'min_price': '80',
#   'modal_price': '100',
#   'max_price': '100',
#   'commodity_arrivals': '1000',
#   'commodity_traded': '1000',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32150417',
#   'state': 'UTTAR PRADESH',
#   'apmc': 'LAKHIMPUR',
#   'commodity': 'WHEAT',
#   'min_price': '2525',
#   'modal_price': '2526',
#   'max_price': '2535',
#   'commodity_arrivals': '2621',
#   'commodity_traded': '1000',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143773',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'KHARGONE',
#   'commodity': 'WHEAT',
#   'min_price': '2579',
#   'modal_price': '2768',
#   'max_price': '2774',
#   'commodity_arrivals': '998',
#   'commodity_traded': '998',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149081',
#   'state': 'TAMIL NADU',
#   'apmc': 'PAPANASAM',
#   'commodity': 'COTTON',
#   'min_price': '469',
#   'modal_price': '7718',
#   'max_price': '77709',
#   'commodity_arrivals': '0',
#   'commodity_traded': '989',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144004',
#   'state': 'MAHARASHTRA',
#   'apmc': 'AMRAVATI',
#   'commodity': 'SOYABEANS',
#   'min_price': '4525',
#   'modal_price': '4726',
#   'max_price': '4825',
#   'commodity_arrivals': '1848',
#   'commodity_traded': '956',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149140',
#   'state': 'TAMIL NADU',
#   'apmc': 'RAJAPALAYAM',
#   'commodity': 'COCONUT',
#   'min_price': '8',
#   'modal_price': '16',
#   'max_price': '16',
#   'commodity_arrivals': '950',
#   'commodity_traded': '950',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Nos'},
#  {'id': '32151059',
#   'state': 'UTTARAKHAND',
#   'apmc': 'HALDWANI',
#   'commodity': 'POTATO',
#   'min_price': '1000',
#   'modal_price': '1500',
#   'max_price': '1500',
#   'commodity_arrivals': '948',
#   'commodity_traded': '948',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32146758',
#   'state': 'RAJASTHAN',
#   'apmc': 'BIKANER F AND V',
#   'commodity': 'POTATO',
#   'min_price': '1100',
#   'modal_price': '1170',
#   'max_price': '1200',
#   'commodity_arrivals': '945',
#   'commodity_traded': '945',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148024',
#   'state': 'RAJASTHAN',
#   'apmc': 'PRATAPGARH RJ',
#   'commodity': 'SOYABEANS',
#   'min_price': '3550',
#   'modal_price': '4600',
#   'max_price': '4750',
#   'commodity_arrivals': '936',
#   'commodity_traded': '936',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144092',
#   'state': 'MAHARASHTRA',
#   'apmc': 'HINGOLI',
#   'commodity': 'TURMERIC FINGER',
#   'min_price': '10325',
#   'modal_price': '11965',
#   'max_price': '12185',
#   'commodity_arrivals': '932',
#   'commodity_traded': '932',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147779',
#   'state': 'RAJASTHAN',
#   'apmc': 'MANDAWARI',
#   'commodity': 'BAJRA',
#   'min_price': '2300',
#   'modal_price': '2300',
#   'max_price': '2310',
#   'commodity_arrivals': '439',
#   'commodity_traded': '932',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149247',
#   'state': 'TAMIL NADU',
#   'apmc': 'THIRUKOVILUR',
#   'commodity': 'PADDY ADT-37(TN)',
#   'min_price': '1336',
#   'modal_price': '1870',
#   'max_price': '2074',
#   'commodity_arrivals': '906',
#   'commodity_traded': '921',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143681',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'CHHINDWARA',
#   'commodity': 'WHEAT',
#   'min_price': '2692',
#   'modal_price': '2723',
#   'max_price': '2860',
#   'commodity_arrivals': '901',
#   'commodity_traded': '901',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32141820',
#   'state': 'HARYANA',
#   'apmc': 'LADWA',
#   'commodity': 'PADDY-BASMATI1509',
#   'min_price': '2650',
#   'modal_price': '2870',
#   'max_price': '3200',
#   'commodity_arrivals': '245',
#   'commodity_traded': '875',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32145984',
#   'state': 'PUNJAB',
#   'apmc': 'PATIALA',
#   'commodity': 'POTATO',
#   'min_price': '1200',
#   'modal_price': '1200',
#   'max_price': '1200',
#   'commodity_arrivals': '870',
#   'commodity_traded': '870',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147306',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'BOTTLE GOURD',
#   'min_price': '2400',
#   'modal_price': '2400',
#   'max_price': '2400',
#   'commodity_arrivals': '630',
#   'commodity_traded': '857',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32146828',
#   'state': 'RAJASTHAN',
#   'apmc': 'BUNDI',
#   'commodity': 'WHEAT',
#   'min_price': '2481',
#   'modal_price': '2595',
#   'max_price': '2607',
#   'commodity_arrivals': '851',
#   'commodity_traded': '851',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144162',
#   'state': 'MAHARASHTRA',
#   'apmc': 'KHAMGAON',
#   'commodity': 'TUR/ARHAR',
#   'min_price': '6200',
#   'modal_price': '6500',
#   'max_price': '6600',
#   'commodity_arrivals': '925',
#   'commodity_traded': '848',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140469',
#   'state': 'GUJARAT',
#   'apmc': 'GONDAL',
#   'commodity': 'GROUND NUT',
#   'min_price': '5140',
#   'modal_price': '5400',
#   'max_price': '5600',
#   'commodity_arrivals': '839',
#   'commodity_traded': '839',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32150401',
#   'state': 'UTTAR PRADESH',
#   'apmc': 'KONCH',
#   'commodity': 'WHEAT',
#   'min_price': '2490',
#   'modal_price': '2490',
#   'max_price': '2490',
#   'commodity_arrivals': '839',
#   'commodity_traded': '839',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143333',
#   'state': 'HIMACHAL PRADESH',
#   'apmc': 'FRUIT MANDI SOLAN',
#   'commodity': 'APPLE',
#   'min_price': '5000',
#   'modal_price': '5000',
#   'max_price': '10000',
#   'commodity_arrivals': '829',
#   'commodity_traded': '829',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147512',
#   'state': 'RAJASTHAN',
#   'apmc': 'JODHPUR GRAIN',
#   'commodity': 'CUMMIN',
#   'min_price': '15400',
#   'modal_price': '17275',
#   'max_price': '20000',
#   'commodity_arrivals': '439',
#   'commodity_traded': '825',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32146206',
#   'state': 'RAJASTHAN',
#   'apmc': 'AJMER F AND V',
#   'commodity': 'ONION',
#   'min_price': '1300',
#   'modal_price': '1330',
#   'max_price': '1338',
#   'commodity_arrivals': '824',
#   'commodity_traded': '824',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140661',
#   'state': 'GUJARAT',
#   'apmc': 'VADODARA',
#   'commodity': 'POTATO',
#   'min_price': '905',
#   'modal_price': '1000',
#   'max_price': '1050',
#   'commodity_arrivals': '505',
#   'commodity_traded': '820',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148322',
#   'state': 'RAJASTHAN',
#   'apmc': 'SRI GANGANAGAR GRAIN',
#   'commodity': 'WHEAT',
#   'min_price': '2231',
#   'modal_price': '2635',
#   'max_price': '2940',
#   'commodity_arrivals': '365',
#   'commodity_traded': '820',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147984',
#   'state': 'RAJASTHAN',
#   'apmc': 'PALSANA',
#   'commodity': 'BARLEY (JAU)',
#   'min_price': '2250',
#   'modal_price': '2260',
#   'max_price': '2260',
#   'commodity_arrivals': '803',
#   'commodity_traded': '803',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147207',
#   'state': 'RAJASTHAN',
#   'apmc': 'HINDOUN',
#   'commodity': 'MUSTARD',
#   'min_price': '6558',
#   'modal_price': '6590',
#   'max_price': '7020',
#   'commodity_arrivals': '795',
#   'commodity_traded': '795',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140634',
#   'state': 'GUJARAT',
#   'apmc': 'SIDDHPUR',
#   'commodity': 'CASTOR SEED',
#   'min_price': '6380',
#   'modal_price': '6480',
#   'max_price': '6520',
#   'commodity_arrivals': '787',
#   'commodity_traded': '787',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149087',
#   'state': 'TAMIL NADU',
#   'apmc': 'PARAMATHI VELUR',
#   'commodity': 'WATER MELON',
#   'min_price': '200',
#   'modal_price': '200',
#   'max_price': '400',
#   'commodity_arrivals': '783',
#   'commodity_traded': '784',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140018',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'KURNOOL',
#   'commodity': 'GROUND NUT',
#   'min_price': '4100',
#   'modal_price': '5900',
#   'max_price': '6900',
#   'commodity_arrivals': '489',
#   'commodity_traded': '780',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144158',
#   'state': 'MAHARASHTRA',
#   'apmc': 'KHAMGAON',
#   'commodity': 'SOYABEANS',
#   'min_price': '4450',
#   'modal_price': '4750',
#   'max_price': '4775',
#   'commodity_arrivals': '1044',
#   'commodity_traded': '780',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32146580',
#   'state': 'RAJASTHAN',
#   'apmc': 'BIJAY NAGAR',
#   'commodity': 'BANANA',
#   'min_price': '2500',
#   'modal_price': '3000',
#   'max_price': '3000',
#   'commodity_arrivals': '408',
#   'commodity_traded': '780',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148327',
#   'state': 'RAJASTHAN',
#   'apmc': 'SRI GANGANAGAR GRAIN',
#   'commodity': 'MUSTARD',
#   'min_price': '6000',
#   'modal_price': '6660',
#   'max_price': '6828',
#   'commodity_arrivals': '613',
#   'commodity_traded': '773',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149426',
#   'state': 'TAMIL NADU',
#   'apmc': 'VELLORE',
#   'commodity': 'PADDY(75 KG)',
#   'min_price': '1652',
#   'modal_price': '2200',
#   'max_price': '2306',
#   'commodity_arrivals': '1150',
#   'commodity_traded': '768',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32142063',
#   'state': 'HARYANA',
#   'apmc': 'PANIPAT',
#   'commodity': 'POTATO',
#   'min_price': '500',
#   'modal_price': '1300',
#   'max_price': '1300',
#   'commodity_arrivals': '765',
#   'commodity_traded': '765',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143730',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'INDORE',
#   'commodity': 'CHANA BENGAL GRAM-DOLLAR',
#   'min_price': '8600',
#   'modal_price': '9800',
#   'max_price': '11000',
#   'commodity_arrivals': '759',
#   'commodity_traded': '759',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143708',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'GUNA',
#   'commodity': 'WHEAT',
#   'min_price': '2635',
#   'modal_price': '2730',
#   'max_price': '2740',
#   'commodity_arrivals': '990',
#   'commodity_traded': '756',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147642',
#   'state': 'RAJASTHAN',
#   'apmc': 'KHERLI',
#   'commodity': 'MUSTARD',
#   'min_price': '6680',
#   'modal_price': '6980',
#   'max_price': '7045',
#   'commodity_arrivals': '757',
#   'commodity_traded': '752',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149525',
#   'state': 'TAMIL NADU',
#   'apmc': 'VIRUDHACHALAM',
#   'commodity': 'PADDY(75 KG)',
#   'min_price': '1128',
#   'modal_price': '1999',
#   'max_price': '2200',
#   'commodity_arrivals': '756',
#   'commodity_traded': '746',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147331',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'LEMON',
#   'min_price': '2000',
#   'modal_price': '2500',
#   'max_price': '2500',
#   'commodity_arrivals': '754',
#   'commodity_traded': '745',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144090',
#   'state': 'MAHARASHTRA',
#   'apmc': 'HINGOLI',
#   'commodity': 'TURMERIC BULB',
#   'min_price': '10470',
#   'modal_price': '11635',
#   'max_price': '11985',
#   'commodity_arrivals': '733',
#   'commodity_traded': '733',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148504',
#   'state': 'RAJASTHAN',
#   'apmc': 'SRIGANGANAGAR F AND V',
#   'commodity': 'ONION',
#   'min_price': '1700',
#   'modal_price': '1700',
#   'max_price': '1700',
#   'commodity_arrivals': '726',
#   'commodity_traded': '726',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140269',
#   'state': 'CHHATTISGARH',
#   'apmc': 'NAVAPARA',
#   'commodity': 'PADDY-MTU 1010',
#   'min_price': '1440',
#   'modal_price': '1880',
#   'max_price': '2310',
#   'commodity_arrivals': '772',
#   'commodity_traded': '724',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140326',
#   'state': 'CHHATTISGARH',
#   'apmc': 'RAJNANDGAON',
#   'commodity': 'PADDY-MTU 1010',
#   'min_price': '1800',
#   'modal_price': '1886',
#   'max_price': '2350',
#   'commodity_arrivals': '597',
#   'commodity_traded': '715',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32150189',
#   'state': 'UTTAR PRADESH',
#   'apmc': 'HAPUR',
#   'commodity': 'POTATO',
#   'min_price': '900',
#   'modal_price': '1000',
#   'max_price': '1000',
#   'commodity_arrivals': '715',
#   'commodity_traded': '715',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147791',
#   'state': 'RAJASTHAN',
#   'apmc': 'MERTA CITY',
#   'commodity': 'MUSTARD',
#   'min_price': '4501',
#   'modal_price': '4501',
#   'max_price': '6983',
#   'commodity_arrivals': '218',
#   'commodity_traded': '712',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32145563',
#   'state': 'ODISHA',
#   'apmc': 'KORAPUT',
#   'commodity': 'GINGER',
#   'min_price': '5000',
#   'modal_price': '5000',
#   'max_price': '5000',
#   'commodity_arrivals': '706',
#   'commodity_traded': '706',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32145951',
#   'state': 'PUNJAB',
#   'apmc': 'BHOGPUR',
#   'commodity': 'MAIZE',
#   'min_price': '2117',
#   'modal_price': '2117',
#   'max_price': '2175',
#   'commodity_arrivals': '705',
#   'commodity_traded': '705',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147012',
#   'state': 'RAJASTHAN',
#   'apmc': 'DEGANA',
#   'commodity': 'GUAR SEEDS',
#   'min_price': '4600',
#   'modal_price': '4900',
#   'max_price': '5100',
#   'commodity_arrivals': '91',
#   'commodity_traded': '705',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32145641',
#   'state': 'ODISHA',
#   'apmc': 'NABARANGPUR',
#   'commodity': 'MAIZE',
#   'min_price': '2000',
#   'modal_price': '2000',
#   'max_price': '2000',
#   'commodity_arrivals': '704',
#   'commodity_traded': '704',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148685',
#   'state': 'RAJASTHAN',
#   'apmc': 'UDAIPUR F AND V',
#   'commodity': 'TOMATO',
#   'min_price': '2500',
#   'modal_price': '3000',
#   'max_price': '4500',
#   'commodity_arrivals': '590',
#   'commodity_traded': '704',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147271',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'APPLE',
#   'min_price': '20000',
#   'modal_price': '20000',
#   'max_price': '25000',
#   'commodity_arrivals': '704',
#   'commodity_traded': '689',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143899',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'SHEOPURKALAN',
#   'commodity': 'WHEAT-HYBRID',
#   'min_price': '2620',
#   'modal_price': '2623',
#   'max_price': '2645',
#   'commodity_arrivals': '670',
#   'commodity_traded': '670',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140273',
#   'state': 'CHHATTISGARH',
#   'apmc': 'NAVAPARA',
#   'commodity': 'SAMA-MASURI',
#   'min_price': '1550',
#   'modal_price': '2054',
#   'max_price': '2362',
#   'commodity_arrivals': '696',
#   'commodity_traded': '667',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32150930',
#   'state': 'UTTAR PRADESH',
#   'apmc': 'TUNDLA',
#   'commodity': 'MAIZE',
#   'min_price': '1800',
#   'modal_price': '1950',
#   'max_price': '2010',
#   'commodity_arrivals': '690',
#   'commodity_traded': '665',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148832',
#   'state': 'TAMIL NADU',
#   'apmc': 'DESUR',
#   'commodity': 'PADDY CO 51(TN)',
#   'min_price': '1348',
#   'modal_price': '1932',
#   'max_price': '1934',
#   'commodity_arrivals': '645',
#   'commodity_traded': '662',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147325',
#   'state': 'RAJASTHAN',
#   'apmc': 'JAIPUR F AND V MUHANA',
#   'commodity': 'CUCUMBER',
#   'min_price': '1200',
#   'modal_price': '2800',
#   'max_price': '2800',
#   'commodity_arrivals': '1042',
#   'commodity_traded': '660',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147790',
#   'state': 'RAJASTHAN',
#   'apmc': 'MERTA CITY',
#   'commodity': 'ISBGOL (PSYLLIUM HUSK) ',
#   'min_price': '6800',
#   'modal_price': '9000',
#   'max_price': '11000',
#   'commodity_arrivals': '153',
#   'commodity_traded': '658',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32139889',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'GUNTUR',
#   'commodity': 'CHILLI TEJA A/C',
#   'min_price': '5500',
#   'modal_price': '12000',
#   'max_price': '14000',
#   'commodity_arrivals': '1909',
#   'commodity_traded': '657',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148587',
#   'state': 'RAJASTHAN',
#   'apmc': 'TONK',
#   'commodity': 'MUSTARD',
#   'min_price': '4100',
#   'modal_price': '6694',
#   'max_price': '7200',
#   'commodity_arrivals': '720',
#   'commodity_traded': '656',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32150452',
#   'state': 'UTTAR PRADESH',
#   'apmc': 'MAHMUDABAD',
#   'commodity': 'WHEAT',
#   'min_price': '2525',
#   'modal_price': '2540',
#   'max_price': '2560',
#   'commodity_arrivals': '655',
#   'commodity_traded': '655',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32151206',
#   'state': 'UTTARAKHAND',
#   'apmc': 'KASHIPUR',
#   'commodity': 'WHEAT',
#   'min_price': '2700',
#   'modal_price': '2700',
#   'max_price': '6602',
#   'commodity_arrivals': '653',
#   'commodity_traded': '653',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149102',
#   'state': 'TAMIL NADU',
#   'apmc': 'POLLACHI',
#   'commodity': 'COCONUT COIR_BRISTLE COIR FIBR',
#   'min_price': '50',
#   'modal_price': '50',
#   'max_price': '50',
#   'commodity_arrivals': '650',
#   'commodity_traded': '650',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147653',
#   'state': 'RAJASTHAN',
#   'apmc': 'KOTA',
#   'commodity': 'PADDY',
#   'min_price': '2551',
#   'modal_price': '3611',
#   'max_price': '3611',
#   'commodity_arrivals': '479',
#   'commodity_traded': '647',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148039',
#   'state': 'RAJASTHAN',
#   'apmc': 'PRATAPGARH RJ',
#   'commodity': 'ONION',
#   'min_price': '300',
#   'modal_price': '630',
#   'max_price': '1431',
#   'commodity_arrivals': '647',
#   'commodity_traded': '647',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147246',
#   'state': 'RAJASTHAN',
#   'apmc': 'ITAWA',
#   'commodity': 'CHANA (BENGAL GRAM)',
#   'min_price': '5193',
#   'modal_price': '5507',
#   'max_price': '5911',
#   'commodity_arrivals': '644',
#   'commodity_traded': '644',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147286',
#   'state': 'RAJASTHAN',
# ...
#   'commodity_traded': '52',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144608',
#   'state': 'ODISHA',
#   'apmc': 'BANKI',
#   'commodity': 'BRINJAL-HYBRID',
#   'min_price': '3000',
#   'modal_price': '3000',
#   'max_price': '3000',
#   'commodity_arrivals': '52',
#   'commodity_traded': '52',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32146413',
#   'state': 'RAJASTHAN',
#   'apmc': 'BARMER',
#   'commodity': 'BEANS -CLUSTER',
#   'min_price': '6540',
#   'modal_price': '6540',
#   'max_price': '6540',
#   'commodity_arrivals': '52',
#   'commodity_traded': '52',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147678',
#   'state': 'RAJASTHAN',
#   'apmc': 'KOTA',
#   'commodity': 'MOONG WHOLE (GREEN GRAM)',
#   'min_price': '7001',
#   'modal_price': '7111',
#   'max_price': '7200',
#   'commodity_arrivals': '10',
#   'commodity_traded': '52',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147684',
#   'state': 'RAJASTHAN',
#   'apmc': 'KOTA',
#   'commodity': 'CORIANDAR',
#   'min_price': '5717',
#   'modal_price': '5717',
#   'max_price': '6741',
#   'commodity_arrivals': '184',
#   'commodity_traded': '52',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149745',
#   'state': 'TELANGANA',
#   'apmc': 'ZAHEERABAD',
#   'commodity': 'REDGRAM-RED',
#   'min_price': '4613',
#   'modal_price': '5811',
#   'max_price': '6428',
#   'commodity_arrivals': '0',
#   'commodity_traded': '52',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140481',
#   'state': 'GUJARAT',
#   'apmc': 'IDAR APMC',
#   'commodity': 'GROUND NUT',
#   'min_price': '4120',
#   'modal_price': '5500',
#   'max_price': '6200',
#   'commodity_arrivals': '51',
#   'commodity_traded': '51',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32142165',
#   'state': 'HARYANA',
#   'apmc': 'PUNDRI',
#   'commodity': 'ONION',
#   'min_price': '1300',
#   'modal_price': '1300',
#   'max_price': '1500',
#   'commodity_arrivals': '20',
#   'commodity_traded': '51',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32142749',
#   'state': 'HARYANA',
#   'apmc': 'SIRSA',
#   'commodity': 'TOMATO',
#   'min_price': '2600',
#   'modal_price': '2600',
#   'max_price': '2700',
#   'commodity_arrivals': '51',
#   'commodity_traded': '51',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144596',
#   'state': 'ODISHA',
#   'apmc': 'BANKI',
#   'commodity': 'RAW BANANA',
#   'min_price': '700',
#   'modal_price': '700',
#   'max_price': '700',
#   'commodity_arrivals': '51',
#   'commodity_traded': '51',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32145904',
#   'state': 'ODISHA',
#   'apmc': 'TIKABALI',
#   'commodity': 'CAULIFLOWER',
#   'min_price': '3500',
#   'modal_price': '3500',
#   'max_price': '3500',
#   'commodity_arrivals': '51',
#   'commodity_traded': '51',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32146629',
#   'state': 'RAJASTHAN',
#   'apmc': 'BIKANER F AND V',
#   'commodity': 'PEAR',
#   'min_price': '2900',
#   'modal_price': '2975',
#   'max_price': '3000',
#   'commodity_arrivals': '51',
#   'commodity_traded': '51',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149778',
#   'state': 'UTTAR PRADESH',
#   'apmc': 'ALIGARH',
#   'commodity': 'BOTTLE GOURD',
#   'min_price': '850',
#   'modal_price': '850',
#   'max_price': '1020',
#   'commodity_arrivals': '51',
#   'commodity_traded': '51',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32151955',
#   'state': 'WEST BENGAL',
#   'apmc': 'SIMLAPAL',
#   'commodity': 'PUMPKIN',
#   'min_price': '1800',
#   'modal_price': '1806',
#   'max_price': '1806',
#   'commodity_arrivals': '51',
#   'commodity_traded': '51',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140281',
#   'state': 'CHHATTISGARH',
#   'apmc': 'PATELPALI RAIGARH',
#   'commodity': 'GROUND NUT',
#   'min_price': '4200',
#   'modal_price': '4200',
#   'max_price': '4200',
#   'commodity_arrivals': '50',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140316',
#   'state': 'CHHATTISGARH',
#   'apmc': 'RAJNANDGAON',
#   'commodity': 'PADDY-DEV BHOG',
#   'min_price': '1841',
#   'modal_price': '1841',
#   'max_price': '2050',
#   'commodity_arrivals': '50',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32141495',
#   'state': 'HARYANA',
#   'apmc': 'GURGAON',
#   'commodity': 'BHINDI (LADIES FINGER)',
#   'min_price': '1355',
#   'modal_price': '1522',
#   'max_price': '2655',
#   'commodity_arrivals': '50',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143918',
#   'state': 'MADHYA PRADESH',
#   'apmc': 'UJJAIN',
#   'commodity': 'WHEAT',
#   'min_price': '2622',
#   'modal_price': '2735',
#   'max_price': '2735',
#   'commodity_arrivals': '873',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144186',
#   'state': 'MAHARASHTRA',
#   'apmc': 'MAJALGAON',
#   'commodity': 'JOWAR',
#   'min_price': '2500',
#   'modal_price': '2500',
#   'max_price': '2500',
#   'commodity_arrivals': '50',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144877',
#   'state': 'ODISHA',
#   'apmc': 'BOUDH',
#   'commodity': 'BRINJAL',
#   'min_price': '4000',
#   'modal_price': '4000',
#   'max_price': '4500',
#   'commodity_arrivals': '50',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32145322',
#   'state': 'ODISHA',
#   'apmc': 'JALESWAR',
#   'commodity': 'TOMATO',
#   'min_price': '5000',
#   'modal_price': '5000',
#   'max_price': '5000',
#   'commodity_arrivals': '50',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32146152',
#   'state': 'RAJASTHAN',
#   'apmc': 'AJMER F AND V',
#   'commodity': 'BITTER GOURD',
#   'min_price': '2200',
#   'modal_price': '2236',
#   'max_price': '2240',
#   'commodity_arrivals': '50',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147173',
#   'state': 'RAJASTHAN',
#   'apmc': 'HANUMANGARH',
#   'commodity': 'GUAR SEEDS',
#   'min_price': '4560',
#   'modal_price': '4799',
#   'max_price': '4799',
#   'commodity_arrivals': '50',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147811',
#   'state': 'RAJASTHAN',
#   'apmc': 'NADBAI',
#   'commodity': 'BAJRA',
#   'min_price': '2167',
#   'modal_price': '2167',
#   'max_price': '2167',
#   'commodity_arrivals': '50',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147977',
#   'state': 'RAJASTHAN',
#   'apmc': 'PADAMPUR',
#   'commodity': 'CHANA (BENGAL GRAM)-DESI',
#   'min_price': '5600',
#   'modal_price': '5600',
#   'max_price': '5612',
#   'commodity_arrivals': '0',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148422',
#   'state': 'RAJASTHAN',
#   'apmc': 'SRIGANGANAGAR F AND V',
#   'commodity': 'POMEGRANATE',
#   'min_price': '13500',
#   'modal_price': '13500',
#   'max_price': '13500',
#   'commodity_arrivals': '50',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148934',
#   'state': 'TAMIL NADU',
#   'apmc': 'KARUMANDURAI',
#   'commodity': 'MANGO',
#   'min_price': '900',
#   'modal_price': '1000',
#   'max_price': '1100',
#   'commodity_arrivals': '93',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32150529',
#   'state': 'UTTAR PRADESH',
#   'apmc': 'MUSKERA',
#   'commodity': 'WHITE PEAS',
#   'min_price': '3400',
#   'modal_price': '3400',
#   'max_price': '3400',
#   'commodity_arrivals': '50',
#   'commodity_traded': '50',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140058',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'PALAMANER',
#   'commodity': 'CAULIFLOWER',
#   'min_price': '800',
#   'modal_price': '800',
#   'max_price': '1000',
#   'commodity_arrivals': '49',
#   'commodity_traded': '49',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32141367',
#   'state': 'HARYANA',
#   'apmc': 'ELLANABAD',
#   'commodity': 'CUCUMBER',
#   'min_price': '700',
#   'modal_price': '1000',
#   'max_price': '3000',
#   'commodity_arrivals': '49',
#   'commodity_traded': '49',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32142196',
#   'state': 'HARYANA',
#   'apmc': 'PUNHANA APMC',
#   'commodity': 'GUAVA',
#   'min_price': '1000',
#   'modal_price': '1200',
#   'max_price': '1500',
#   'commodity_arrivals': '54',
#   'commodity_traded': '49',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32142207',
#   'state': 'HARYANA',
#   'apmc': 'PUNHANA APMC',
#   'commodity': 'CHILLI-DESI',
#   'min_price': '3000',
#   'modal_price': '3000',
#   'max_price': '5000',
#   'commodity_arrivals': '11',
#   'commodity_traded': '49',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32145199',
#   'state': 'ODISHA',
#   'apmc': 'HINJILICUT',
#   'commodity': 'CABBAGE',
#   'min_price': '2400',
#   'modal_price': '2500',
#   'max_price': '2500',
#   'commodity_arrivals': '49',
#   'commodity_traded': '49',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147774',
#   'state': 'RAJASTHAN',
#   'apmc': 'MAHUWA RJ',
#   'commodity': 'WHEAT',
#   'min_price': '2450',
#   'modal_price': '2450',
#   'max_price': '2450',
#   'commodity_arrivals': '49',
#   'commodity_traded': '49',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149318',
#   'state': 'TAMIL NADU',
#   'apmc': 'TINDIVANAM',
#   'commodity': 'GROUNDNUT KERNEL_80 KG(TN)',
#   'min_price': '6574',
#   'modal_price': '8640',
#   'max_price': '9669',
#   'commodity_arrivals': '51',
#   'commodity_traded': '49',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': '50 Kg'},
#  {'id': '32149736',
#   'state': 'TELANGANA',
#   'apmc': 'WARANGAL',
#   'commodity': 'TURMERIC FINGER',
#   'min_price': '9400',
#   'modal_price': '9890',
#   'max_price': '9911',
#   'commodity_arrivals': '47',
#   'commodity_traded': '49',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32139946',
#   'state': 'ANDHRA PRADESH',
#   'apmc': 'GUNTUR',
#   'commodity': 'CHILLI-DEVANURU DELUX',
#   'min_price': '11500',
#   'modal_price': '11500',
#   'max_price': '12000',
#   'commodity_arrivals': '182',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140431',
#   'state': 'GUJARAT',
#   'apmc': 'CHOTILA APMC',
#   'commodity': 'JOWAR',
#   'min_price': '3650',
#   'modal_price': '3875',
#   'max_price': '3875',
#   'commodity_arrivals': '48',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32140612',
#   'state': 'GUJARAT',
#   'apmc': 'RAJKOT',
#   'commodity': 'CUMMIN',
#   'min_price': '12500',
#   'modal_price': '12500',
#   'max_price': '17500',
#   'commodity_arrivals': '12',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32141673',
#   'state': 'HARYANA',
#   'apmc': 'HANSI',
#   'commodity': 'LADY FINGER',
#   'min_price': '2000',
#   'modal_price': '2000',
#   'max_price': '3000',
#   'commodity_arrivals': '30',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32143443',
#   'state': 'HIMACHAL PRADESH',
#   'apmc': 'ROHRU',
#   'commodity': 'APPLE',
#   'min_price': '10000',
#   'modal_price': '10000',
#   'max_price': '10000',
#   'commodity_arrivals': '48',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32145383',
#   'state': 'ODISHA',
#   'apmc': 'JHARSUGUDA',
#   'commodity': 'TOMATO',
#   'min_price': '3500',
#   'modal_price': '3500',
#   'max_price': '3500',
#   'commodity_arrivals': '0',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32145638',
#   'state': 'ODISHA',
#   'apmc': 'MUKHIGUDA',
#   'commodity': 'TOMATO',
#   'min_price': '2900',
#   'modal_price': '2900',
#   'max_price': '3000',
#   'commodity_arrivals': '48',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32147526',
#   'state': 'RAJASTHAN',
#   'apmc': 'KAPASAN',
#   'commodity': 'WHEAT',
#   'min_price': '2450',
#   'modal_price': '2550',
#   'max_price': '2640',
#   'commodity_arrivals': '48',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148018',
#   'state': 'RAJASTHAN',
#   'apmc': 'PRATAPGARH RJ',
#   'commodity': 'LINSEED',
#   'min_price': '7487',
#   'modal_price': '7640',
#   'max_price': '7761',
#   'commodity_arrivals': '48',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148619',
#   'state': 'RAJASTHAN',
#   'apmc': 'UDAIPUR F AND V',
#   'commodity': 'GINGER',
#   'min_price': '2000',
#   'modal_price': '2000',
#   'max_price': '3000',
#   'commodity_arrivals': '40',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32148978',
#   'state': 'TAMIL NADU',
#   'apmc': 'KUDAVASAL',
#   'commodity': 'COTTON',
#   'min_price': '7010',
#   'modal_price': '7569',
#   'max_price': '7609',
#   'commodity_arrivals': '0',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149374',
#   'state': 'TAMIL NADU',
#   'apmc': 'UTHIRAMERUR',
#   'commodity': 'PADDY CO 51(TN)',
#   'min_price': '1615',
#   'modal_price': '1615',
#   'max_price': '1642',
#   'commodity_arrivals': '36',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32149875',
#   'state': 'UTTAR PRADESH',
#   'apmc': 'BALRAMPUR APMC',
#   'commodity': 'BOTTLE GOURD',
#   'min_price': '1020',
#   'modal_price': '1020',
#   'max_price': '1020',
#   'commodity_arrivals': '48',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32151915',
#   'state': 'WEST BENGAL',
#   'apmc': 'SHEORAPHULI',
#   'commodity': 'PUMPKIN',
#   'min_price': '1900',
#   'modal_price': '1900',
#   'max_price': '1900',
#   'commodity_arrivals': '48',
#   'commodity_traded': '48',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32144487',
#   'state': 'ODISHA',
#   'apmc': 'BAHADAJHOLA',
#   'commodity': 'CABBAGE',
#   'min_price': '1800',
#   'modal_price': '1800',
#   'max_price': '1800',
#   'commodity_arrivals': '47',
#   'commodity_traded': '47',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32145197',
#   'state': 'ODISHA',
#   'apmc': 'HINJILICUT',
#   'commodity': 'BRINJAL',
#   'min_price': '3400',
#   'modal_price': '3500',
#   'max_price': '3500',
#   'commodity_arrivals': '47',
#   'commodity_traded': '47',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32146156',
#   'state': 'RAJASTHAN',
#   'apmc': 'AJMER F AND V',
#   'commodity': 'BOTTLE GOURD',
#   'min_price': '1800',
#   'modal_price': '1812',
#   'max_price': '1830',
#   'commodity_arrivals': '47',
#   'commodity_traded': '47',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  {'id': '32146178',
#   'state': 'RAJASTHAN',
#   'apmc': 'AJMER F AND V',
#   'commodity': 'BEANS -CLUSTER',
#   'min_price': '3200',
#   'modal_price': '3208',
#   'max_price': '3244',
#   'commodity_arrivals': '47',
#   'commodity_traded': '47',
#   'created_at': '2025-08-12',
#   'status': '1',
#   'Commodity_Uom': 'Qui'},
#  ...]

# %%
def get_trade_date_range(start_date: str, end_date: str, jsonl_path: str) -> list:
    all_data = []
    for d in date_range(start_date, end_date):
        dt = datetime.strptime(d, "%Y-%m-%d")
        date_str = dt.strftime("%Y-%m-%d")
        year_str = dt.strftime("%Y") 
        month_str = dt.strftime("%b") 
        data = get_trade_data(date_str)
        day_dir = Path(jsonl_path)
        out_path = day_dir / year_str / month_str / f"{date_str}.jsonl.gz"
        out_path.parent.mkdir(parents=True, exist_ok=True)
        print(f"Processing for date: {date_str}")
        save_jsonl_gz(data, out_path)
        all_data.extend(data)
    return all_data

# %%
output_location = "../data/enam/"
trade_data_list = get_trade_date_range("2024-01-01", "2024-12-31", output_location)
# Out:
# Processing for date: 2024-01-01
# Processing for date: 2024-01-02
# Processing for date: 2024-01-03
# Processing for date: 2024-01-04
# Processing for date: 2024-01-05
# Processing for date: 2024-01-06
# Processing for date: 2024-01-07
# Processing for date: 2024-01-08
# Processing for date: 2024-01-09
# Processing for date: 2024-01-10
# Processing for date: 2024-01-11
# Processing for date: 2024-01-12
# Processing for date: 2024-01-13
# Processing for date: 2024-01-14
# Processing for date: 2024-01-15
# Processing for date: 2024-01-16
# Processing for date: 2024-01-17
# Processing for date: 2024-01-18
# Processing for date: 2024-01-19
# Processing for date: 2024-01-20
# Processing for date: 2024-01-21
# Processing for date: 2024-01-22
# Processing for date: 2024-01-23
# Processing for date: 2024-01-24
# Processing for date: 2024-01-25
# Processing for date: 2024-01-26
# Processing for date: 2024-01-27
# Processing for date: 2024-01-28
# Processing for date: 2024-01-29
# Processing for date: 2024-01-30
# Processing for date: 2024-01-31
# Processing for date: 2024-02-01
# Processing for date: 2024-02-02
# Processing for date: 2024-02-03
# Processing for date: 2024-02-04
# Processing for date: 2024-02-05
# Processing for date: 2024-02-06
# Processing for date: 2024-02-07
# Processing for date: 2024-02-08
# Processing for date: 2024-02-09
# Processing for date: 2024-02-10
# Processing for date: 2024-02-11
# Processing for date: 2024-02-12
# Processing for date: 2024-02-13
# Processing for date: 2024-02-14
# Processing for date: 2024-02-15
# Processing for date: 2024-02-16
# Processing for date: 2024-02-17
# Processing for date: 2024-02-18
# Processing for date: 2024-02-19
# Processing for date: 2024-02-20
# Processing for date: 2024-02-21
# Processing for date: 2024-02-22
# Processing for date: 2024-02-23
# Processing for date: 2024-02-24
# Processing for date: 2024-02-25
# Processing for date: 2024-02-26
# Processing for date: 2024-02-27
# Processing for date: 2024-02-28
# Processing for date: 2024-02-29
# Processing for date: 2024-03-01
# Processing for date: 2024-03-02
# Processing for date: 2024-03-03
# Processing for date: 2024-03-04
# Processing for date: 2024-03-05
# Processing for date: 2024-03-06
# Processing for date: 2024-03-07
# Processing for date: 2024-03-08
# Processing for date: 2024-03-09
# Processing for date: 2024-03-10
# Processing for date: 2024-03-11
# Processing for date: 2024-03-12
# Processing for date: 2024-03-13
# Processing for date: 2024-03-14
# Processing for date: 2024-03-15
# Processing for date: 2024-03-16
# Processing for date: 2024-03-17
# Processing for date: 2024-03-18
# Processing for date: 2024-03-19
# Processing for date: 2024-03-20
# Processing for date: 2024-03-21
# Processing for date: 2024-03-22
# Processing for date: 2024-03-23
# Processing for date: 2024-03-24
# Processing for date: 2024-03-25
# Processing for date: 2024-03-26
# Processing for date: 2024-03-27
# Processing for date: 2024-03-28
# Processing for date: 2024-03-29
# Processing for date: 2024-03-30
# Processing for date: 2024-03-31
# Processing for date: 2024-04-01
# Processing for date: 2024-04-02
# Processing for date: 2024-04-03
# Processing for date: 2024-04-04
# Processing for date: 2024-04-05
# Processing for date: 2024-04-06
# Processing for date: 2024-04-07
# Processing for date: 2024-04-08
# Processing for date: 2024-04-09
# Processing for date: 2024-04-10
# Processing for date: 2024-04-11
# Processing for date: 2024-04-12
# Processing for date: 2024-04-13
# Processing for date: 2024-04-14
# Processing for date: 2024-04-15
# Processing for date: 2024-04-16
# Processing for date: 2024-04-17
# Processing for date: 2024-04-18
# Processing for date: 2024-04-19
# Processing for date: 2024-04-20
# Processing for date: 2024-04-21
# Processing for date: 2024-04-22
# Processing for date: 2024-04-23
# Processing for date: 2024-04-24
# Processing for date: 2024-04-25
# Processing for date: 2024-04-26
# Processing for date: 2024-04-27
# Processing for date: 2024-04-28
# Processing for date: 2024-04-29
# Processing for date: 2024-04-30
# Processing for date: 2024-05-01
# Processing for date: 2024-05-02
# Processing for date: 2024-05-03
# Processing for date: 2024-05-04
# Processing for date: 2024-05-05
# Processing for date: 2024-05-06
# Processing for date: 2024-05-07
# Processing for date: 2024-05-08
# Processing for date: 2024-05-09
# Processing for date: 2024-05-10
# Processing for date: 2024-05-11
# Processing for date: 2024-05-12
# Processing for date: 2024-05-13
# Processing for date: 2024-05-14
# Processing for date: 2024-05-15
# Processing for date: 2024-05-16
# Processing for date: 2024-05-17
# Processing for date: 2024-05-18
# Processing for date: 2024-05-19
# Processing for date: 2024-05-20
# Processing for date: 2024-05-21
# Processing for date: 2024-05-22
# Processing for date: 2024-05-23
# Processing for date: 2024-05-24
# Processing for date: 2024-05-25
# Processing for date: 2024-05-26
# Processing for date: 2024-05-27
# Processing for date: 2024-05-28
# Processing for date: 2024-05-29
# Processing for date: 2024-05-30
# Processing for date: 2024-05-31
# Processing for date: 2024-06-01
# Processing for date: 2024-06-02
# Processing for date: 2024-06-03
# Processing for date: 2024-06-04
# Processing for date: 2024-06-05
# Processing for date: 2024-06-06
# Processing for date: 2024-06-07
# Processing for date: 2024-06-08
# Processing for date: 2024-06-09
# Processing for date: 2024-06-10
# Processing for date: 2024-06-11
# Processing for date: 2024-06-12
# Processing for date: 2024-06-13
# Processing for date: 2024-06-14
# Processing for date: 2024-06-15
# Processing for date: 2024-06-16
# Processing for date: 2024-06-17
# Processing for date: 2024-06-18
# Processing for date: 2024-06-19
# Processing for date: 2024-06-20
# Processing for date: 2024-06-21
# Processing for date: 2024-06-22
# Processing for date: 2024-06-23
# Processing for date: 2024-06-24
# Processing for date: 2024-06-25
# Processing for date: 2024-06-26
# Processing for date: 2024-06-27
# Processing for date: 2024-06-28
# Processing for date: 2024-06-29
# Processing for date: 2024-06-30
# Processing for date: 2024-07-01
# Processing for date: 2024-07-02
# Processing for date: 2024-07-03
# Processing for date: 2024-07-04
# Processing for date: 2024-07-05
# Processing for date: 2024-07-06
# Processing for date: 2024-07-07
# Processing for date: 2024-07-08
# Processing for date: 2024-07-09
# Processing for date: 2024-07-10
# Processing for date: 2024-07-11
# Processing for date: 2024-07-12
# Processing for date: 2024-07-13
# Processing for date: 2024-07-14
# Processing for date: 2024-07-15
# Processing for date: 2024-07-16
# Processing for date: 2024-07-17
# Processing for date: 2024-07-18
# Processing for date: 2024-07-19
# Processing for date: 2024-07-20
# Processing for date: 2024-07-21
# Processing for date: 2024-07-22
# Processing for date: 2024-07-23
# Processing for date: 2024-07-24
# Processing for date: 2024-07-25
# Processing for date: 2024-07-26
# Processing for date: 2024-07-27
# Processing for date: 2024-07-28
# Processing for date: 2024-07-29
# Processing for date: 2024-07-30
# Processing for date: 2024-07-31
# Processing for date: 2024-08-01
# Processing for date: 2024-08-02
# Processing for date: 2024-08-03
# Processing for date: 2024-08-04
# Processing for date: 2024-08-05
# Processing for date: 2024-08-06
# Processing for date: 2024-08-07
# Processing for date: 2024-08-08
# Processing for date: 2024-08-09
# Processing for date: 2024-08-10
# Processing for date: 2024-08-11
# Processing for date: 2024-08-12
# Processing for date: 2024-08-13
# Processing for date: 2024-08-14
# Processing for date: 2024-08-15
# Processing for date: 2024-08-16
# Processing for date: 2024-08-17
# Processing for date: 2024-08-18
# Processing for date: 2024-08-19
# Processing for date: 2024-08-20
# Processing for date: 2024-08-21
# Processing for date: 2024-08-22
# Processing for date: 2024-08-23
# Processing for date: 2024-08-24
# Processing for date: 2024-08-25
# Processing for date: 2024-08-26
# Processing for date: 2024-08-27
# Processing for date: 2024-08-28
# Processing for date: 2024-08-29
# Processing for date: 2024-08-30
# Processing for date: 2024-08-31
# Processing for date: 2024-09-01
# Processing for date: 2024-09-02
# Processing for date: 2024-09-03
# Processing for date: 2024-09-04
# Processing for date: 2024-09-05
# Processing for date: 2024-09-06
# Processing for date: 2024-09-07
# Processing for date: 2024-09-08
# Processing for date: 2024-09-09
# Processing for date: 2024-09-10
# Processing for date: 2024-09-11
# Processing for date: 2024-09-12
# Processing for date: 2024-09-13
# Processing for date: 2024-09-14
# Processing for date: 2024-09-15
# Processing for date: 2024-09-16
# Processing for date: 2024-09-17
# Processing for date: 2024-09-18
# Processing for date: 2024-09-19
# Processing for date: 2024-09-20
# Processing for date: 2024-09-21
# Processing for date: 2024-09-22
# Processing for date: 2024-09-23
# Processing for date: 2024-09-24
# Processing for date: 2024-09-25
# Processing for date: 2024-09-26
# Processing for date: 2024-09-27
# Processing for date: 2024-09-28
# Processing for date: 2024-09-29
# Processing for date: 2024-09-30
# Processing for date: 2024-10-01
# Processing for date: 2024-10-02
# Processing for date: 2024-10-03
# Processing for date: 2024-10-04
# Processing for date: 2024-10-05
# Processing for date: 2024-10-06
# Processing for date: 2024-10-07
# Processing for date: 2024-10-08
# Processing for date: 2024-10-09
# Processing for date: 2024-10-10
# Processing for date: 2024-10-11
# Processing for date: 2024-10-12
# Processing for date: 2024-10-13
# Processing for date: 2024-10-14
# Processing for date: 2024-10-15
# Processing for date: 2024-10-16
# Processing for date: 2024-10-17
# Processing for date: 2024-10-18
# Processing for date: 2024-10-19
# Processing for date: 2024-10-20
# Processing for date: 2024-10-21
# Processing for date: 2024-10-22
# Processing for date: 2024-10-23
# Processing for date: 2024-10-24
# Processing for date: 2024-10-25
# Processing for date: 2024-10-26
# Processing for date: 2024-10-27
# Processing for date: 2024-10-28
# Processing for date: 2024-10-29
# Processing for date: 2024-10-30
# Processing for date: 2024-10-31
# Processing for date: 2024-11-01
# Processing for date: 2024-11-02
# Processing for date: 2024-11-03
# Processing for date: 2024-11-04
# Processing for date: 2024-11-05
# Processing for date: 2024-11-06
# Processing for date: 2024-11-07
# Processing for date: 2024-11-08
# Processing for date: 2024-11-09
# Processing for date: 2024-11-10
# Processing for date: 2024-11-11
# Processing for date: 2024-11-12
# Processing for date: 2024-11-13
# Processing for date: 2024-11-14
# Processing for date: 2024-11-15
# Processing for date: 2024-11-16
# Processing for date: 2024-11-17
# Processing for date: 2024-11-18
# Processing for date: 2024-11-19
# Processing for date: 2024-11-20
# Processing for date: 2024-11-21
# Processing for date: 2024-11-22
# Processing for date: 2024-11-23
# Processing for date: 2024-11-24
# Processing for date: 2024-11-25
# Processing for date: 2024-11-26
# Processing for date: 2024-11-27
# Processing for date: 2024-11-28
# Processing for date: 2024-11-29
# Processing for date: 2024-11-30
# Processing for date: 2024-12-01
# Processing for date: 2024-12-02
# Processing for date: 2024-12-03
# Processing for date: 2024-12-04
# Processing for date: 2024-12-05
# Processing for date: 2024-12-06
# Processing for date: 2024-12-07
# Processing for date: 2024-12-08
# Processing for date: 2024-12-09
# Processing for date: 2024-12-10
# Processing for date: 2024-12-11
# Processing for date: 2024-12-12
# Processing for date: 2024-12-13
# Processing for date: 2024-12-14
# Processing for date: 2024-12-15
# Processing for date: 2024-12-16
# Processing for date: 2024-12-17
# Processing for date: 2024-12-18
# Processing for date: 2024-12-19
# Processing for date: 2024-12-20
# Processing for date: 2024-12-21
# Processing for date: 2024-12-22
# Processing for date: 2024-12-23
# Processing for date: 2024-12-24
# Processing for date: 2024-12-25
# Processing for date: 2024-12-26
# Processing for date: 2024-12-27
# Processing for date: 2024-12-28
# Processing for date: 2024-12-29
# Processing for date: 2024-12-30
# Processing for date: 2024-12-31

# %%
len(trade_data_list)

# %%
output_file = 'enam.jsonl'
# Save as JSONL
with open(output_file, "w", encoding="utf-8") as f:
    for record in trade_data_list:
        f.write(json.dumps(record, ensure_ascii=False) + "\n")

# %%
url = "https://enam.gov.in/web/Ajax_ctrl/commodity_list"
payload = {
    "language": "en",
    "stateName": "ANDHRA PRADESH",
    "apmcName": "-- Select APMCs --",
    "fromDate": "2025-08-13",
    "toDate": "2025-08-13"
}
response = requests.post(url, data=payload, headers=headers)
commodity_list = response.json()['data']
commodity_list

# %%
len(commodity_list)
