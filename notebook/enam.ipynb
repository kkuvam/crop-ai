# %%
import os
import json
import time
import requests
from pathlib import Path
import gzip, json
from datetime import datetime, timedelta
from typing import Dict, Any, Optional, Iterable

# %%
def get_states():
    url = "https://enam.gov.in/web/ajax_ctrl/states_name"
    response = requests.get(url)
    return response.json()

# %%
get_states()

# %%
headers = {
    "User-Agent": "Mozilla/5.0",
    "Content-Type": "application/x-www-form-urlencoded"
}

# %%
def get_apmcs():
    apmcs = []
    url = "https://enam.gov.in/web/Ajax_ctrl/apmc_list"
    states = get_states()['data']
    # Extract all state_ids
    state_ids = [item['state_id'] for item in states]
    for state_id in state_ids:
        payload = { 'state_id': state_id}
        response = requests.post(url, data=payload, headers=headers)
        apmcs.extend(response.json()['data'])
    return apmcs

# %%
get_apmcs()

# %%
def date_range(start_date: str, end_date: str):
    """
    Yields date strings (YYYY-MM-DD) from start_date to end_date inclusive.
    """
    start = datetime.strptime(start_date, "%Y-%m-%d").date()
    end = datetime.strptime(end_date, "%Y-%m-%d").date()

    current = start
    while current <= end:
        yield current.strftime("%Y-%m-%d")
        current += timedelta(days=1)

# %%
date_range("2025-08-01", "2025-08-12")

# %%
def save_jsonl_gz(data: list, jsonl_path: str) -> None:
    """
    Append DataFrame rows to a JSONL file (one JSON object per line).
    """
    if not data:
        return
    with gzip.open(jsonl_path, "wt", encoding="utf-8") as f:
        for row in data:
            f.write(json.dumps(row, ensure_ascii=False) + "\n")

# %%
def to_date(s: str) -> datetime:
    """
    Parse a date string into a datetime object.
    Supports common formats like:
    - YYYY-MM-DD
    - DD-MM-YYYY
    - DD/MM/YYYY
    - YYYY/MM/DD
    - MM/DD/YYYY
    """
    try:
        return datetime.fromisoformat(s)  # handles YYYY-MM-DD
    except ValueError:
        for fmt in ("%d-%m-%Y", "%d/%m/%Y", "%Y/%m/%d", "%m/%d/%Y"):
            try:
                return datetime.strptime(s, fmt)
            except ValueError:
                continue
    raise ValueError(f"Unrecognized date format: {s}")

# %%
def get_trade_data(date_str: str) -> list:
    url = "https://enam.gov.in/web/Ajax_ctrl/trade_data_list"
    payload = {
        "language": "en",
        "stateName": "-- All --",
        "apmcName": "-- Select APMCs --",
        "commodityName": "-- Select Commodity --"    
    }
    payload["fromDate"] = date_str
    payload["toDate"] = date_str
    response = requests.post(url, data=payload, headers=headers)
    return response.json()['data']

# %%
get_trade_data("2025-08-12")

# %%
def get_trade_date_range(start_date: str, end_date: str, jsonl_path: str) -> list:
    all_data = []
    for d in date_range(start_date, end_date):
        dt = datetime.strptime(d, "%Y-%m-%d")
        date_str = dt.strftime("%Y-%m-%d")
        year_str = dt.strftime("%Y") 
        month_str = dt.strftime("%b") 
        data = get_trade_data(date_str)
        day_dir = Path(jsonl_path)
        out_path = day_dir / year_str / month_str / f"{date_str}.jsonl.gz"
        out_path.parent.mkdir(parents=True, exist_ok=True)
        print(f"Processing for date: {date_str}")
        save_jsonl_gz(data, out_path)
        all_data.extend(data)
    return all_data

# %%
output_location = "../data/enam/"
trade_data_list = get_trade_date_range("2025-01-01", "2025-12-31", output_location)
# Processing for date: 2025-07-14
# Processing for date: 2025-07-15
# Processing for date: 2025-07-16
# Processing for date: 2025-07-17
# Processing for date: 2025-07-18
# Processing for date: 2025-07-19
# Processing for date: 2025-07-20
# Processing for date: 2025-07-21
# Processing for date: 2025-07-22
# Processing for date: 2025-07-23
# Processing for date: 2025-07-24
# Processing for date: 2025-07-25
# Processing for date: 2025-07-26
# Processing for date: 2025-07-27
# Processing for date: 2025-07-28
# Processing for date: 2025-07-29
# Processing for date: 2025-07-30
# Processing for date: 2025-07-31
# Processing for date: 2025-08-01
# Processing for date: 2025-08-02
# Processing for date: 2025-08-03
# Processing for date: 2025-08-04
# Processing for date: 2025-08-05
# Processing for date: 2025-08-06
# Processing for date: 2025-08-07
# Processing for date: 2025-08-08
# Processing for date: 2025-08-09
# Processing for date: 2025-08-10
# Processing for date: 2025-08-11
# Processing for date: 2025-08-12
# Processing for date: 2025-08-13
# Processing for date: 2025-08-14
# Processing for date: 2025-08-15
# Processing for date: 2025-08-16
# Processing for date: 2025-08-17
# Processing for date: 2025-08-18
# Processing for date: 2025-08-19
# Processing for date: 2025-08-20
# Processing for date: 2025-08-21
# Processing for date: 2025-08-22
# Processing for date: 2025-08-23
# Processing for date: 2025-08-24
# Processing for date: 2025-08-25
# Processing for date: 2025-08-26
# Processing for date: 2025-08-27
# Processing for date: 2025-08-28
# Processing for date: 2025-08-29
# Processing for date: 2025-08-30
# Processing for date: 2025-08-31
# Processing for date: 2025-09-01
# Processing for date: 2025-09-02
# Processing for date: 2025-09-03
# Processing for date: 2025-09-04
# Processing for date: 2025-09-05
# Processing for date: 2025-09-06
# Processing for date: 2025-09-07
# Processing for date: 2025-09-08
# Processing for date: 2025-09-09
# Processing for date: 2025-09-10
# Processing for date: 2025-09-11
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 output_location = "../data/enam/"
# ----> 2 trade_data_list = get_trade_date_range("2025-01-01", "2025-12-31", output_location)
#
# Cell In[9], line 8, in get_trade_date_range(start_date, end_date, jsonl_path)
#       6 year_str = dt.strftime("%Y")
#       7 month_str = dt.strftime("%b")
# ----> 8 data = get_trade_data(date_str)
#       9 day_dir = Path(jsonl_path)
#      10 out_path = day_dir / year_str / month_str / f"{date_str}.jsonl.gz"
#
# Cell In[8], line 12, in get_trade_data(date_str)
#      10 payload["toDate"] = date_str
#      11 response = requests.post(url, data=payload, headers=headers)
# ---> 12 return response.json()['data']
#
# KeyError: 'data'

# %%
len(trade_data_list)

# %%
output_file = 'enam.jsonl'
# Save as JSONL
with open(output_file, "w", encoding="utf-8") as f:
    for record in trade_data_list:
        f.write(json.dumps(record, ensure_ascii=False) + "\n")

# %%
url = "https://enam.gov.in/web/Ajax_ctrl/commodity_list"
payload = {
    "language": "en",
    "stateName": "ANDHRA PRADESH",
    "apmcName": "-- Select APMCs --",
    "fromDate": "2025-08-13",
    "toDate": "2025-08-13"
}
response = requests.post(url, data=payload, headers=headers)
commodity_list = response.json()['data']
commodity_list

# %%
len(commodity_list)
